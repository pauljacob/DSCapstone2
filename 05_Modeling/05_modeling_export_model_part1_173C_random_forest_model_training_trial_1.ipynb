# %%
# !pip install ipython-autotime
# Out:
# Requirement already satisfied: ipython-autotime in c:\users\paul\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: ipython in c:\users\paul\anaconda3\lib\site-packages (from ipython-autotime) (7.12.0)
# Requirement already satisfied: pickleshare in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.14.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (3.0.3)
# Requirement already satisfied: backcall in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.1.0)
# Requirement already satisfied: pygments in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (2.5.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (45.2.0.post20200210)
# Requirement already satisfied: decorator in c:\users\paul\anaconda3\lib\site-packages (from ipython->ipython-autotime) (4.4.1)
# Requirement already satisfied: parso>=0.5.0 in c:\users\paul\anaconda3\lib\site-packages (from jedi>=0.10->ipython->ipython-autotime) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\paul\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.1.8)
# Requirement already satisfied: six in c:\users\paul\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->ipython-autotime) (1.14.0)
# Requirement already satisfied: ipython-genutils in c:\users\paul\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)

# %%
# %load_ext autotime
# Out:
# time: 0 ns (started: 2021-09-12 16:09:30 -07:00)

# %% [markdown]
# ## 4.3 Imports<a id='4.3_Imports'></a>

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
import datetime
# Out:
# time: 1.12 s (started: 2021-09-12 16:09:30 -07:00)

# %%
#return the first 5 and last 5 rows of this dataframe
def p(df_):
    if df_.shape[0] > 6:
        print(df_.shape)
        return pd.concat([df_.head(), df_.tail()])
    else:
        return df_

def rcp(file_, pd_=None, ic_=None):
    if (pd_ == None) and (ic_ == None):
        return pd.read_csv(os.path.join('..', 'processed_data', file_))
    elif (pd_ != None) and (ic_ == None):
        return pd.read_csv(os.path.join('..', 'processed_data', file_), parse_dates=pd_)
    elif (pd_ != None) and (ic_ != None):
        return pd.read_csv(os.path.join('..', 'processed_data', file_), parse_dates=pd_, index_col = ic_)
    else:
        return pd.read_csv(os.path.join('..', 'processed_data', file_), index_col = ic_)
    
def rcr(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'raw_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'raw_data', file_), parse_dates=pd_)
    
#sort dataframe by column
def s(df_, column_):
    return df_.sort_values(column_)

#reset index and sort dataframe by column
def sr(df_, column_, ascending_=True):
    df_ = df_.sort_values(column_, ascending=ascending_)
    return df_.reset_index(drop=True)

#print length of list
def pl(list_):
    print(len(list_))
    return list_

#print length of dictionary
def pdc(dict_):
    print(len(dict_))
    return dict_
# Out:
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %%
def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape
# Out:
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %% [markdown]
# ## 4.4 Load Data<a id='4.4_Load_Data'></a>

# %%
df_train = rcp('173C_train_split_time_series_merge_173A_and_173B.csv', 
               None)
p(df_train)
# Out:
# (9239, 101)
#       travel_distance_diff  latitude_diff  longitude_diff  \
# 0                -1.045984       2.249661        0.309284
# 1                 0.835137      -1.609206        0.383027
# 2                 1.138839      -0.562003        1.001028
# 3                -1.256725       0.877570        1.270549
# 4                 0.848535      -1.892884       -0.403891
# 9234              1.950338       0.908407       -2.448327
# 9235             -0.159237      -0.346823       -0.114386
# 9236              0.668894       0.365307        0.609586
# 9237             -1.178771      -1.458661       -1.226125
# 9238             -1.593147       1.080693       -1.772901
#
#       team_id_b_1610612759  games_back_to_back_percentage_game_window999_diff  \
# 0                        0                                          -0.016676
# 1                        0                                          -0.016676
# 2                        0                                          -0.016676
# 3                        0                                          -0.016676
# 4                        0                                           6.083854
# 9234                     0                                           1.781375
# 9235                     0                                           0.464945
# 9236                     0                                          -1.933986
# 9237                     0                                          -0.016676
# 9238                     0                                           1.203430
#
#       city_proper_metro_Area_b_San Antonio  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# 9234                                     0
# 9235                                     0
# 9236                                     0
# 9237                                     0
# 9238                                     0
#
#       future_Away_game_percent_day_window999_diff  \
# 0                                        0.009482
# 1                                        0.009482
# 2                                        0.009482
# 3                                        0.009482
# 4                                       -0.030497
# 9234                                     0.163685
# 9235                                     0.163685
# 9236                                     0.059225
# 9237                                    -0.395302
# 9238                                     0.009482
#
#       future_home_game_percent_day_window999_diff  \
# 0                                       -0.009482
# 1                                       -0.009482
# 2                                       -0.009482
# 3                                       -0.009482
# 4                                        0.030497
# 9234                                    -0.163685
# 9235                                    -0.163685
# 9236                                    -0.059225
# 9237                                     0.395302
# 9238                                    -0.009482
#
#       away_game_percent_day_window999_diff  \
# 0                                -6.465582
# 1                                 6.416819
# 2                                 6.416819
# 3                                -6.465582
# 4                                 6.416819
# 9234                             -0.176936
# 9235                             -0.838007
# 9236                              0.113645
# 9237                              0.992650
# 9238                             -0.346441
#
#       games_back_to_back_count_game_window999_diff  ...  \
# 0                                        -0.052324  ...
# 1                                        -0.052324  ...
# 2                                        -0.052324  ...
# 3                                        -0.052324  ...
# 4                                         0.414362  ...
# 9234                                      1.347733  ...
# 9235                                      0.414362  ...
# 9236                                     -1.452381  ...
# 9237                                     -0.052324  ...
# 9238                                      0.881048  ...
#
#       NET_RATING_cma12_diff  pf_cmax999_diff  lc_sum_NET_RATING_cmax999_diff  \
# 0                 -0.026252         0.110128                       -0.049559
# 1                 -0.026252         0.110128                       -0.049559
# 2                 -0.026252         0.110128                       -0.049559
# 3                 -0.026252         0.110128                       -0.049559
# 4                 -0.879667         4.661921                       -0.319484
# 9234              -0.234987        -0.973632                       -1.004135
# 9235              -0.967409        -0.540128                       -1.002372
# 9236               0.552851         0.543632                       -1.278631
# 9237               1.152273         0.977137                       -0.462101
# 9238               1.435821        -0.540128                       -0.305763
#
#       lc_max_AST_TOV_cmax12_diff  lc_sum_AST_PCT_cmax5_diff  \
# 0                      -0.088860                  -0.094422
# 1                      -0.088860                  -0.094422
# 2                      -0.088860                  -0.094422
# 3                      -0.088860                  -0.094422
# 4                       1.247488                   1.691365
# 9234                   -2.694313                   0.931848
# 9235                    0.228034                   1.378510
# 9236                    0.481034                  -0.087806
# 9237                    5.274412                  -1.226123
# 9238                    0.053790                  -0.145745
#
#       fg3_pct_cma999_diff  ft_pct_cmax12_diff  lc_max_MIN_cmax5_diff  \
# 0               -0.008676            0.001855              -0.025856
# 1               -0.008676            0.001855              -0.025856
# 2               -0.008676            0.001855              -0.025856
# 3               -0.008676            0.001855              -0.025856
# 4                8.286999            8.007766               3.521210
# 9234             0.273061            0.163264              -0.448480
# 9235             0.025707            0.196310              -0.184705
# 9236            -1.030682           -0.349282               1.555168
# 9237             0.139954           -0.431214               0.707843
# 9238             1.330639            0.001855               0.458857
#
#       E_NET_RATING_cma5_diff  E_NET_RATING_cmax12_diff
# 0                  -0.017154                 -0.031080
# 1                  -0.017154                 -0.031080
# 2                  -0.017154                 -0.031080
# 3                  -0.017154                 -0.031080
# 4                  -0.677803                 -0.598734
# 9234                0.130420                  0.013153
# 9235               -0.567981                  0.543946
# 9236               -0.463307                 -0.900991
# 9237                1.522073                  0.507086
# 9238                0.813377                  1.745603
#
# [10 rows x 101 columns]
# time: 203 ms (started: 2021-09-12 16:09:32 -07:00)

# %%
df_test = rcp('173C_test_split_time_series_merge_173A_and_173B.csv', 
              None)
p(df_test)
# Out:
# (1027, 101)
#       travel_distance_diff  latitude_diff  longitude_diff  \
# 0                 1.028423       0.322683        1.055866
# 1                -0.989872       2.184396       -0.524758
# 2                 0.792883       0.757034        0.660032
# 3                -1.063182       1.568692        0.796300
# 4                -0.509033       0.020163        0.452923
# 1022              1.359732       1.106411       -1.506188
# 1023              1.789289       0.507847        1.893345
# 1024              1.789289       0.507847        1.893345
# 1025             -1.790571       0.507847        1.893345
# 1026             -1.790571       0.507847        1.893345
#
#       team_id_b_1610612759  games_back_to_back_percentage_game_window999_diff  \
# 0                        0                                          -0.423378
# 1                        0                                           1.374673
# 2                        0                                           0.625485
# 3                        0                                          -1.091531
# 4                        0                                          -0.921539
# 1022                     0                                          -0.016676
# 1023                     0                                          -0.154391
# 1024                     0                                          -0.152875
# 1025                     0                                          -0.151392
# 1026                     0                                          -0.149940
#
#       city_proper_metro_Area_b_San Antonio  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# 1022                                     0
# 1023                                     0
# 1024                                     0
# 1025                                     0
# 1026                                     0
#
#       future_Away_game_percent_day_window999_diff  \
# 0                                       -0.094902
# 1                                       -0.239616
# 2                                       -0.091714
# 3                                       -0.355300
# 4                                       -0.149777
# 1022                                     0.009482
# 1023                                     0.009482
# 1024                                     0.009482
# 1025                                     0.009482
# 1026                                     0.009482
#
#       future_home_game_percent_day_window999_diff  \
# 0                                        0.094902
# 1                                        0.239616
# 2                                        0.091714
# 3                                        0.355300
# 4                                        0.149777
# 1022                                    -0.009482
# 1023                                    -0.009482
# 1024                                    -0.009482
# 1025                                    -0.009482
# 1026                                    -0.009482
#
#       away_game_percent_day_window999_diff  \
# 0                                 0.619739
# 1                                 0.521802
# 2                                 0.653640
# 3                                 0.742428
# 4                                 0.098895
# 1022                              0.040681
# 1023                              0.071918
# 1024                              0.134429
# 1025                              0.070036
# 1026                              0.006887
#
#       games_back_to_back_count_game_window999_diff  ...  \
# 0                                        -0.519009  ...
# 1                                         0.881048  ...
# 2                                         0.414362  ...
# 3                                        -0.985695  ...
# 4                                        -0.519009  ...
# 1022                                     -0.052324  ...
# 1023                                     -0.519009  ...
# 1024                                     -0.519009  ...
# 1025                                     -0.519009  ...
# 1026                                     -0.519009  ...
#
#       NET_RATING_cma12_diff  pf_cmax999_diff  lc_sum_NET_RATING_cmax999_diff  \
# 0                 -0.323654         0.543632                       -0.623327
# 1                 -1.365485        -0.106624                       -1.258891
# 2                  0.285004         0.326880                        1.028775
# 3                  1.161510        -0.756880                        0.248091
# 4                  0.792989        -0.973632                        0.899901
# 1022               0.854871        -0.973632                        0.731619
# 1023              -0.452036         0.543632                        1.359431
# 1024              -0.542549         0.543632                        1.359431
# 1025              -0.925847         0.543632                        1.359431
# 1026              -1.439374         0.543632                        1.359431
#
#       lc_max_AST_TOV_cmax12_diff  lc_sum_AST_PCT_cmax5_diff  \
# 0                       0.183842                   0.547129
# 1                      -0.790590                   2.544037
# 2                      -0.317461                   0.295721
# 3                       1.364641                   0.100918
# 4                       0.785766                  -1.158458
# 1022                   -1.495076                   0.110108
# 1023                    0.365893                   0.047835
# 1024                    0.365893                   0.047835
# 1025                    0.392504                   0.590597
# 1026                    0.392504                   0.590597
#
#       fg3_pct_cma999_diff  ft_pct_cmax12_diff  lc_max_MIN_cmax5_diff  \
# 0               -0.093945           -0.615885               0.401065
# 1               -0.582190            0.316977               1.269063
# 2                0.448738           -1.731027              -0.381070
# 3                0.879725            0.404729               0.836795
# 4               -0.596616           -1.233626               1.533060
# 1022             0.406319            0.038192              -0.733868
# 1023            -0.323504           -1.048304              -0.077045
# 1024            -0.339029           -1.110078              -0.077045
# 1025            -0.352941           -1.110078               1.181174
# 1026            -0.360802           -1.110078               1.195694
#
#       E_NET_RATING_cma5_diff  E_NET_RATING_cmax12_diff
# 0                  -1.033010                 -1.505506
# 1                  -1.523778                  0.278550
# 2                   0.322609                 -0.067941
# 3                   0.753318                  0.853576
# 4                   1.247518                 -0.001591
# 1022                1.695387                  1.480207
# 1023               -0.640052                 -0.849386
# 1024               -0.730998                 -0.849386
# 1025               -1.566677                 -0.849386
# 1026               -1.915019                 -0.849386
#
# [10 rows x 101 columns]
# time: 62 ms (started: 2021-09-12 16:09:32 -07:00)

# %%
X_train = df_train.drop(columns = 'spread_a')
p(X_train)
# Out:
# (9239, 100)
#       travel_distance_diff  latitude_diff  longitude_diff  \
# 0                -1.045984       2.249661        0.309284
# 1                 0.835137      -1.609206        0.383027
# 2                 1.138839      -0.562003        1.001028
# 3                -1.256725       0.877570        1.270549
# 4                 0.848535      -1.892884       -0.403891
# 9234              1.950338       0.908407       -2.448327
# 9235             -0.159237      -0.346823       -0.114386
# 9236              0.668894       0.365307        0.609586
# 9237             -1.178771      -1.458661       -1.226125
# 9238             -1.593147       1.080693       -1.772901
#
#       team_id_b_1610612759  games_back_to_back_percentage_game_window999_diff  \
# 0                        0                                          -0.016676
# 1                        0                                          -0.016676
# 2                        0                                          -0.016676
# 3                        0                                          -0.016676
# 4                        0                                           6.083854
# 9234                     0                                           1.781375
# 9235                     0                                           0.464945
# 9236                     0                                          -1.933986
# 9237                     0                                          -0.016676
# 9238                     0                                           1.203430
#
#       city_proper_metro_Area_b_San Antonio  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# 9234                                     0
# 9235                                     0
# 9236                                     0
# 9237                                     0
# 9238                                     0
#
#       future_Away_game_percent_day_window999_diff  \
# 0                                        0.009482
# 1                                        0.009482
# 2                                        0.009482
# 3                                        0.009482
# 4                                       -0.030497
# 9234                                     0.163685
# 9235                                     0.163685
# 9236                                     0.059225
# 9237                                    -0.395302
# 9238                                     0.009482
#
#       future_home_game_percent_day_window999_diff  \
# 0                                       -0.009482
# 1                                       -0.009482
# 2                                       -0.009482
# 3                                       -0.009482
# 4                                        0.030497
# 9234                                    -0.163685
# 9235                                    -0.163685
# 9236                                    -0.059225
# 9237                                     0.395302
# 9238                                    -0.009482
#
#       away_game_percent_day_window999_diff  \
# 0                                -6.465582
# 1                                 6.416819
# 2                                 6.416819
# 3                                -6.465582
# 4                                 6.416819
# 9234                             -0.176936
# 9235                             -0.838007
# 9236                              0.113645
# 9237                              0.992650
# 9238                             -0.346441
#
#       games_back_to_back_count_game_window999_diff  ...  \
# 0                                        -0.052324  ...
# 1                                        -0.052324  ...
# 2                                        -0.052324  ...
# 3                                        -0.052324  ...
# 4                                         0.414362  ...
# 9234                                      1.347733  ...
# 9235                                      0.414362  ...
# 9236                                     -1.452381  ...
# 9237                                     -0.052324  ...
# 9238                                      0.881048  ...
#
#       NET_RATING_cma12_diff  pf_cmax999_diff  lc_sum_NET_RATING_cmax999_diff  \
# 0                 -0.026252         0.110128                       -0.049559
# 1                 -0.026252         0.110128                       -0.049559
# 2                 -0.026252         0.110128                       -0.049559
# 3                 -0.026252         0.110128                       -0.049559
# 4                 -0.879667         4.661921                       -0.319484
# 9234              -0.234987        -0.973632                       -1.004135
# 9235              -0.967409        -0.540128                       -1.002372
# 9236               0.552851         0.543632                       -1.278631
# 9237               1.152273         0.977137                       -0.462101
# 9238               1.435821        -0.540128                       -0.305763
#
#       lc_max_AST_TOV_cmax12_diff  lc_sum_AST_PCT_cmax5_diff  \
# 0                      -0.088860                  -0.094422
# 1                      -0.088860                  -0.094422
# 2                      -0.088860                  -0.094422
# 3                      -0.088860                  -0.094422
# 4                       1.247488                   1.691365
# 9234                   -2.694313                   0.931848
# 9235                    0.228034                   1.378510
# 9236                    0.481034                  -0.087806
# 9237                    5.274412                  -1.226123
# 9238                    0.053790                  -0.145745
#
#       fg3_pct_cma999_diff  ft_pct_cmax12_diff  lc_max_MIN_cmax5_diff  \
# 0               -0.008676            0.001855              -0.025856
# 1               -0.008676            0.001855              -0.025856
# 2               -0.008676            0.001855              -0.025856
# 3               -0.008676            0.001855              -0.025856
# 4                8.286999            8.007766               3.521210
# 9234             0.273061            0.163264              -0.448480
# 9235             0.025707            0.196310              -0.184705
# 9236            -1.030682           -0.349282               1.555168
# 9237             0.139954           -0.431214               0.707843
# 9238             1.330639            0.001855               0.458857
#
#       E_NET_RATING_cma5_diff  E_NET_RATING_cmax12_diff
# 0                  -0.017154                 -0.031080
# 1                  -0.017154                 -0.031080
# 2                  -0.017154                 -0.031080
# 3                  -0.017154                 -0.031080
# 4                  -0.677803                 -0.598734
# 9234                0.130420                  0.013153
# 9235               -0.567981                  0.543946
# 9236               -0.463307                 -0.900991
# 9237                1.522073                  0.507086
# 9238                0.813377                  1.745603
#
# [10 rows x 100 columns]
# time: 31 ms (started: 2021-09-12 16:09:32 -07:00)

# %%
y_train = df_train.spread_a
p(y_train)
# Out:
# (9239,)
# 0       -8
# 1       14
# 2        2
# 3        1
# 4      -10
# 9234    -3
# 9235   -16
# 9236   -10
# 9237   -15
# 9238   -15
# Name: spread_a, dtype: int64
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %%
X_test = df_test.drop(columns = 'spread_a')
p(X_test)
# Out:
# (1027, 100)
#       travel_distance_diff  latitude_diff  longitude_diff  \
# 0                 1.028423       0.322683        1.055866
# 1                -0.989872       2.184396       -0.524758
# 2                 0.792883       0.757034        0.660032
# 3                -1.063182       1.568692        0.796300
# 4                -0.509033       0.020163        0.452923
# 1022              1.359732       1.106411       -1.506188
# 1023              1.789289       0.507847        1.893345
# 1024              1.789289       0.507847        1.893345
# 1025             -1.790571       0.507847        1.893345
# 1026             -1.790571       0.507847        1.893345
#
#       team_id_b_1610612759  games_back_to_back_percentage_game_window999_diff  \
# 0                        0                                          -0.423378
# 1                        0                                           1.374673
# 2                        0                                           0.625485
# 3                        0                                          -1.091531
# 4                        0                                          -0.921539
# 1022                     0                                          -0.016676
# 1023                     0                                          -0.154391
# 1024                     0                                          -0.152875
# 1025                     0                                          -0.151392
# 1026                     0                                          -0.149940
#
#       city_proper_metro_Area_b_San Antonio  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# 1022                                     0
# 1023                                     0
# 1024                                     0
# 1025                                     0
# 1026                                     0
#
#       future_Away_game_percent_day_window999_diff  \
# 0                                       -0.094902
# 1                                       -0.239616
# 2                                       -0.091714
# 3                                       -0.355300
# 4                                       -0.149777
# 1022                                     0.009482
# 1023                                     0.009482
# 1024                                     0.009482
# 1025                                     0.009482
# 1026                                     0.009482
#
#       future_home_game_percent_day_window999_diff  \
# 0                                        0.094902
# 1                                        0.239616
# 2                                        0.091714
# 3                                        0.355300
# 4                                        0.149777
# 1022                                    -0.009482
# 1023                                    -0.009482
# 1024                                    -0.009482
# 1025                                    -0.009482
# 1026                                    -0.009482
#
#       away_game_percent_day_window999_diff  \
# 0                                 0.619739
# 1                                 0.521802
# 2                                 0.653640
# 3                                 0.742428
# 4                                 0.098895
# 1022                              0.040681
# 1023                              0.071918
# 1024                              0.134429
# 1025                              0.070036
# 1026                              0.006887
#
#       games_back_to_back_count_game_window999_diff  ...  \
# 0                                        -0.519009  ...
# 1                                         0.881048  ...
# 2                                         0.414362  ...
# 3                                        -0.985695  ...
# 4                                        -0.519009  ...
# 1022                                     -0.052324  ...
# 1023                                     -0.519009  ...
# 1024                                     -0.519009  ...
# 1025                                     -0.519009  ...
# 1026                                     -0.519009  ...
#
#       NET_RATING_cma12_diff  pf_cmax999_diff  lc_sum_NET_RATING_cmax999_diff  \
# 0                 -0.323654         0.543632                       -0.623327
# 1                 -1.365485        -0.106624                       -1.258891
# 2                  0.285004         0.326880                        1.028775
# 3                  1.161510        -0.756880                        0.248091
# 4                  0.792989        -0.973632                        0.899901
# 1022               0.854871        -0.973632                        0.731619
# 1023              -0.452036         0.543632                        1.359431
# 1024              -0.542549         0.543632                        1.359431
# 1025              -0.925847         0.543632                        1.359431
# 1026              -1.439374         0.543632                        1.359431
#
#       lc_max_AST_TOV_cmax12_diff  lc_sum_AST_PCT_cmax5_diff  \
# 0                       0.183842                   0.547129
# 1                      -0.790590                   2.544037
# 2                      -0.317461                   0.295721
# 3                       1.364641                   0.100918
# 4                       0.785766                  -1.158458
# 1022                   -1.495076                   0.110108
# 1023                    0.365893                   0.047835
# 1024                    0.365893                   0.047835
# 1025                    0.392504                   0.590597
# 1026                    0.392504                   0.590597
#
#       fg3_pct_cma999_diff  ft_pct_cmax12_diff  lc_max_MIN_cmax5_diff  \
# 0               -0.093945           -0.615885               0.401065
# 1               -0.582190            0.316977               1.269063
# 2                0.448738           -1.731027              -0.381070
# 3                0.879725            0.404729               0.836795
# 4               -0.596616           -1.233626               1.533060
# 1022             0.406319            0.038192              -0.733868
# 1023            -0.323504           -1.048304              -0.077045
# 1024            -0.339029           -1.110078              -0.077045
# 1025            -0.352941           -1.110078               1.181174
# 1026            -0.360802           -1.110078               1.195694
#
#       E_NET_RATING_cma5_diff  E_NET_RATING_cmax12_diff
# 0                  -1.033010                 -1.505506
# 1                  -1.523778                  0.278550
# 2                   0.322609                 -0.067941
# 3                   0.753318                  0.853576
# 4                   1.247518                 -0.001591
# 1022                1.695387                  1.480207
# 1023               -0.640052                 -0.849386
# 1024               -0.730998                 -0.849386
# 1025               -1.566677                 -0.849386
# 1026               -1.915019                 -0.849386
#
# [10 rows x 100 columns]
# time: 32 ms (started: 2021-09-12 16:09:32 -07:00)

# %%
y_test = df_test.spread_a
p(y_test)
# Out:
# (1027,)
# 0       13
# 1        7
# 2      -10
# 3      -11
# 4       10
# 1022    -9
# 1023    10
# 1024    19
# 1025     8
# 1026    23
# Name: spread_a, dtype: int64
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %% [markdown]
# ## 4.10 Random Forest Model<a id='4.10_Random_Forest_Model'></a>

# %% [markdown]
# A model that can work very well in a lot of cases is the random forest. For regression, this is provided by `sklearn`'s `RandomForestRegressor` class.
#
# Time to stop the bad practice of repeatedly checking performance on the test split. Instead, go straight from defining the pipeline to assessing performance using cross-validation. `cross_validate` will perform the fitting as part of the process. This uses the default settings for the random forest so you'll then proceed to investigate some different hyperparameters.

# %% [markdown]
# ### 4.10.1 Define the pipeline<a id='4.10.1_Define_the_pipeline'></a>

# %%
RF_pipe = make_pipeline(
    RandomForestRegressor(criterion = 'mae', random_state=47)
)
# Out:
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %% [markdown]
# <font color='red'> default parameters of the RandomForestRegressor are?????</font>
#
# min_samples_split=2,
# max_features='auto'

# %%
type(RF_pipe)
# Out:
# sklearn.pipeline.Pipeline
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %%
hasattr(RF_pipe, 'fit'), hasattr(RF_pipe, 'predict')
# Out:
# (True, True)
# time: 0 ns (started: 2021-09-12 16:09:32 -07:00)

# %% [markdown]
# ### 4.10.2 Fit and assess performance using cross-validation<a id='4.10.2_Fit_and_assess_performance_using_cross-validation'></a>

# %%
#Code task 23#
#Call `cross_validate` to estimate the pipeline's performance.
#Pass it the random forest pipe object, `X_train` and `y_train`,
#and get it to use 5-fold cross-validation
rf_default_cv_results = cross_validate(RF_pipe, X_train, y_train, cv=5)
# Out:
# time: 1h 4min 13s (started: 2021-09-12 16:09:32 -07:00)

# %% [markdown]
# <font color='red'> specify you want mape or mae here instead of test_score?????????</font>

# %%
rf_cv_scores = rf_default_cv_results['test_score']
rf_cv_scores
# Out:
# array([0.1899763 , 0.18713922, 0.19185661, 0.19540521, 0.16715047])
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %% [markdown]
# <font color='red'> this is test score for the training set cv splits?????</font>

# %%
np.mean(rf_cv_scores), np.std(rf_cv_scores)
# Out:
# (0.18630556035232776, 0.009946905589772868)
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %%
#rf_cv_scores_mae = rf_default_cv_results['test_mae']
#rf_cv_scores_mae
# Out:
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %%
#np.mean(rf_cv_scores_mae), np.std(rf_cv_scores_mae)
# Out:
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %% [markdown]
# <font color='red'> this 'test_mae' the correct syntax???? </font>

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html
# Out:
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %% [markdown]
# ### 4.10.3 Hyperparameter search using GridSearchCV<a id='4.10.3_Hyperparameter_search_using_GridSearchCV'></a>

# %% [markdown]
# Random forest has a number of hyperparameters that can be explored, however here you'll limit yourselves to exploring some different values for the number of trees. You'll try it with and without feature scaling, and try both the mean and median as strategies for imputing missing values.

# %%
#n_est = [int(n) for n in np.logspace(start=1, stop=3, num=20)]

grid_params = {
        'randomforestregressor__n_estimators': [200],
        'randomforestregressor__max_depth': [5, 10, 20, 1000],
        'randomforestregressor__min_samples_split': [50, 100, 1000]
}
grid_params
# Out:
# {'randomforestregressor__n_estimators': [200],
#  'randomforestregressor__max_depth': [5, 10, 20, 1000],
#  'randomforestregressor__min_samples_split': [50, 100, 1000]}
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %%
#Code task 24#
#Call `GridSearchCV` with the random forest pipeline, passing in the above `grid_params`
#dict for parameters to evaluate, 5-fold cross-validation, and all available CPU cores (if desired)
rf_grid_cv = GridSearchCV(RF_pipe, param_grid=grid_params, cv=5, n_jobs=-1)
# Out:
# time: 0 ns (started: 2021-09-12 17:13:47 -07:00)

# %%
#Code task 25#
#Now call the `GridSearchCV`'s `fit()` method with `X_train` and `y_train` as arguments
#to actually start the grid search. This may take a minute or two.
rf_grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('randomforestregressor',
#                                         RandomForestRegressor(bootstrap=True,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mae',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=...
#                                                               oob_score=False,
#                                                               random_state=47,
#                                                               verbose=0,
#                                                               warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'randomforestregressor__max_depth': [5, 10, 20, 1000],
#                          'randomforestregressor__min_samples_split': [50, 100,
#                                                                       1000],
#                          'randomforestregressor__n_estimators': [200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# time: 5h 27min 47s (started: 2021-09-12 17:13:47 -07:00)

# %%
#Code task 26#
#Print the best params (`best_params_` attribute) from the grid search
rf_grid_cv.best_params_
# Out:
# {'randomforestregressor__max_depth': 10,
#  'randomforestregressor__min_samples_split': 100,
#  'randomforestregressor__n_estimators': 200}
# time: 15 ms (started: 2021-09-12 22:41:35 -07:00)

# %% [markdown]
# It looks like imputing with the median helps, but scaling the features doesn't.

# %%
rf_best_cv_results = cross_validate(rf_grid_cv.best_estimator_, X_train, y_train, cv=5)
rf_best_scores = rf_best_cv_results['test_score']
rf_best_scores
# Out:
# array([0.20209809, 0.20690631, 0.20353192, 0.21237841, 0.17416444])
# time: 1h 54min 9s (started: 2021-09-12 22:41:35 -07:00)

# %% [markdown]
# <font color='red'> why is this cross-validatino repeated when it was just done above in GridSearchCV????</font>

# %%
np.mean(rf_best_scores), np.std(rf_best_scores)
# Out:
# (0.19981583471621275, 0.013304925299022585)
# time: 0 ns (started: 2021-09-13 00:35:45 -07:00)

# %% [markdown]
# You've marginally improved upon the default CV results. Random forest has many more hyperparameters you could tune, but we won't dive into that here.

# %% [markdown]
# <font color='red'>what hyperparameters did we just tune???????? n_est????????<font>

# %%
#Code task 27#
#Plot a barplot of the random forest's feature importances,
#assigning the `feature_importances_` attribute of 
#`rf_grid_cv.best_estimator_.named_steps.randomforestregressor` to the name `imps` to then
#create a pandas Series object of the feature importances, with the index given by the
#training data column names, sorting the values in descending order
plt.subplots(figsize=(10, 5))
imps = rf_grid_cv.best_estimator_.named_steps.randomforestregressor.feature_importances_
rf_feat_imps = pd.Series(imps, index=X_train.columns).sort_values(ascending=False)
rf_feat_imps.plot(kind='bar')
plt.xlabel('features')
plt.ylabel('importance')
plt.title('Best random forest regressor feature importances');
# Out:
# time: 2.73 s (started: 2021-09-13 00:35:45 -07:00)

# %%
rf_feat_imps
# Out:
# NET_RATING_cma999_diff                    0.162368
# spread_cma999_diff                        0.130247
# travel_distance_diff                      0.090997
# E_NET_RATING_cma999_diff                  0.045290
# PIE_cma999_diff                           0.035900
#                                             ...
# team_id_b_1610612755                      0.000129
# team_id_b_1610612759                      0.000116
# city_proper_metro_Area_a_San Francisco    0.000115
# team_id_a_1610612744                      0.000100
# city_proper_metro_Area_b_Philadelphia     0.000048
# Length: 100, dtype: float64
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
print(rf_feat_imps.shape[0])
rf_feat_imps[0:50]
# Out:
# 100
# NET_RATING_cma999_diff                               0.162368
# spread_cma999_diff                                   0.130247
# travel_distance_diff                                 0.090997
# E_NET_RATING_cma999_diff                             0.045290
# PIE_cma999_diff                                      0.035900
# win_pct_diff                                         0.028417
# strength_of_schedule_diff                            0.025510
# opp_win_pct_diff                                     0.022604
# fg3a_cma12_diff                                      0.012597
# pf_cma999_diff                                       0.012378
# lc_sum_NET_RATING_cmax999_diff                       0.012143
# lc_mean_EFG_PCT_cmax999_diff                         0.012088
# lc_sum_AST_PCT_cmax5_diff                            0.010334
# lc_sum_TS_PCT_cma5_diff                              0.010304
# lc_sum_TS_PCT_cma999_diff                            0.010280
# lc_max_AST_TOV_cmax999_diff                          0.009896
# E_DEF_RATING_cma12_diff                              0.009814
# away_home__cma999_diff                               0.009769
# opp_opps_win_pct_diff                                0.009759
# lc_sum_AST_RATIO_cma5_diff                           0.009749
# E_NET_RATING_cmax5_diff                              0.009743
# lc_max_AST_TOV_cmax12_diff                           0.009743
# lc_sum_POSS_cmax5_diff                               0.009723
# E_NET_RATING_cma12_diff                              0.009674
# lc_max_MIN_cma12_diff                                0.009627
# E_NET_RATING_cmax12_diff                             0.009612
# lc_mean_TS_PCT_cma5_diff                             0.009495
# ft_pct_cmax12_diff                                   0.009467
# opp_losses_diff                                      0.009121
# longitude_diff                                       0.008810
# PIE_cma5_diff                                        0.008809
# fg3_pct_cma999_diff                                  0.008802
# TS_PCT_cma999_diff                                   0.008422
# AST_RATIO_cmax5_diff                                 0.008092
# PIE_cma12_diff                                       0.008051
# EFG_PCT_cma999_diff                                  0.008038
# lc_max_POSS_cma5_diff                                0.007925
# lc_max_MIN_cmax5_diff                                0.007854
# latitude_diff                                        0.007408
# games_back_to_back_percentage_game_window999_diff    0.007377
# E_NET_RATING_cma5_diff                               0.007251
# E_OFF_RATING_cma999_diff                             0.007160
# w_pct_cma12_diff                                     0.006853
# lc_max_MIN_cma5_diff                                 0.006827
# losses_diff                                          0.006773
# OFF_RATING_cma999_diff                               0.006618
# w_pct_cmax5_diff                                     0.005808
# w_pct_cma5_diff                                      0.005558
# spread_cma12_diff                                    0.005330
# away_game_count_day_window2_diff                     0.005294
# dtype: float64
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
rf_feat_imps[50:]
# Out:
# NET_RATING_cma12_diff                               0.004512
# pf_cmax999_diff                                     0.004417
# opp_wins_diff                                       0.004014
# home_game_percent_day_window999_diff                0.004013
# future_Away_game_percent_day_window12_diff          0.003820
# future_Away_game_percent_day_window999_diff         0.003637
# away_home_a                                         0.003528
# away_game_percent_day_window999_diff                0.003493
# game_count_day_window12_diff                        0.003464
# wins_diff                                           0.003194
# future_home_game_percent_day_window999_diff         0.003121
# future_home_game_percent_day_window12_diff          0.002761
# game_count_day_window999_diff                       0.002534
# away_game_percent_day_window12_diff                 0.002440
# game_count_day_window8_diff                         0.002395
# away_game_percent_day_window8_diff                  0.002299
# games_back_to_back_percentage_game_window12_diff    0.002288
# home_game_count_day_window8_diff                    0.002198
# future_home_game_percent_day_window8_diff           0.002161
# games_back_to_back_count_game_window999_diff        0.002128
# game_date_diff_diff                                 0.002022
# home_game_percent_day_window12_diff                 0.001812
# future_home_game_count_day_window12_diff            0.001762
# home_game_percent_day_window8_diff                  0.001759
# future_Away_game_percent_day_window8_diff           0.001743
# games_back_to_back_percentage_game_window5_diff     0.001693
# future_game_count_day_window8_diff                  0.001590
# future_game_count_day_window12_diff                 0.001523
# away_game_count_day_window999_diff                  0.001516
# away_game_count_day_window12_diff                   0.001466
# game_count_day_window5_diff                         0.001439
# home_game_count_day_window999_diff                  0.001347
# future_game_count_day_window999_diff                0.001216
# future_Away_game_count_day_window8_diff             0.001114
# home_game_count_day_window12_diff                   0.001067
# games_back_to_back_count_game_window12_diff         0.000992
# team_id_b_1610612758                                0.000567
# future_game_count_day_window2_diff                  0.000527
# city_proper_metro_Area_b_Oklahoma City              0.000498
# city_proper_metro_Area_b_Sacramento                 0.000407
# team_id_b_1610612760                                0.000327
# city_proper_metro_Area_b_San Antonio                0.000317
# season_2011-12                                      0.000317
# team_id_a_1610612747                                0.000211
# team_id_a_1610612751                                0.000135
# team_id_b_1610612755                                0.000129
# team_id_b_1610612759                                0.000116
# city_proper_metro_Area_a_San Francisco              0.000115
# team_id_a_1610612744                                0.000100
# city_proper_metro_Area_b_Philadelphia               0.000048
# dtype: float64
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
#feature importance affected by collinearity


#https://www.quora.com/Does-the-random-forests-technique-suffer-if-there-is-a-multi-colinerarity-present-in-the-features-data-when-trying-to-predict-the-classification-of-the-next-datapoint-If-not-why
# Out:
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
# can reduce runtime by dropping the bottom 5% of feature importances

#https://towardsdatascience.com/improving-random-forest-in-python-part-1-893916666cd
# Out:
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
#play with max depth

#specify maximum number of features to include in each node split


#https://www.keboola.com/blog/random-forest-regression
# Out:
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %%
#Random Search Cross Validation

#https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74


#random_grid = {'n_estimators': n_estimators,
#               'max_features': max_features,
#               'max_depth': max_depth,
#               'min_samples_split': min_samples_split,
#               'min_samples_leaf': min_samples_leaf,
#               'bootstrap': bootstrap}
# Out:
# time: 0 ns (started: 2021-09-13 00:35:47 -07:00)

# %% [markdown]
# ## 4.11 Final Model Selection<a id='4.11_Final_Model_Selection'></a>

# %% [markdown]
# Time to select your final model to use for further business modeling! It would be good to revisit the above model selection; there is undoubtedly more that could be done to explore possible hyperparameters.
# It would also be worthwhile to investigate removing the least useful features. Gathering or calculating, and storing, features adds business cost and dependencies, so if features genuinely are not needed they should be removed.
# Building a simpler model with fewer features can also have the advantage of being easier to sell (and/or explain) to stakeholders.
# Certainly there seem to be four strong features here and so a model using only those would probably work well.
# However, you want to explore some different scenarios where other features vary so keep the fuller
# model for now.
# The business is waiting for this model and you have something that you have confidence in to be much better than guessing with the average price.
#
# Or, rather, you have two "somethings". You built a best linear model and a best random forest model. You need to finally choose between them. You can calculate the mean absolute error using cross-validation. Although `cross-validate` defaults to the $R^2$ [metric for scoring](https://scikit-learn.org/stable/modules/model_evaluation.html#scoring) regression, you can specify the mean absolute error as an alternative via
# the `scoring` parameter.

# %% [markdown]
# ### 4.11.1 Linear regression model performance<a id='4.11.1_Linear_regression_model_performance'></a>

# %% [markdown]
# ### 4.11.2 Random forest regression model performance<a id='4.11.2_Random_forest_regression_model_performance'></a>

# %%
rf_neg_mae = cross_validate(rf_grid_cv.best_estimator_, X_train, y_train, 
                            scoring='neg_mean_absolute_error', cv=5, n_jobs=-1)
# Out:
# time: 32min 23s (started: 2021-09-13 00:35:48 -07:00)

# %%
rf_mae_mean = np.mean(-1 * rf_neg_mae['test_score'])
rf_mae_std = np.std(-1 * rf_neg_mae['test_score'])
rf_mae_mean, rf_mae_std
# Out:
# (9.588544070822698, 0.3611405966810585)
# time: 0 ns (started: 2021-09-13 01:08:11 -07:00)

# %%
mean_absolute_error(y_test, rf_grid_cv.best_estimator_.predict(X_test))
# Out:
# 9.683213242453748
# time: 140 ms (started: 2021-09-13 01:08:11 -07:00)

# %%
MAPE(y_test, rf_grid_cv.best_estimator_.predict(X_test))
# Out:
# 112.86574956201913
# time: 62 ms (started: 2021-09-13 01:08:11 -07:00)

# %% [markdown]
# ### 4.11.3 Conclusion<a id='4.11.3_Conclusion'></a>

# %% [markdown]
# The random forest model has a cross-validation mean absolute error... It also exhibits ... variability.
#
# ???Verifying performance on the test set produces performance consistent with the cross-validation results????

# %% [markdown]
# ## 4.12 Data quantity assessment<a id='4.12_Data_quantity_assessment'></a>

# %% [markdown]
# Finally, you need to advise the business whether it needs to undertake further data collection. Would more data be useful? We're often led to believe more data is always good, but gathering data invariably has a cost associated with it. Assess this trade off by seeing how performance varies with differing data set sizes. The `learning_curve` function does this conveniently.

# %%
fractions = [.2, .25, .3, .35, .4, .45, .5, .6, .75, .8, 1.0]
train_size, train_scores, test_scores = learning_curve(RF_pipe, X_train, y_train, train_sizes=fractions)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)
# Out:
# time: 4h 4min 54s (started: 2021-09-13 01:08:11 -07:00)

# %%
plt.subplots(figsize=(10, 5))
plt.errorbar(train_size, test_scores_mean, yerr=test_scores_std)
plt.xlabel('Training set size')
plt.ylabel('CV scores')
plt.title('Cross-validation score as training set size increases');
# Out:
# time: 93 ms (started: 2021-09-13 05:13:06 -07:00)

# %% [markdown]
# This shows that you seem to have plenty of data. There's an initial rapid improvement in model scores as one would expect, but it's essentially levelled off by around a sample size of 40-50.

# %% [markdown]
# ## 4.13 Save best model object from pipeline<a id='4.13_Save_best_model_object_from_pipeline'></a>

# %%
#This may not be "production grade ML deployment" practice, but adding some basic
#information to your saved models can save your bacon in development.
#Just what version model have you just loaded to reuse? What version of `sklearn`
#created it? When did you make it?
#Assign the pandas version number (`pd.__version__`) to the `pandas_version` attribute,
#the numpy version (`np.__version__`) to the `numpy_version` attribute,
#the sklearn version (`sklearn_version`) to the `sklearn_version` attribute,
#and the current datetime (`datetime.datetime.now()`) to the `build_datetime` attribute
#Let's call this model version '1.0'
best_model = rf_grid_cv.best_estimator_
best_model.version = '1.0'
best_model.pandas_version = pd.__version__
best_model.numpy_version = np.__version__
best_model.sklearn_version = sklearn_version
best_model.X_columns = [col for col in X_train.columns]
best_model.build_datetime = datetime.datetime.now()
    
modelpath = os.path.join('..', 'models')
if not os.path.exists(modelpath):
    os.mkdir(modelpath)
nbamodel_path = os.path.join(modelpath, '173C_model_trial_1.pkl')
if not os.path.exists(nbamodel_path):
    with open(nbamodel_path, 'wb') as f:
        pickle.dump(best_model, f)
# Out:
# time: 15 ms (started: 2021-09-13 05:13:06 -07:00)

# %% [markdown]
# ## 4.14 Summary<a id='4.14_Summary'></a>

# %% [markdown]
# **Q: 1** Write a summary of the work in this notebook. Capture the fact that you gained a baseline idea of performance by simply taking the average price and how well that did. Then highlight that you built a linear model and the features that found. Comment on the estimate of its performance from cross-validation and whether its performance on the test split was consistent with this estimate. Also highlight that a random forest regressor was tried, what preprocessing steps were found to be best, and again what its estimated performance via cross-validation was and whether its performance on the test set was consistent with that. State which model you have decided to use going forwards and why. This summary should provide a quick overview for someone wanting to know quickly why the given model was chosen for the next part of the business problem to help guide important business decisions.

# %% [markdown]
# Capture the fact that you gained a baseline idea of performance by simply taking the average price and how well that did.
# -Average price yielded an R^2, explained variance, of 0 and a mean absolute error of 18 and 19 on the training (i.e. y_train) and testing (i.e. y_train) sets respectively when compared to their predicted average 'AdultWeekend' ticket price (i.e. y_tr_pred).
#
# Then highlight that you built a linear model and the features that found.
# -In building a linear model, features found (using GridSearchCV) included vertical_drop, Snow Making_ac, total_chairs, fastQuads, Runs, LongestRun_mi, trams, SkiableTerrain_ac. In selecting eight (8) features (i.e. hyperparameter k=8) in linear regression to predict 'AdultWeekend' ticket price (i.e. y_train and y_test), the cross validation average test score of R^2 (i.e. explained variance) performance reached a maximum.
#
#
# Comment on the estimate of its performance from cross-validation and whether its performance on the test split was consistent with this estimate.
# -Cross-validation (with number of folds k=5) performance using linear regression model with 15 features (i.e. pipe15) showed an average R^2 score of .6349 and average std of .095. Using the pipe15 model, mean explained variance R^2 of cross-validation is close to the test split R^2 score .6347.
#
#
# Also highlight that a random forest regressor was tried, what preprocessing steps were found to be best, and again what its estimated performance via cross-validation was and whether its performance on the test set was consistent with that.
# -Preprocessing steps that were found to be best included ?using n_est=69,? omitting the use of feature scaling, and using median instead of mean for feature imputing.
# -The estimated performance of random forest regressor via cross-validation was a mean absolute error of 9.754 and standard deviation of 1.353.
# -This performance was consistent with performance of the test set where mean absolute error was 9.342 using y_test and X_test.
#
# State which model you have decided to use going forwards and why.
# We have decided to go forwards with the random forest regression model because it yields the lower MAE (mean absolute error) between linear regression at 10.448 and random forest regression at 9.754, each by cross validation.
