# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sqlite3

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.set_option('max_colwidth', None)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
def replace_player(df_):
    df_.player.replace({'J.J. Redick':'JJ Redick'}, inplace=True)
    
    df_.player.replace({'A.J. Price': 'AJ Price'}, inplace=True)
    
    df_.player.replace({'Alex Ajinca':'Alexis Ajinca'}, inplace=True)
    
    df_.player.replace({'C.J. Miles': 'CJ Miles'}, inplace=True)
    
    df_.player.replace({'D.J. White': 'DJ White'}, inplace=True)
    
    df_.player.replace({"Hamady N'Diaye" : 'Hamady Ndiaye'}, inplace=True)
    
    df_.player.replace({'J.J. Hickson': 'JJ Hickson'}, inplace=True)
    
    df_.player.replace({'John Wallace' : 'John Wall'}, inplace=True)
    
    df_.player.replace({'Jose Barea' : 'J.J. Barea'}, inplace=True)
    
    df_.player.replace({'Wes Johnson':'Wesley Johnson'}, inplace=True)
    
    df_.player.replace({'B.J. Mullens':'Byron Mullens'}, inplace=True)
    
    df_.player.replace({'Bill Walker':'Henry Walker'}, inplace=True)
    
    df_.player.replace({'Gerald Henderson Jr.':'Gerald Henderson'}, inplace=True)
    
    df_.player.replace({'Jianlian Yi':'Yi Jianlian'}, inplace=True)
    
    df_.player.replace({'Mike Conley Jr.':'Mike Conley'}, inplace=True)
    
    df_.player.replace({'Mike Dunleavy Jr.':'Mike Dunleavy'}, inplace=True)
    
    df_.player.replace({'Nene Hilario': 'Nene'}, inplace=True)
    
    df_.player.replace({'Didier Mbenga':'DJ Mbenga'}, inplace=True)
    
    df_.player.replace({'A.J. Hammons':'AJ Hammons'}, inplace=True)
    
    df_.player.replace({'C.J. McCollum':'CJ McCollum'}, inplace=True)
    
    df_.player.replace({'D.J. Augustine':'D.J. Augustin'}, inplace=True)
    
    df_.player.replace({'DeAndre Bembry':"DeAndre' Bembry"}, inplace=True)
    
    df_.player.replace({'Giorgios Papagiannis':'Georgios Papagiannis'}, inplace=True)
    
    df_.player.replace({'Glen Rice Jr.':'Glen Rice'}, inplace=True)
    
    df_.player.replace({'J.R. Smith':'JR Smith'}, inplace=True)
    
    df_.player.replace({'James Ennis':'James Ennis III'}, inplace=True)
    
    df_.player.replace({'John Collins  John Collins':'John Collins'}, inplace=True)
    
    df_.player.replace({'Juan Hernangomez':'Juancho Hernangomez'}, inplace=True)
    
    df_.player.replace({'Billy Ouattara':'Yakuba Ouattara'}, inplace=True)
    
    df_.player.replace({'Courtney Simpson':'Diamon Simpson'}, inplace=True)
    
    df_.player.replace({'Danuel House':'Danuel House Jr.'}, inplace=True)
    
    df_.player.replace({'Domas Sabonis':'Domantas Sabonis'}, inplace=True)
    
    df_.player.replace({'Jake Wiley':'Jacob Wiley'}, inplace=True)
    
    df_.player.replace({'James McAdoo':'James Michael McAdoo'}, inplace=True)
    
    df_.player.replace({'Jeff Pendergraph':'Jeff Ayres'}, inplace=True)
    
    df_.player.replace({'Jeff Taylor':'Jeffery Taylor'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'Malcom Lee':'Malcolm Lee'}, inplace=True)
    
    df_.player.replace({'Marcus Morris':'Marcus Morris Sr.'}, inplace=True)
    
    df_.player.replace({'Matt Williams':'Matt Williams Jr.'}, inplace=True)
    
    df_.player.replace({"Maurice N'dour":'Maurice Ndour'}, inplace=True)
    
    df_.player.replace({'Milos Tedosic':'Milos Teodosic'}, inplace=True)
    
    df_.player.replace({'Moe Harkless':'Maurice Harkless'}, inplace=True)
    
    df_.player.replace({'O.G. Anunoby':'OG Anunoby'}, inplace=True)
    
    df_.player.replace({'Ognen Kuzmic':'Ognjen Kuzmic'}, inplace=True)
    
    df_.player.replace({'P.J. Dozier':'PJ Dozier'}, inplace=True)
    
    df_.player.replace({'P.J. Hairston':'PJ Hairston'}, inplace=True)
    
    df_.player.replace({'Qi Zhou':'Zhou Qi'}, inplace=True)
    
    df_.player.replace({'R.J. Hunter':'RJ Hunter'}, inplace=True)
    
    df_.player.replace({'Ray McCallum Jr.':'Ray McCallum'}, inplace=True)
    
    df_.player.replace({'Ron Artest':'Metta World Peace'}, inplace=True)
    
    df_.player.replace({'Roy Marble':'Devyn Marble'}, inplace=True)
    
    df_.player.replace({'Stephen Zimmerman Jr.':'Stephen Zimmerman'}, inplace=True)
    
    df_.player.replace({'Tony Wroten Jr.':'Tony Wroten'}, inplace=True)
    
    df_.player.replace({'Toure Murry':"Toure' Murry"}, inplace=True)
    
    df_.player.replace({'Viacheslav Kravstov':'Viacheslav Kravtsov'}, inplace=True)
    
    df_.player.replace({'Vince Hunter':'Vincent Hunter'}, inplace=True)
    
    df_.player.replace({'Walker Russell Jr.':'Walker Russell'}, inplace=True)
    
    df_.player.replace({'Wayne Selden Jr.':'Wayne Selden'}, inplace=True)
    
    df_.player.replace({'Wes Matthews Jr.':'Wesley Matthews'}, inplace=True)
    
    return df_

#names dropped from Injury Report dataframe df_inj1018 for the following reasons:
#a. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons.
#b. player did not play an nba regular season or playoff game between the 2009-10 and 2017-18 seasons.
#c. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons. Player plays in nba games
#   following the 2017-18 season.
#d. this is the injury of a coach, not a player. coaches do not have boxscore advanced stats


def drop_player(df_):
    df_.drop(df_[df_.player.str.contains('Marion Hillard')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Matt Janning')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains("Da'Sean Butler")].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Eric Griffin')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Harry Giles')].index, inplace = True) #c
    
    df_.drop(df_[df_.player.str.contains('Magnum Rolle')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Robert Vaden')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Steve Clifford')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Steve Kerr')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Terrico White')].index, inplace = True)#a
    
    df_.drop(df_[df_.player.str.contains('Tyronn Lue')].index, inplace = True) #d
    
    return df_

def df_inj1020_fix_Date_Team(df_):
    df_.loc[5923, ['Team']] = 'Pacers'
    return df_

def manual_not_the_actual_game_date_drop(df_):
    df_.drop(21307, inplace=True) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_.reset_index(drop=True, inplace=True)
    return df_

'''def manual_not_the_game_date_drop2(df_):
    df_ = df_.drop(14084) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_ = df_.reset_index(drop=True)
    return df_'''


def get_5bsa1018_inj1018_player_diff():
    print(len(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME)))
    print(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME))
    print()
    
    print(len(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player)))
    print(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player))
    return 0
    
    
#get injury data for player
def gi(player_):
    return df_inj1018[df_inj1018.player.str.contains(player_)] 

#get boxscore advance for player
def gb(player_):
    return df_5bsa1018[df_5bsa1018.PLAYER_NAME.str.contains(player_)]

#get inactive player game-by-game
def gia(player_):
    return df_ina1018[df_ina1018.player.str.contains(player_)]

#return the first 5 and last 5 rows of this dataframe
def p(df_):
    return pd.concat([df_.head(), df_.tail()])

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
#get injury report for 2010-11 thru 2017-18 sesasons: df_inj1018

#last game_date of 2017-18 season
path = os.path.join('..', 'processed_data', '7season_first_game_date_last_game_date.csv')
df_7sfgdlgd = pd.read_csv(path, parse_dates=['first', 'last'])
last_game_date_s1718 = df_7sfgdlgd.iloc[8]['last']
last_game_date_s1718
# Out:
# Timestamp('2018-06-08 00:00:00')

# %%
#read in raw injury report
path = os.path.join('..', 'raw_data', 'injuries_2010-2020.csv')
df_inj1020 = pd.read_csv(path, parse_dates=['Date'])
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 5)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls           NaN  Carlos Boozer
# 1     2010-10-06  Pistons           NaN  Jonas Jerebko
# 2     2010-10-06  Pistons           NaN  Terrico White
# 3     2010-10-08  Blazers           NaN     Jeff Ayres
# 4     2010-10-08     Nets           NaN    Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters            NaN
# 27101 2020-10-02     Heat           NaN    Bam Adebayo
# 27102 2020-10-02     Heat           NaN   Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva            NaN
# 27104 2020-10-06     Heat   Bam Adebayo            NaN
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#preprocess player & Date
df_inj1020.Acquired.fillna('', inplace=True)
df_inj1020.Relinquished.fillna('', inplace=True)
df_inj1020['player'] = df_inj1020.Relinquished + ' ' + df_inj1020.Acquired
df_inj1020.player = df_inj1020.player.str.strip()
df_inj1020 = df_inj1020_fix_Date_Team(df_inj1020)
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 6)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls                Carlos Boozer
# 1     2010-10-06  Pistons                Jonas Jerebko
# 2     2010-10-06  Pistons                Terrico White
# 3     2010-10-08  Blazers                   Jeff Ayres
# 4     2010-10-08     Nets                  Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters
# 27101 2020-10-02     Heat                  Bam Adebayo
# 27102 2020-10-02     Heat                 Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva
# 27104 2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes         player
# 0       fractured bone in right pinky finger (out indefinitely)  Carlos Boozer
# 1                 torn right Achilles tendon (out indefinitely)  Jonas Jerebko
# 2      broken fifth metatarsal in right foot (out indefinitely)  Terrico White
# ...

# %%
#bound last game date and make new dateframe: df_inj1018
df_inj1018 = df_inj1020.loc[df_inj1020['Date'] <= last_game_date_s1718]
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22257, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 2     2010-10-06    Pistons                  Terrico White
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                           Notes  \
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#fix player (name)
df_inj1018 = replace_player(df_inj1018)
df_inj1018 = drop_player(df_inj1018)
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22232, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# ...

# %%
#filter Date to game_date
df_3gdgiti0618 = pd.read_csv(os.path.join('..', 'processed_data', '3game_id_game_date_team_id.csv'), parse_dates=['game_date'])
df_3gds0618 = df_3gdgiti0618[['game_date', 'season']].drop_duplicates()
df_3gds0618 = df_3gds0618.drop_duplicates()
df_inj1018 = pd.merge(df_3gds0618.drop_duplicates(), df_inj1018.rename(columns={'Date':'game_date'}), on='game_date', how='inner')

manual_not_the_actual_game_date_drop(df_inj1018) #inplace=True
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (21920, 7)
#        game_date   season       Team        Acquired      Relinquished  \
# 0     2010-10-26  2010-11    Blazers                   Elliot Williams
# 1     2010-10-26  2010-11    Blazers                         Greg Oden
# 2     2010-10-26  2010-11    Blazers                    Joel Przybilla
# 3     2010-10-26  2010-11    Celtics                     Avery Bradley
# 4     2010-10-26  2010-11    Celtics                  Kendrick Perkins
# 21915 2018-05-22  2017-18   Warriors                    Andre Iguodala
# 21916 2018-05-26  2017-18  Cavaliers                        Kevin Love
# 21917 2018-05-26  2017-18   Warriors   Patrick McCaw
# 21918 2018-05-31  2017-18  Cavaliers      Kevin Love
# 21919 2018-06-06  2017-18   Warriors  Andre Iguodala
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# ...

# %%
df_inj1018[(df_inj1018.game_date == '2013-05-10') & (df_inj1018.player == 'Eric Gordon')]
# Out:
# Empty DataFrame
# Columns: [game_date, season, Team, Acquired, Relinquished, Notes, player]
# Index: []

# %%
df_inj1018[(df_inj1018.game_date == '2013-05-10') & (df_inj1018.player == 'Eric Gordon')]
# Out:
# Empty DataFrame
# Columns: [game_date, season, Team, Acquired, Relinquished, Notes, player]
# Index: []

# %%
datapath = os.path.join('..', 'processed_data')

if not os.path.exists(datapath):
    os.mkdir(datapath)

datapath_df = os.path.join(datapath, '9injury_game_date_team_acquired_relinquished_player_2010_2018.csv')
if not os.path.exists(datapath_df):
    df_inj1018.to_csv(datapath_df, index=False)

# %%
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (21920, 7)
#        game_date   season       Team        Acquired      Relinquished  \
# 0     2010-10-26  2010-11    Blazers                   Elliot Williams
# 1     2010-10-26  2010-11    Blazers                         Greg Oden
# 2     2010-10-26  2010-11    Blazers                    Joel Przybilla
# 3     2010-10-26  2010-11    Celtics                     Avery Bradley
# 4     2010-10-26  2010-11    Celtics                  Kendrick Perkins
# 21915 2018-05-22  2017-18   Warriors                    Andre Iguodala
# 21916 2018-05-26  2017-18  Cavaliers                        Kevin Love
# 21917 2018-05-26  2017-18   Warriors   Patrick McCaw
# 21918 2018-05-31  2017-18  Cavaliers      Kevin Love
# 21919 2018-06-06  2017-18   Warriors  Andre Iguodala
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# ...

# %%
#get Relinquished player's and drop 'Acquired' column
df_inj1018r = df_inj1018[df_inj1018.Relinquished != ''].drop(columns=['Acquired']).reset_index(drop=True)
print(df_inj1018r.shape)
p(df_inj1018r)
# Out:
# (14448, 6)
#        game_date   season       Team      Relinquished  \
# 0     2010-10-26  2010-11    Blazers   Elliot Williams
# 1     2010-10-26  2010-11    Blazers         Greg Oden
# 2     2010-10-26  2010-11    Blazers    Joel Przybilla
# 3     2010-10-26  2010-11    Celtics     Avery Bradley
# 4     2010-10-26  2010-11    Celtics  Kendrick Perkins
# 14443 2018-05-09  2017-18    Thunder       Paul George
# 14444 2018-05-08  2017-18       Jazz        Dante Exum
# 14445 2018-05-25  2017-18    Rockets        Chris Paul
# 14446 2018-05-22  2017-18   Warriors    Andre Iguodala
# 14447 2018-05-26  2017-18  Cavaliers        Kevin Love
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...

# %%
df_bsa1018 =  pd.read_csv(os.path.join('..', 'processed_data', '5boxscoreadvancedv2_2009_2018.csv'))
print(df_bsa1018.shape)
p(df_bsa1018)
# Out:
# (291643, 31)
#          GAME_ID       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0       20900001  1.610613e+09               BOS     Boston     1718.0
# 1       20900001  1.610613e+09               BOS     Boston      708.0
# 2       20900001  1.610613e+09               BOS     Boston     2570.0
# 3       20900001  1.610613e+09               BOS     Boston      951.0
# 4       20900001  1.610613e+09               BOS     Boston   200765.0
# 291638  41700404  1.610613e+09               CLE  Cleveland  1626204.0
# 291639  41700404  1.610613e+09               CLE  Cleveland  1626224.0
# 291640  41700404  1.610613e+09               CLE  Cleveland   101181.0
# 291641  41700404  1.610613e+09               CLE  Cleveland  1627790.0
# 291642  41700404  1.610613e+09               CLE  Cleveland   203903.0
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# 0            Paul Pierce              F                     NaN  37:59
# ...

# %%
df_right = pd.read_csv(os.path.join('..', 'processed_data', '3game_id_game_date_team_id.csv'), parse_dates=['game_date'])[['game_id', 'game_date']]
df_right
# Out:
#         game_id  game_date
# 0      20600001 2006-10-31
# 1      20600001 2006-10-31
# 2      20600002 2006-10-31
# 3      20600002 2006-10-31
# 4      20600003 2006-11-01
# ...         ...        ...
# 31033  41700402 2018-06-03
# 31034  41700403 2018-06-06
# 31035  41700403 2018-06-06
# 31036  41700404 2018-06-08
# 31037  41700404 2018-06-08
#
# [31038 rows x 2 columns]

# %%
df_bsa1018 = pd.merge(df_bsa1018.rename(columns={'GAME_ID':'game_id'}), df_right, on='game_id', how='inner')
df_bsa1018
# Out:
#          game_id       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0       20900001  1.610613e+09               BOS     Boston     1718.0
# 1       20900001  1.610613e+09               BOS     Boston     1718.0
# 2       20900001  1.610613e+09               BOS     Boston      708.0
# 3       20900001  1.610613e+09               BOS     Boston      708.0
# 4       20900001  1.610613e+09               BOS     Boston     2570.0
# ...          ...           ...               ...        ...        ...
# 583281  41700404  1.610613e+09               CLE  Cleveland   101181.0
# 583282  41700404  1.610613e+09               CLE  Cleveland  1627790.0
# 583283  41700404  1.610613e+09               CLE  Cleveland  1627790.0
# 583284  41700404  1.610613e+09               CLE  Cleveland   203903.0
# 583285  41700404  1.610613e+09               CLE  Cleveland   203903.0
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# ...

# %%
df_inj1018
# Out:
#        game_date   season       Team        Acquired      Relinquished  \
# 0     2010-10-26  2010-11    Blazers                   Elliot Williams
# 1     2010-10-26  2010-11    Blazers                         Greg Oden
# 2     2010-10-26  2010-11    Blazers                    Joel Przybilla
# 3     2010-10-26  2010-11    Celtics                     Avery Bradley
# 4     2010-10-26  2010-11    Celtics                  Kendrick Perkins
# ...          ...      ...        ...             ...               ...
# 21915 2018-05-22  2017-18   Warriors                    Andre Iguodala
# 21916 2018-05-26  2017-18  Cavaliers                        Kevin Love
# 21917 2018-05-26  2017-18   Warriors   Patrick McCaw
# 21918 2018-05-31  2017-18  Cavaliers      Kevin Love
# 21919 2018-06-06  2017-18   Warriors  Andre Iguodala
#
#                                                                                                    Notes  \
# ...

# %%
df_inj1018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21920 entries, 0 to 21919
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_date     21920 non-null  datetime64[ns]
#  1   season        21920 non-null  object
#  2   Team          21920 non-null  object
#  3   Acquired      21920 non-null  object
#  4   Relinquished  21920 non-null  object
#  5   Notes         21920 non-null  object
#  6   player        21920 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1.2+ MB

# %%
df_bsa1018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583286 entries, 0 to 583285
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   game_id            583286 non-null  int64
#  1   TEAM_ID            583284 non-null  float64
#  2   TEAM_ABBREVIATION  583284 non-null  object
#  3   TEAM_CITY          583284 non-null  object
#  4   PLAYER_ID          583284 non-null  float64
#  5   PLAYER_NAME        583284 non-null  object
#  6   START_POSITION     231560 non-null  object
#  7   COMMENT            99022 non-null   object
#  8   MIN                484288 non-null  object
#  9   E_OFF_RATING       484288 non-null  float64
#  10  OFF_RATING         583284 non-null  float64
#  11  E_DEF_RATING       484288 non-null  float64
#  12  DEF_RATING         583284 non-null  float64
#  13  E_NET_RATING       484288 non-null  float64
#  14  NET_RATING         583284 non-null  float64
# ...

# %%
pd.merge(df_bsa1018.rename(columns={'PLAYER_NAME':'player'}), df_inj1018, on=['game_date', 'player'])
# Out:
#         game_id       TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0      21000001  1.610613e+09               MIA         Miami   201596.0
# 1      21000001  1.610613e+09               MIA         Miami   201596.0
# 2      21000006  1.610613e+09               MIA         Miami      711.0
# 3      21000006  1.610613e+09               MIA         Miami      711.0
# 4      21000010  1.610613e+09               MIL     Milwaukee   201972.0
# ...         ...           ...               ...           ...        ...
# 27767  41700316  1.610613e+09               GSW  Golden State  1627775.0
# 27768  41700401  1.610613e+09               CLE     Cleveland   201567.0
# 27769  41700401  1.610613e+09               CLE     Cleveland   201567.0
# 27770  41700403  1.610613e+09               GSW  Golden State     2738.0
# 27771  41700403  1.610613e+09               GSW  Golden State     2738.0
#
#                  player START_POSITION                  COMMENT    MIN  \
# ...

# %%
df_merged = pd.merge(df_bsa1018.rename(columns={'PLAYER_NAME':'player'}), df_inj1018r, on=['game_date', 'player'], how='inner')
df_merged
# Out:
#         game_id       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0      21000001  1.610613e+09               MIA      Miami   201596.0
# 1      21000001  1.610613e+09               MIA      Miami   201596.0
# 2      21000010  1.610613e+09               MIL  Milwaukee   201972.0
# 3      21000010  1.610613e+09               MIL  Milwaukee   201972.0
# 4      21000010  1.610613e+09               MIL  Milwaukee   201601.0
# ...         ...           ...               ...        ...        ...
# 13331  41700144  1.610613e+09               MIN  Minnesota  1626145.0
# 13332  41700211  1.610613e+09               BOS     Boston  1627759.0
# 13333  41700211  1.610613e+09               BOS     Boston  1627759.0
# 13334  41700215  1.610613e+09               BOS     Boston   203499.0
# 13335  41700215  1.610613e+09               BOS     Boston   203499.0
#
#                  player START_POSITION                   COMMENT  MIN  \
# ...

# %%
df_merged.MIN.fillna('00:00')
# Out:
# 0        00:00
# 1        00:00
# 2        00:00
# 3        00:00
# 4        00:00
#          ...
# 13331    00:00
# 13332    00:00
# 13333    00:00
# 13334    00:00
# 13335    00:00
# Name: MIN, Length: 13336, dtype: object

# %%
df_merged.MIN = df_merged.MIN.fillna('00:00')

# %%
df_merged.MIN = pd.to_timedelta('00:' + df_merged.MIN).astype('timedelta64[s]').astype('float64') / 60
df_merged
# Out:
#         game_id       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0      21000001  1.610613e+09               MIA      Miami   201596.0
# 1      21000001  1.610613e+09               MIA      Miami   201596.0
# 2      21000010  1.610613e+09               MIL  Milwaukee   201972.0
# 3      21000010  1.610613e+09               MIL  Milwaukee   201972.0
# 4      21000010  1.610613e+09               MIL  Milwaukee   201601.0
# ...         ...           ...               ...        ...        ...
# 13331  41700144  1.610613e+09               MIN  Minnesota  1626145.0
# 13332  41700211  1.610613e+09               BOS     Boston  1627759.0
# 13333  41700211  1.610613e+09               BOS     Boston  1627759.0
# 13334  41700215  1.610613e+09               BOS     Boston   203499.0
# 13335  41700215  1.610613e+09               BOS     Boston   203499.0
#
#                  player START_POSITION                   COMMENT  MIN  \
# ...

# %%
df_merged = df_merged[df_merged.MIN != 0].drop_duplicates().reset_index(drop=True)
df_merged
# Out:
#       game_id       TEAM_ID TEAM_ABBREVIATION      TEAM_CITY  PLAYER_ID  \
# 0    21000212  1.610613e+09               BOS         Boston     2753.0
# 1    21000224  1.610613e+09               TOR        Toronto     2501.0
# 2    21000342  1.610613e+09               IND        Indiana     1902.0
# 3    21000342  1.610613e+09               ATL        Atlanta     2585.0
# 4    21000345  1.610613e+09               CHI        Chicago      703.0
# 5    21000370  1.610613e+09               CHI        Chicago   201149.0
# 6    21000578  1.610613e+09               TOR        Toronto     2571.0
# 7    21000580  1.610613e+09               NYK       New York   101142.0
# 8    21000581  1.610613e+09               SAS    San Antonio     2588.0
# 9    21000629  1.610613e+09               DET        Detroit   101111.0
# 10   21000630  1.610613e+09               TOR        Toronto   201595.0
# 11   21000632  1.610613e+09               BOS         Boston      406.0
# ...

# %%
df_merged[['game_date', 'player']]
# Out:
#      game_date               player
# 0   2010-11-24         Delonte West
# 1   2010-11-26         Reggie Evans
# 2   2010-12-11          Jeff Foster
# 3   2010-12-11        Zaza Pachulia
# 4   2010-12-11          Kurt Thomas
# 5   2010-12-15          Joakim Noah
# 6   2011-01-14      Leandro Barbosa
# 7   2011-01-14         Ronny Turiaf
# 8   2011-01-14          Matt Bonner
# 9   2011-01-21   Charlie Villanueva
# 10  2011-01-21          Joey Dorsey
# 11  2011-01-21     Shaquille O'Neal
# 12  2011-01-21         Kirk Hinrich
# 13  2011-01-22          George Hill
# 14  2011-01-22         Trevor Ariza
# 15  2011-01-28          Mehmet Okur
# 16  2011-02-04      Michael Beasley
# 17  2011-02-05     Dante Cunningham
# 18  2011-02-06      Marquis Daniels
# 19  2011-02-27       Antawn Jamison
# 20  2011-03-21           Tim Duncan
# 21  2011-03-23     Andrei Kirilenko
# 22  2011-04-03        Ryan Anderson
# 23  2011-04-12         Andrew Bynum
# 24  2011-12-25        Iman Shumpert
# ...

# %%
datapath = os.path.join('..', 'processed_data')

if not os.path.exists(datapath):
    os.mkdir(datapath)

datapath_df = os.path.join(datapath, '9inj_bsa_nzm_209.csv')
if not os.path.exists(datapath_df):
    df_merged.to_csv(datapath_df, index=False)

# %%
df_tist1018 = pd.read_csv(os.path.join('..', 'processed_data', '10team_id_season_team_2010_2018.csv'))
df_tist1018
# Out:
#         TEAM_ID   season          Team
# 0    1610612748  2010-11          Heat
# 1    1610612749  2010-11         Bucks
# 2    1610612765  2010-11       Pistons
# 3    1610612753  2010-11         Magic
# 4    1610612737  2010-11         Hawks
# 5    1610612743  2010-11       Nuggets
# 6    1610612762  2010-11          Jazz
# 7    1610612744  2010-11      Warriors
# 8    1610612757  2010-11       Blazers
# 9    1610612764  2010-11       Wizards
# 10   1610612746  2010-11      Clippers
# 11   1610612750  2010-11  Timberwolves
# 12   1610612738  2010-11       Celtics
# 13   1610612761  2010-11       Raptors
# 14   1610612745  2010-11       Rockets
# 15   1610612752  2010-11        Knicks
# 16   1610612756  2010-11          Suns
# 17   1610612740  2010-11       Hornets
# 18   1610612741  2010-11         Bulls
# 19   1610612747  2010-11        Lakers
# 20   1610612760  2010-11       Thunder
# 21   1610612754  2010-11        Pacers
# 22   1610612739  2010-11     Cavaliers
# ...

# %%
df_inj1018r = pd.merge(df_inj1018r, df_tist1018, on=['Team', 'season'], how='outer', indicator=True)
print(df_inj1018r.shape)
p(df_inj1018r)
# Out:
# (14448, 8)
#        game_date   season     Team     Relinquished  \
# 0     2010-10-26  2010-11  Blazers  Elliot Williams
# 1     2010-10-26  2010-11  Blazers        Greg Oden
# 2     2010-10-26  2010-11  Blazers   Joel Przybilla
# 3     2010-11-02  2010-11  Blazers      Patty Mills
# 4     2010-11-04  2010-11  Blazers  Elliot Williams
# 14443 2018-03-13  2017-18  Thunder     Steven Adams
# 14444 2018-03-16  2017-18  Thunder  Daniel Hamilton
# 14445 2018-04-10  2017-18  Thunder     Alex Abrines
# 14446 2018-04-11  2017-18  Thunder     Alex Abrines
# 14447 2018-05-09  2017-18  Thunder      Paul George
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...

# %%
df_inj1018r.value_counts('_merge')
# Out:
# _merge
# both          14448
# right_only        0
# left_only         0
# dtype: int64

# %%
df_inj1018r.drop(columns=['_merge'], inplace=True)
print(df_inj1018r.shape)
p(df_inj1018r)
# Out:
# (14448, 7)
#        game_date   season     Team     Relinquished  \
# 0     2010-10-26  2010-11  Blazers  Elliot Williams
# 1     2010-10-26  2010-11  Blazers        Greg Oden
# 2     2010-10-26  2010-11  Blazers   Joel Przybilla
# 3     2010-11-02  2010-11  Blazers      Patty Mills
# 4     2010-11-04  2010-11  Blazers  Elliot Williams
# 14443 2018-03-13  2017-18  Thunder     Steven Adams
# 14444 2018-03-16  2017-18  Thunder  Daniel Hamilton
# 14445 2018-04-10  2017-18  Thunder     Alex Abrines
# 14446 2018-04-11  2017-18  Thunder     Alex Abrines
# 14447 2018-05-09  2017-18  Thunder      Paul George
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...

# %%
#add player_id

df_piptist1018 = pd.read_csv(os.path.join('..', 'processed_data', '14player_id_player_team_id_season_team_2010_2018.csv'))
print(df_piptist1018.shape)
p(df_piptist1018)
# Out:
# (3763, 5)
#       PLAYER_ID       PLAYER_NAME     team_id   season     Team
# 0      201623.0       Semih Erden  1610612738  2010-11  Celtics
# 1      101144.0         Von Wafer  1610612738  2010-11  Celtics
# 2        2753.0      Delonte West  1610612738  2010-11  Celtics
# 3      202376.0    Luke Harangody  1610612738  2010-11  Celtics
# 4         406.0  Shaquille O'Neal  1610612738  2010-11  Celtics
# 3758   202695.0     Kawhi Leonard  1610612759  2017-18    Spurs
# 3759     2200.0         Pau Gasol  1610612759  2017-18    Spurs
# 3760  1626199.0   Darrun Hilliard  1610612759  2017-18    Spurs
# 3761  1627749.0   Dejounte Murray  1610612759  2017-18    Spurs
# 3762  1627854.0       Bryn Forbes  1610612759  2017-18    Spurs

# %%
df_injury_piptist1018 = pd.merge(df_inj1018r.rename(columns={'TEAM_ID':'team_id'}), df_piptist1018.rename(columns={'PLAYER_NAME':'player'}), on=['player', 'Team', 'team_id', 'season'])
print(df_injury_piptist1018.shape)
p(df_injury_piptist1018)
# Out:
# (13667, 8)
#        game_date   season     Team       Relinquished  \
# 0     2010-10-26  2010-11  Blazers    Elliot Williams
# 1     2010-11-04  2010-11  Blazers    Elliot Williams
# 2     2010-11-06  2010-11  Blazers    Elliot Williams
# 3     2010-10-26  2010-11  Blazers          Greg Oden
# 4     2010-11-19  2010-11  Blazers          Greg Oden
# 13662 2018-01-03  2017-18  Thunder       Alex Abrines
# 13663 2018-04-10  2017-18  Thunder       Alex Abrines
# 13664 2018-04-11  2017-18  Thunder       Alex Abrines
# 13665 2018-03-09  2017-18  Thunder  Terrance Ferguson
# 13666 2018-03-10  2017-18  Thunder  Terrance Ferguson
#
#                                                                               Notes  \
# 0                                                                      placed on IL
# 1                        dislocated patella in right knee (surgery, out for season)
# 2      placed on IL with dislocated patella in right knee (surgery, out for season)
# ...

# %%
#filter game_date with team_id
df_gdtigi0618 = pd.read_csv(os.path.join('..', 'processed_data', '3game_id_game_date_team_id.csv'), parse_dates=['game_date'])[['game_date', 'team_id', 'game_id']]
print(df_gdtigi0618.shape)
p(df_gdtigi0618)
# Out:
# (31038, 3)
#        game_date     team_id   game_id
# 0     2006-10-31  1610612748  20600001
# 1     2006-10-31  1610612741  20600001
# 2     2006-10-31  1610612747  20600002
# 3     2006-10-31  1610612756  20600002
# 4     2006-11-01  1610612755  20600003
# 31033 2018-06-03  1610612744  41700402
# 31034 2018-06-06  1610612744  41700403
# 31035 2018-06-06  1610612739  41700403
# 31036 2018-06-08  1610612739  41700404
# 31037 2018-06-08  1610612744  41700404

# %%
df_gdtigi0618.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31038 entries, 0 to 31037
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   game_date  31038 non-null  datetime64[ns]
#  1   team_id    31038 non-null  int64
#  2   game_id    31038 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 727.6 KB

# %%
df_injury_piptist1018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13667 entries, 0 to 13666
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_date     13667 non-null  datetime64[ns]
#  1   season        13667 non-null  object
#  2   Team          13667 non-null  object
#  3   Relinquished  13667 non-null  object
#  4   Notes         13667 non-null  object
#  5   player        13667 non-null  object
#  6   team_id       13667 non-null  int64
#  7   PLAYER_ID     13667 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 961.0+ KB

# %%
df_inj_gitipi1018 = pd.merge(df_injury_piptist1018, df_gdtigi0618, on=['game_date', 'team_id'], how='inner', indicator=True)
#df_inj_gitipi1018 = df_inj_gitipi1018[['game_date', 'game_id', 'Team', 'team_id',  'season', 'player','PLAYER_ID', 'Relinquished', 'Notes']]#rearrange and drop columns
print(df_inj_gitipi1018.shape)
p(df_inj_gitipi1018)
# Out:
# (13034, 10)
#        game_date   season     Team       Relinquished  \
# 0     2010-10-26  2010-11  Blazers    Elliot Williams
# 1     2010-10-26  2010-11  Blazers          Greg Oden
# 2     2010-10-26  2010-11  Blazers     Joel Przybilla
# 3     2010-11-04  2010-11  Blazers    Elliot Williams
# 4     2010-11-06  2010-11  Blazers    Elliot Williams
# 13029 2018-03-03  2017-18  Thunder    Carmelo Anthony
# 13030 2017-12-03  2017-18  Thunder     Dakari Johnson
# 13031 2018-01-03  2017-18  Thunder       Alex Abrines
# 13032 2018-04-11  2017-18  Thunder       Alex Abrines
# 13033 2018-03-10  2017-18  Thunder  Terrance Ferguson
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...

# %%
df_inj_gitipi1018.value_counts('_merge')
# Out:
# _merge
# both          13034
# right_only        0
# left_only         0
# dtype: int64

# %%
df_inj_gitipi1018.drop(columns='_merge', inplace=True)

# %%
print(df_inj_gitipi1018.shape)
p(df_inj_gitipi1018)
# Out:
# (13034, 9)
#        game_date   season     Team       Relinquished  \
# 0     2010-10-26  2010-11  Blazers    Elliot Williams
# 1     2010-10-26  2010-11  Blazers          Greg Oden
# 2     2010-10-26  2010-11  Blazers     Joel Przybilla
# 3     2010-11-04  2010-11  Blazers    Elliot Williams
# 4     2010-11-06  2010-11  Blazers    Elliot Williams
# 13029 2018-03-03  2017-18  Thunder    Carmelo Anthony
# 13030 2017-12-03  2017-18  Thunder     Dakari Johnson
# 13031 2018-01-03  2017-18  Thunder       Alex Abrines
# 13032 2018-04-11  2017-18  Thunder       Alex Abrines
# 13033 2018-03-10  2017-18  Thunder  Terrance Ferguson
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...

# %%
#game_date's dropped by merge on game_date and team_id
print(df_injury_piptist1018.shape[0])
print(df_inj_gitipi1018.shape[0])
print('rows dropped: '+ str(df_injury_piptist1018.shape[0] - df_inj_gitipi1018.shape[0]))
print('percentage dropped: '+ str("{:.2f}".format(((df_injury_piptist1018.shape[0] - df_inj_gitipi1018.shape[0]) / df_injury_piptist1018.shape[0]) * 100)) + '%')
# Out:
# 13667
# 13034
# rows dropped: 633
# percentage dropped: 4.63%

# %%
df_inj_gitipi1018.columns
# Out:
# Index(['game_date', 'season', 'Team', 'Relinquished', 'Notes', 'player',
#        'team_id', 'PLAYER_ID', 'game_id'],
#       dtype='object')

# %%
df_inj_gdgitistpip1018 = df_inj_gitipi1018[['game_date', 'game_id', 'team_id', 'season', 'Team',  'PLAYER_ID', 'player']]
print(df_inj_gdgitistpip1018.shape)
p(df_inj_gdgitistpip1018)
# Out:
# (13034, 7)
#        game_date   game_id     team_id   season     Team  PLAYER_ID  \
# 0     2010-10-26  21000002  1610612757  2010-11  Blazers   202343.0
# 1     2010-10-26  21000002  1610612757  2010-11  Blazers   201141.0
# 2     2010-10-26  21000002  1610612757  2010-11  Blazers     2038.0
# 3     2010-11-04  21000067  1610612757  2010-11  Blazers   202343.0
# 4     2010-11-06  21000087  1610612757  2010-11  Blazers   202343.0
# 13029 2018-03-03  21700941  1610612760  2017-18  Thunder     2546.0
# 13030 2017-12-03  21700337  1610612760  2017-18  Thunder  1626177.0
# 13031 2018-01-03  21700565  1610612760  2017-18  Thunder   203518.0
# 13032 2018-04-11  21701227  1610612760  2017-18  Thunder   203518.0
# 13033 2018-03-10  21700990  1610612760  2017-18  Thunder  1628390.0
#
#                   player
# 0        Elliot Williams
# 1              Greg Oden
# 2         Joel Przybilla
# 3        Elliot Williams
# 4        Elliot Williams
# 13029    Carmelo Anthony
# ...

# %%
df_inj_gdgitistpip1018
# Out:
#        game_date   game_id     team_id   season     Team  PLAYER_ID  \
# 0     2010-10-26  21000002  1610612757  2010-11  Blazers   202343.0
# 1     2010-10-26  21000002  1610612757  2010-11  Blazers   201141.0
# 2     2010-10-26  21000002  1610612757  2010-11  Blazers     2038.0
# 3     2010-11-04  21000067  1610612757  2010-11  Blazers   202343.0
# 4     2010-11-06  21000087  1610612757  2010-11  Blazers   202343.0
# ...          ...       ...         ...      ...      ...        ...
# 13029 2018-03-03  21700941  1610612760  2017-18  Thunder     2546.0
# 13030 2017-12-03  21700337  1610612760  2017-18  Thunder  1626177.0
# 13031 2018-01-03  21700565  1610612760  2017-18  Thunder   203518.0
# 13032 2018-04-11  21701227  1610612760  2017-18  Thunder   203518.0
# 13033 2018-03-10  21700990  1610612760  2017-18  Thunder  1628390.0
#
#                   player
# 0        Elliot Williams
# 1              Greg Oden
# 2         Joel Przybilla
# 3        Elliot Williams
# ...

# %%
datapath = os.path.join('..', 'processed_data')

if not os.path.exists(datapath):
    os.mkdir(datapath)

datapath_df = os.path.join(datapath, 'A9injury_game_id_team_id_player_id_2010_2018.csv')
if not os.path.exists(datapath_df):
    df_inj_gdgitistpip1018.to_csv(datapath_df, index=False)

# %%
df = pd.read_csv(os.path.join('..', 'processed_data', 'A9injury_game_id_team_id_player_id_2010_2018.csv'))
print(df.shape)
p(df)
# Out:
# (13034, 9)
#         game_date   season     Team       Relinquished  \
# 0      2010-10-26  2010-11  Blazers    Elliot Williams
# 1      2010-10-26  2010-11  Blazers          Greg Oden
# 2      2010-10-26  2010-11  Blazers     Joel Przybilla
# 3      2010-11-04  2010-11  Blazers    Elliot Williams
# 4      2010-11-06  2010-11  Blazers    Elliot Williams
# 13029  2018-03-03  2017-18  Thunder    Carmelo Anthony
# 13030  2017-12-03  2017-18  Thunder     Dakari Johnson
# 13031  2018-01-03  2017-18  Thunder       Alex Abrines
# 13032  2018-04-11  2017-18  Thunder       Alex Abrines
# 13033  2018-03-10  2017-18  Thunder  Terrance Ferguson
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# ...
