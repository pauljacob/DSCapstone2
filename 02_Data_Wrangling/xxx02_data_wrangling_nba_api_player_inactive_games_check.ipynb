# %%
import pandas as pd
import time
from nba_api.stats.endpoints import boxscoreadvancedv2
import os

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.set_option('max_colwidth', None)

# %%
#get advanced stats dataset to use player

df_or = pd.read_csv(os.path.join('..', 'processed_data', '5boxscoreadvancedv2_2010_2018.csv'))
df_or
# Out:
#          GAME_ID       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0       20900001  1.610613e+09               BOS     Boston     1718.0
# 1       20900001  1.610613e+09               BOS     Boston      708.0
# 2       20900001  1.610613e+09               BOS     Boston     2570.0
# 3       20900001  1.610613e+09               BOS     Boston      951.0
# 4       20900001  1.610613e+09               BOS     Boston   200765.0
# ...          ...           ...               ...        ...        ...
# 291638  41700404  1.610613e+09               CLE  Cleveland  1626204.0
# 291639  41700404  1.610613e+09               CLE  Cleveland  1626224.0
# 291640  41700404  1.610613e+09               CLE  Cleveland   101181.0
# 291641  41700404  1.610613e+09               CLE  Cleveland  1627790.0
# 291642  41700404  1.610613e+09               CLE  Cleveland   203903.0
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# ...

# %%
from nba_api.stats.endpoints import boxscoreplayertrackv2

boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0041700404').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041700404  1610612744               GSW  Golden State     201142
# 1   0041700404  1610612744               GSW  Golden State     203110
# 2   0041700404  1610612744               GSW  Golden State     201580
# 3   0041700404  1610612744               GSW  Golden State     202691
# 4   0041700404  1610612744               GSW  Golden State     201939
# 5   0041700404  1610612744               GSW  Golden State       2738
# 6   0041700404  1610612744               GSW  Golden State    1628395
# 7   0041700404  1610612744               GSW  Golden State       2733
# 8   0041700404  1610612744               GSW  Golden State     201156
# 9   0041700404  1610612744               GSW  Golden State       2561
# 10  0041700404  1610612744               GSW  Golden State    1626172
# 11  0041700404  1610612744               GSW  Golden State       2585
# ...

# %%
boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0041700404').get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID  TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0041700404  1610612744   Warriors               GSW  Golden State  240:00
# 1  0041700404  1610612739  Cavaliers               CLE     Cleveland  240:00
#
#     DIST  ORBC  DRBC  RBC  TCHS  SAST  FTAST  PASS  AST  CFGM  CFGA  CFG_PCT  \
# 0  16.57    31    70   98   432     3      1   314   25    15    35    0.429
# 1  16.48    43    53   96   400     4      1   279   21    13    38    0.342
#
#    UFGM  UFGA  UFG_PCT  FG_PCT  DFGM  DFGA  DFG_PCT
# 0    24    51    0.471   0.453    15    26    0.577
# 1    17    49    0.347   0.345    15    20    0.750

# %%
boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0041700404').get_data_frames()[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-41da9cc752b2> in <module>
# ----> 1 boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0041700404').get_data_frames()[2]
#
# IndexError: list index out of range

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0020900001').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0   0020900001  1610612738               BOS     Boston       1718
# 1   0020900001  1610612738               BOS     Boston        708
# 2   0020900001  1610612738               BOS     Boston       2570
# 3   0020900001  1610612738               BOS     Boston        951
# 4   0020900001  1610612738               BOS     Boston     200765
# 5   0020900001  1610612738               BOS     Boston        739
# 6   0020900001  1610612738               BOS     Boston       2605
# 7   0020900001  1610612738               BOS     Boston     200749
# 8   0020900001  1610612738               BOS     Boston       2067
# 9   0020900001  1610612738               BOS     Boston     201592
# 10  0020900001  1610612738               BOS     Boston     201991
# 11  0020900001  1610612738               BOS     Boston       2243
# 12  0020900001  1610612739               CLE  Cleveland       2544
# ...

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0020900001').get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID  TEAM_NAME TEAM_ABBREVIATION  TEAM_CITY     MIN  \
# 0  0020900001  1610612739  Cavaliers               CLE  Cleveland  240:00
# 1  0020900001  1610612738    Celtics               BOS     Boston  240:00
#
#    E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  E_NET_RATING  \
# 0          96.7        97.8         101.7       104.4          -5.0
# 1         101.7       104.4          96.7        97.8           5.0
#
#    NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  DREB_PCT  REB_PCT  \
# 0        -6.6    0.586     1.21       14.8     0.222     0.732    0.465
# 1         6.6    0.625     1.25       16.7     0.268     0.778    0.535
#
#    E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE  \
# 0        15.204        15.4    0.457   0.529      1.0      0.200   92.76
# 1        17.123        17.6    0.507   0.569      1.0      0.197   92.76
#
#    PACE  PACE_PER40  POSS    PIE
# 0  91.0       75.83    91  0.451
# ...

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0020900001').get_data_frames()[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-f36d29772076> in <module>
# ----> 1 boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0020900001').get_data_frames()[2]
#
# IndexError: list index out of range

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0021000005').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0   0021000005  1610612765               DET     Detroit       2419
# 1   0021000005  1610612765               DET     Detroit     201948
# 2   0021000005  1610612765               DET     Detroit       1112
# 3   0021000005  1610612765               DET     Detroit       1888
# 4   0021000005  1610612765               DET     Detroit     201155
# 5   0021000005  1610612765               DET     Detroit     101198
# 6   0021000005  1610612765               DET     Detroit       2732
# 7   0021000005  1610612765               DET     Detroit     101111
# 8   0021000005  1610612765               DET     Detroit     101131
# 9   0021000005  1610612765               DET     Detroit       1503
# 10  0021000005  1610612765               DET     Detroit     202328
# 11  0021000005  1610612765               DET     Detroit     201969
# 12  0021000005  1610612751               NJN  New Jersey       2566
# ...

# %%
boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0021000005').get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION   TEAM_CITY     MIN  \
# 0  0021000005  1610612751      Nets               NJN  New Jersey  240:00
# 1  0021000005  1610612765   Pistons               DET     Detroit  240:00
#
#    E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  E_NET_RATING  \
# 0         108.0       113.5         106.3       108.9           1.7
# 1         106.3       108.9         108.0       113.5          -1.7
#
#    NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  DREB_PCT  REB_PCT  \
# 0         4.6    0.436     1.42       14.2     0.318     0.712    0.531
# 1        -4.6    0.568     3.50       17.0     0.288     0.682    0.469
#
#    E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE  \
# 0        12.826        13.5    0.525   0.558      1.0      0.197   92.88
# 1         6.508         6.7    0.494   0.509      1.0      0.200   92.88
#
#    PACE  PACE_PER40  POSS    PIE
# 0  89.5       74.58    89  0.519
# ...

# %%
from nba_api.stats.endpoints import commonallplayers
from nba_api.stats.endpoints import commonallplayers

# %%
commonallplayers.CommonAllPlayers(season='2010-11').get_data_frames()[0]
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4594    1627790              Zizic, Ante           Ante Zizic             0
# 4595      78647                Zoet, Jim             Jim Zoet             0
# 4596      78648               Zopf, Bill            Bill Zopf             0
# 4597    1627826             Zubac, Ivica          Ivica Zubac             0
# 4598      78650              Zunic, Matt           Matt Zunic             0
#
# ...

# %%
commonallplayers.CommonAllPlayers().get_data_frames()[0]
# Out:
#       PERSON_ID DISPLAY_LAST_COMMA_FIRST   DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby             0
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz             0
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar             0
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf             0
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad             0
# ...         ...                      ...                  ...           ...
# 4594    1627790              Zizic, Ante           Ante Zizic             0
# 4595      78647                Zoet, Jim             Jim Zoet             0
# 4596      78648               Zopf, Bill            Bill Zopf             0
# 4597    1627826             Zubac, Ivica          Ivica Zubac             1
# 4598      78650              Zunic, Matt           Matt Zunic             0
#
# ...

# %%
#commonallplayers.CommonAllPlayers().get_data_frames()[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-41f95788eeaa> in <module>
# ----> 1 commonallplayers.CommonAllPlayers().get_data_frames()[1]
#
# IndexError: list index out of range

# %%
#help(commonallplayers)

# %%
from nba_api.stats.endpoints import commonteamroster

# %%
commonteamroster.CommonTeamRoster(team_id='001610612751', season='2010-11').get_data_frames()[0]
# Out:
#         TeamID SEASON LeagueID           PLAYER      PLAYER_SLUG NUM POSITION  \
# 0   1610612751   2010       00  Sundiata Gaines  sundiata-gaines   0        G
# 1   1610612751   2010       00    Jordan Farmar    jordan-farmar   2        G
# 2   1610612751   2010       00       Mario West       mario-west   6        G
# 3   1610612751   2010       00   Deron Williams   deron-williams   8        G
# 4   1610612751   2010       00     Damion James     damion-james  10        F
# 5   1610612751   2010       00      Brook Lopez      brook-lopez  11        C
# 6   1610612751   2010       00         Ben Uzoh         ben-uzoh  18        G
# 7   1610612751   2010       00    Sasha Vujacic    sasha-vujacic  20        G
# 8   1610612751   2010       00    Travis Outlaw    travis-outlaw  21        F
# 9   1610612751   2010       00   Anthony Morrow   anthony-morrow  22        G
# 10  1610612751   2010       00   Stephen Graham   stephen-graham  26      G-F
# ...

# %%
commonteamroster.CommonTeamRoster(team_id='001610612751', season='2010-11').get_data_frames()[1]
# Out:
#       TEAM_ID SEASON  COACH_ID FIRST_NAME    LAST_NAME         COACH_NAME  \
# 0  1610612751   2010      2885      Avery      Johnson      Avery Johnson
# 1  1610612751   2010    202434     Popeye        Jones       Popeye Jones
# 2  1610612751   2010      2517        Sam     Mitchell       Sam Mitchell
# 3  1610612751   2010      2703       John        Loyer         John Loyer
# 4  1610612751   2010      2806        Tom      Barrise        Tom Barrise
# 5  1610612751   2010    200869      Larry  Krystkowiak  Larry Krystkowiak
# 6  1610612751   2010      1673       Rich      Dalatri       Rich Dalatri
# 7  1610612751   2010      1303        Tim        Walsh          Tim Walsh
#
#    IS_ASSISTANT       COACH_TYPE SORT_SEQUENCE  SUB_SORT_SEQUENCE
# 0             1       Head Coach          None                  1
# 1             2  Assistant Coach          None                  5
# 2             2  Assistant Coach          None                  5
# ...

# %%
#commonteamroster.CommonTeamRoster(team_id='001610612751', season='2010-11').get_data_frames()[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-5859ae0ffb3c> in <module>
# ----> 1 commonteamroster.CommonTeamRoster(team_id='001610612751', season='2010-11').get_data_frames()[2]
#
# IndexError: list index out of range

# %%
commonteamroster.CommonTeamRoster(team_id='001610612765', season='2010-11').get_data_frames()[0]
# Out:
#         TeamID SEASON LeagueID              PLAYER         PLAYER_SLUG NUM  \
# 0   1610612765   2010       00       Tracy McGrady       tracy-mcgrady   1
# 1   1610612765   2010       00      Rodney Stuckey      rodney-stuckey   3
# 2   1610612765   2010       00         Austin Daye         austin-daye   5
# 3   1610612765   2010       00         Ben Wallace         ben-wallace   6
# 4   1610612765   2010       00          Ben Gordon          ben-gordon   7
# 5   1610612765   2010       00        Chris Wilcox        chris-wilcox   9
# 6   1610612765   2010       00         Greg Monroe         greg-monroe  10
# 7   1610612765   2010       00          Will Bynum          will-bynum  12
# 8   1610612765   2010       00     Tayshaun Prince     tayshaun-prince  22
# 9   1610612765   2010       00       Terrico White       terrico-white  23
# 10  1610612765   2010       00  Charlie Villanueva  charlie-villanueva  31
# ...

# %%
from nba_api.stats.endpoints import leaguedashplayerbiostats

# %%
leaguedashplayerbiostats.LeagueDashPlayerBioStats(season='2010-11').get_data_frames()[0]
# Out:
#      PLAYER_ID            PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 0       201985               AJ Price  1610612754               IND  24.0
# 1       201166           Aaron Brooks  1610612756               PHX  26.0
# 2       201189             Aaron Gray  1610612740               NOH  26.0
# 3       201151               Acie Law  1610612744               GSW  26.0
# 4         1733          Al Harrington  1610612743               DEN  31.0
# 5       201143             Al Horford  1610612737               ATL  25.0
# 6         2744           Al Jefferson  1610612762               UTA  26.0
# 7       201154            Al Thornton  1610612744               GSW  27.0
# 8       202329        Al-Farouq Aminu  1610612746               LAC  20.0
# 9       201582          Alexis Ajinca  1610612761               TOR  23.0
# 10      202087             Alonzo Gee  1610612739               CLE  24.0
# 11        2405      Amar'e Stoudemire  1610612752               NYK  28.0
# ...

# %%
from nba_api.stats.endpoints import playercompare

# %%
from playercompare.PlayerCompare().get_data_frames()
# Out:
#   File "<ipython-input-85-4e38a25e1586>", line 1
#     from playercompare.PlayerCompare().get_data_frames()
#                                     ^
# SyntaxError: invalid syntax

# %%
from nba_api.stats.endpoints import boxscoretraditionalv2

# %%
boxscoretraditionalv2.BoxScoreTraditionalV2(game_id = '0020900001').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0   0020900001  1610612738               BOS     Boston       1718
# 1   0020900001  1610612738               BOS     Boston        708
# 2   0020900001  1610612738               BOS     Boston       2570
# 3   0020900001  1610612738               BOS     Boston        951
# 4   0020900001  1610612738               BOS     Boston     200765
# 5   0020900001  1610612738               BOS     Boston        739
# 6   0020900001  1610612738               BOS     Boston       2605
# 7   0020900001  1610612738               BOS     Boston     200749
# 8   0020900001  1610612738               BOS     Boston       2067
# 9   0020900001  1610612738               BOS     Boston     201592
# 10  0020900001  1610612738               BOS     Boston     201991
# 11  0020900001  1610612738               BOS     Boston       2243
# 12  0020900001  1610612739               CLE  Cleveland       2544
# ...

# %%
help(boxscoretraditionalv2)
# Out:
# Help on module nba_api.stats.endpoints.boxscoretraditionalv2 in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.boxscoretraditionalv2
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         BoxScoreTraditionalV2
#
#     class BoxScoreTraditionalV2(nba_api.stats.endpoints._base.Endpoint)
#      |  BoxScoreTraditionalV2(game_id, end_period='0', end_range='0', range_type='0', start_period='0', start_range='0', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      BoxScoreTraditionalV2
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, game_id, end_period='0', end_range='0', range_type='0', start_period='0', start_range='0', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
# ...

# %%
help(playercompare)
# Out:
# Help on module nba_api.stats.endpoints.playercompare in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.playercompare
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         PlayerCompare
#
#     class PlayerCompare(nba_api.stats.endpoints._base.Endpoint)
#      |  PlayerCompare(vs_player_id_list, player_id_list, last_n_games='0', measure_type_detailed_defense='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_playoffs='Regular Season', conference_nullable='', date_from_nullable='', date_to_nullable='', division_simple_nullable='', game_segment_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', season_segment_nullable='', shot_clock_range_nullable='', vs_conference_nullable='', vs_division_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
# ...

# %%
help(leaguedashplayerbiostats)
# Out:
# Help on module nba_api.stats.endpoints.leaguedashplayerbiostats in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.leaguedashplayerbiostats
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         LeagueDashPlayerBioStats
#
#     class LeagueDashPlayerBioStats(nba_api.stats.endpoints._base.Endpoint)
# ...

# %%
help(commonteamroster)
# Out:
# Help on module nba_api.stats.endpoints.commonteamroster in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.commonteamroster
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         CommonTeamRoster
#
#     class CommonTeamRoster(nba_api.stats.endpoints._base.Endpoint)
#      |  CommonTeamRoster(team_id, season='2020-21', league_id_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      CommonTeamRoster
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, team_id, season='2020-21', league_id_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
# ...

# %%
# Out:
# Help on module nba_api.stats.endpoints.commonallplayers in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.commonallplayers
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         CommonAllPlayers
#
#     class CommonAllPlayers(nba_api.stats.endpoints._base.Endpoint)
#      |  CommonAllPlayers(is_only_current_season=0, league_id='00', season='2020-21', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      CommonAllPlayers
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, is_only_current_season=0, league_id='00', season='2020-21', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
# ...

# %%
df_games2 = pd.read_csv(os.path.join('..', 'processed_data', '4game_id_date_stats_betting_totals_2010_2018.csv'))
df_games2.head(11)
# Out:
#      game_id   game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0   21000001  2010-10-26    1610612738         1.0       240      32.0
# 1   21000002  2010-10-26    1610612757         1.0       240      43.0
# 2   21000003  2010-10-26    1610612747         1.0       240      40.0
# 3   21000004  2010-10-27    1610612739         1.0       240      36.0
# 4   21000005  2010-10-27    1610612751         1.0       240      39.0
# 5   21000006  2010-10-27    1610612755         0.0       240      36.0
# 6   21000007  2010-10-27    1610612761         0.0       240      36.0
# 7   21000008  2010-10-27    1610612763         0.0       240      40.0
# 8   21000009  2010-10-27    1610612750         0.0       240      43.0
# 9   21000010  2010-10-27    1610612740         1.0       240      34.0
# 10  21000011  2010-10-27    1610612760         1.0       240      32.0
#
#     fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# ...

# %%
df_games_all = pd.read_csv(os.path.join('..', 'raw_data', 'nba_games_all.csv'))
df_games_all.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2  20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3  20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4  20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
#
#    w_pct  min   fgm    fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0  0.569  240  39.0   74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 1  0.542  240  37.0   68.0   0.544   5.0  20.0    0.250  29.0  37.0     1.0
# 2  0.600  240  37.0   71.0   0.521   7.0  19.0    0.368  20.0  27.0     1.0
# 3  0.605  240  39.0   85.0   0.459   8.0  18.0    0.444  34.0  37.0     1.0
# 4  0.563  290  49.0  100.0   0.490   5.0  13.0    0.385  12.0  18.0     1.0
#
# ...

# %%
df_games_all[df_games_all.game_id == 41700404]

# %%
df_bsadv = pd.read_csv(os.path.join('..', 'processed_data', '5boxscoreadvancedv2_2010_2018.csv'))
df_bsadv.head()
# Out:
#     GAME_ID       TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0  20900001  1.610613e+09               BOS    Boston     1718.0
# 1  20900001  1.610613e+09               BOS    Boston      708.0
# 2  20900001  1.610613e+09               BOS    Boston     2570.0
# 3  20900001  1.610613e+09               BOS    Boston      951.0
# 4  20900001  1.610613e+09               BOS    Boston   200765.0
#
#         PLAYER_NAME START_POSITION COMMENT    MIN  E_OFF_RATING  OFF_RATING  \
# 0       Paul Pierce              F     NaN  37:59          95.3        97.4
# 1     Kevin Garnett              F     NaN  33:05          95.6        95.5
# 2  Kendrick Perkins              C     NaN  25:42          99.2       100.0
# 3         Ray Allen              G     NaN  42:21         105.2       108.8
# 4       Rajon Rondo              G     NaN  34:29          92.7        94.1
#
#    E_DEF_RATING  DEF_RATING  E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  \
# ...

# %%
df_bsadv

# %%
from nba_api.stats.endpoints import boxscoreplayertrackv2

# %%
boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id='0041700404').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041700404  1610612744               GSW  Golden State     201142
# 1   0041700404  1610612744               GSW  Golden State     203110
# 2   0041700404  1610612744               GSW  Golden State     201580
# 3   0041700404  1610612744               GSW  Golden State     202691
# 4   0041700404  1610612744               GSW  Golden State     201939
# 5   0041700404  1610612744               GSW  Golden State       2738
# 6   0041700404  1610612744               GSW  Golden State    1628395
# 7   0041700404  1610612744               GSW  Golden State       2733
# 8   0041700404  1610612744               GSW  Golden State     201156
# 9   0041700404  1610612744               GSW  Golden State       2561
# 10  0041700404  1610612744               GSW  Golden State    1626172
# 11  0041700404  1610612744               GSW  Golden State       2585
# ...

# %%
help(boxscoreplayertrackv2)

# %%
df2 = pd.read_csv(os.path.join('..', 'processed_data', '3game_date_home_away.csv'), parse_dates=['game_date'])
df2



df_empty = pd.DataFrame({})

# %%
game_ids = '00' + df2.game_id.apply(str)
game_ids

# %%
path = os.path.join('..', 'processed_data_preliminary', '5game_id_team_id_player_name_advanced_stats.csv')
df5 = pd.read_csv(path)
df5

# %%
game_ids[game_ids == '0020600808']

# %%
game_ids.shape

# %%
14712 / 100

# %%
startstops = [807 + i * 148 for i in range(0, 101)]
startstops

# %%
startstops[100] = 15519
startstops[100]

# %%
startstops

# %%
game_ids

# %%
len(startstops)

# %%
for _ in range(len(startstops) - 1):
    print(_)

# %%
game_ids[startstops[0]:startstops[1],]

# %%
for i in range(len(startstops) - 1):
    for game_id_ in game_ids[startstops[i]:startstops[i+1],]:
        print(str(game_id_) + ': ' + str(startstops[i]) + ' : ' + str(startstops[i+1]))

# %%
#set(df.column_name) - set(df2.column_name)

# %%
#df.state[df.column_name.str.contains('state1|state2|state3|state4')]

# %%
#regex
#df.column_name.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)

# %%
#df.plot(x='column_name1', y='column_name2', kind='scatter');

# %%
#df.loc[df.column_name == 'state1', ['column_name', 'column_name']]

# %%
#missing = pd.concat([df.isnull().sum(axis=1), 100 * df.isnull().mean(axis=1)], axis=1)
#missing.columns=['count', '%']
#missing.sort_values(by='count', ascending=False).head(10)

# %%
#missing['%'].unique()

# %%
#datapath = 'data'

# %%
#if not os.path.exists(datapath):
    #os.mkdir(datapath)

# %%
#datapath_df = os.path.join(datapath, 'df_cleaned.csv')
#if not os.path.exists(datapath_df):
#    df.to_csv(datapath_df, index=False)

# %%
#datapath_df2 = os.path.join(datapath, 'df2.csv')
#if not os.path.exists(datapath_df2):
#    df2.to_csv(datapath_df2, index=False)
