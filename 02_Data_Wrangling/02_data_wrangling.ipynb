# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

pd.set_option('display.max_colwidth', None)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Paul\\sb\\DSCapstone2\\02_Data_Wrangling'

# %%
filenames = ['nba_games_all.csv', 'injuries_2010-2020.csv', 'nba_teams_all.csv',
             'nba_players_all.csv', 'nba_teams.csv', 'teams.csv']

# %%
dataframes = [pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\raw_data\\' + f) for f in filenames]   
df = dataframes[0]
df2 = dataframes[1]
df3 = dataframes[2]
df4 = dataframes[3]
df5 = dataframes[4]
df6 = dataframes[5]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125624 entries, 0 to 125623
# Data columns (total 32 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   game_id      125624 non-null  int64
#  1   game_date    119376 non-null  object
#  2   matchup      125624 non-null  object
#  3   team_id      125624 non-null  int64
#  4   is_home      125624 non-null  object
#  5   wl           125614 non-null  object
#  6   w            41000 non-null   float64
#  7   l            41000 non-null   float64
#  8   w_pct        41000 non-null   float64
#  9   min          125624 non-null  int64
#  10  fgm          125607 non-null  float64
#  11  fga          90894 non-null   float64
#  12  fg_pct       90871 non-null   float64
#  13  fg3m         95248 non-null   float64
#  14  fg3a         84316 non-null   float64
#  15  fg3_pct      80062 non-null   float64
#  16  ftm          125605 non-null  float64
# ...

# %%
df.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2  20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3  20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4  20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
#
#    w_pct  min   fgm    fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0  0.569  240  39.0   74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 1  0.542  240  37.0   68.0   0.544   5.0  20.0    0.250  29.0  37.0     1.0
# 2  0.600  240  37.0   71.0   0.521   7.0  19.0    0.368  20.0  27.0     1.0
# 3  0.605  240  39.0   85.0   0.459   8.0  18.0    0.444  34.0  37.0     1.0
# 4  0.563  290  49.0  100.0   0.490   5.0  13.0    0.385  12.0  18.0     1.0
#
# ...

# %%
df[df.season == '2010-11']
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 1008    21001206  2011-04-11  DET vs. CLE  1610612739       f  W  18.0  63.0
# 1009    21001190  2011-04-09  MIL vs. CLE  1610612739       f  L  17.0  63.0
# 1010    21001123  2011-04-01  WAS vs. CLE  1610612739       f  L  15.0  60.0
# 1011    21001011  2011-03-16  SAC vs. CLE  1610612739       f  W  13.0  53.0
# 1012    21000985  2011-03-13    OKC @ CLE  1610612739       t  L  12.0  53.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 101410  21000068  2010-11-05  IND vs. MIL  1610612749       f  W   2.0   4.0
# 101411  21000026         NaN  MIN vs. MIL  1610612749       f  L   0.0   2.0
# 101416  11000120         NaN    MIN @ MIL  1610612749       t  L   3.0   5.0
# 101417  11000084         NaN  MIN vs. MIL  1610612749       f  L   3.0   3.0
# 101418  11000034         NaN    CHA @ MIL  1610612749       t  W   2.0   1.0
#
# ...

# %%
df[df.season == '2010-11'][df.team_id > 33333].team_id.unique()
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# array([1610612739, 1610612738, 1610612765, 1610612763, 1610612760,
#        1610612753, 1610612754, 1610612751, 1610612757, 1610612758,
#        1610612755, 1610612759, 1610612750, 1610612742, 1610612743,
#        1610612740, 1610612746, 1610612747, 1610612744, 1610612745,
#        1610612748, 1610612737, 1610612764, 1610612762, 1610612766,
#        1610612761, 1610612752, 1610612756, 1610612741, 1610612749,
#        1610616833, 1610616834], dtype=int64)

# %%
df[df.season == '2010-11'][df.team_id > 33333].team_id.unique().shape
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (32,)

# %%
df[df.team_id > 33333].team_id.unique()
# Out:
# array([1610612762, 1610612764, 1610612763, 1610612765, 1610612766,
#        1610612760, 1610612761, 1610612753, 1610612751, 1610612754,
#        1610612752, 1610610036, 1610612758, 1610612756, 1610612755,
#        1610612757, 1610612750, 1610612743, 1610612741, 1610612746,
#        1610612747, 1610612745, 1610612748, 1610612749, 1610612759,
#        1610612739, 1610612737, 1610612742, 1610612738, 1610612740,
#        1610612744, 1610610030, 1610610024, 1610616833, 1610616834],
#       dtype=int64)

# %%
df[df.team_id > 33333].team_id.unique().shape
# Out:
# (35,)

# %%
df[df.team_id > 33333][df.team_id != 1610610030][df.team_id != 1610610024][df.team_id != 1610610036][df.team_id  != 1610616833][df.team_id != 1610616834].team_id.unique()
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ...

# %%
df[df.team_id > 33333][df.team_id != 1610610030][df.team_id != 1610610024][df.team_id != 1610610036][df.team_id  != 1610616833][df.team_id != 1610616834].team_id.unique().shape
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (30,)

# %%
seta = set(df[df.team_id > 33333][df.team_id != 1610610030][df.team_id != 1610610024][df.team_id != 1610610036][df.team_id  != 1610616833][df.team_id != 1610616834].team_id.unique())
seta
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# {1610612737,
# ...

# %%
dff = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data\\0team_id_abbreviation_df.csv')
dff
# Out:
#        team_id abbreviation
# 0   1610612737          ATL
# 1   1610612738          BOS
# 2   1610612739          CLE
# 3   1610612740          NOP
# 4   1610612741          CHI
# 5   1610612742          DAL
# 6   1610612743          DEN
# 7   1610612744          GSW
# 8   1610612745          HOU
# 9   1610612746          LAC
# 10  1610612747          LAL
# 11  1610612748          MIA
# 12  1610612749          MIL
# 13  1610612750          MIN
# 14  1610612751          BKN
# 15  1610612752          NYK
# 16  1610612753          ORL
# 17  1610612754          IND
# 18  1610612755          PHI
# 19  1610612756          PHX
# 20  1610612757          POR
# 21  1610612758          SAC
# 22  1610612759          SAS
# 23  1610612760          OKC
# 24  1610612761          TOR
# 25  1610612762          UTA
# 26  1610612763          MEM
# 27  1610612764          WAS
# 28  1610612765          DET
# 29  1610612766          CHA

# %%
dff.team_id
# Out:
# 0     1610612737
# 1     1610612738
# 2     1610612739
# 3     1610612740
# 4     1610612741
# 5     1610612742
# 6     1610612743
# 7     1610612744
# 8     1610612745
# 9     1610612746
# 10    1610612747
# 11    1610612748
# 12    1610612749
# 13    1610612750
# 14    1610612751
# 15    1610612752
# 16    1610612753
# 17    1610612754
# 18    1610612755
# 19    1610612756
# 20    1610612757
# 21    1610612758
# 22    1610612759
# 23    1610612760
# 24    1610612761
# 25    1610612762
# 26    1610612763
# 27    1610612764
# 28    1610612765
# 29    1610612766
# Name: team_id, dtype: int64

# %%
setb = set(dff.team_id)
setb
# Out:
# {1610612737,
#  1610612738,
#  1610612739,
#  1610612740,
#  1610612741,
#  1610612742,
#  1610612743,
#  1610612744,
#  1610612745,
#  1610612746,
#  1610612747,
#  1610612748,
#  1610612749,
#  1610612750,
#  1610612751,
#  1610612752,
#  1610612753,
#  1610612754,
#  1610612755,
#  1610612756,
#  1610612757,
#  1610612758,
#  1610612759,
#  1610612760,
#  1610612761,
#  1610612762,
#  1610612763,
#  1610612764,
#  1610612765,
#  1610612766}

# %%
setab = seta - setb
setab
# Out:
# set()

# %%
setba = setb - seta
setba
# Out:
# set()

# %%
str(df[df.team_id > 33333].team_id).contains('16106127')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-20dbefdf3448> in <module>
# ----> 1 str(df[df.team_id > 33333].team_id).contains('16106127')
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
df[df.team_id == 1610616833]
# Out:
#          game_id   game_date      matchup     team_id is_home wl    w    l  \
# 1418    31200001  2013-02-17  WST vs. EST  1610616833       f  L  0.0  1.0
# 2281    35100001  1952-02-11    WST @ EST  1610616833       t  W  NaN  NaN
# 2774    35500001  1956-01-24    WST @ EST  1610616833       t  L  NaN  NaN
# 3043    35700001  1958-01-21  WST vs. EST  1610616833       f  W  NaN  NaN
# 3582    36103001  1962-01-16    WST @ EST  1610616833       t  L  NaN  NaN
# 3904    36300001  1964-01-14    WST @ EST  1610616833       t  W  NaN  NaN
# 4092    36400001  1965-01-13  WST vs. EST  1610616833       f  W  NaN  NaN
# 4938    36800001  1969-01-14    WST @ EST  1610616833       t  W  NaN  NaN
# 5840    37100022  1972-01-18  WST vs. EST  1610616833       f  L  NaN  NaN
# 6169    37200001  1973-01-23  WST vs. EST  1610616833       f  W  NaN  NaN
# 7637    37700001  1978-02-05    WST @ EST  1610616833       t  W  NaN  NaN
# ...

# %%
df[df.team_id == 1610616834]
# Out:
#          game_id   game_date      matchup     team_id is_home wl    w    l  \
# 2298    35100001  1952-02-11  EST vs. WST  1610616834       f  L  NaN  NaN
# 2798    35500001  1956-01-24  EST vs. WST  1610616834       f  W  NaN  NaN
# 3596    36103001  1962-01-16  EST vs. WST  1610616834       f  W  NaN  NaN
# 3936    36300001  1964-01-14  EST vs. WST  1610616834       f  L  NaN  NaN
# 4119    36400001  1965-01-13    EST @ WST  1610616834       t  L  NaN  NaN
# 4957    36800001  1969-01-14  EST vs. WST  1610616834       f  L  NaN  NaN
# 5856    37100022  1972-01-18    EST @ WST  1610616834       t  W  NaN  NaN
# 6190    37200001  1973-01-23    EST @ WST  1610616834       t  L  NaN  NaN
# 6589    37400101  1975-01-14    EST @ WST  1610616834       t  L  NaN  NaN
# 7666    37700001  1978-02-05  EST vs. WST  1610616834       f  L  NaN  NaN
# 8782    31200001  2013-02-17    EST @ WST  1610616834       t  W  1.0  0.0
# ...

# %%
df2.head()
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls      NaN  Carlos Boozer
# 1  2010-10-06  Pistons      NaN  Jonas Jerebko
# 2  2010-10-06  Pistons      NaN  Terrico White
# 3  2010-10-08  Blazers      NaN     Jeff Ayres
# 4  2010-10-08     Nets      NaN    Troy Murphy
#
#                                                       Notes
# 0   fractured bone in right pinky finger (out indefinitely)
# 1             torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out indefinitely)
# 3                 torn ACL in right knee (out indefinitely)
# 4                    strained lower back (out indefinitely)

# %%
df2.shape
# Out:
# (27105, 5)

# %%
df2 = df2[df2.Team != 'Bullets']
df2
# Out:
#              Date     Team      Acquired   Relinquished  \
# 0      2010-10-03    Bulls           NaN  Carlos Boozer
# 1      2010-10-06  Pistons           NaN  Jonas Jerebko
# 2      2010-10-06  Pistons           NaN  Terrico White
# 3      2010-10-08  Blazers           NaN     Jeff Ayres
# 4      2010-10-08     Nets           NaN    Troy Murphy
# ...           ...      ...           ...            ...
# 27100  2020-09-30   Lakers  Dion Waiters            NaN
# 27101  2020-10-02     Heat           NaN    Bam Adebayo
# 27102  2020-10-02     Heat           NaN   Goran Dragic
# 27103  2020-10-02     Heat   Chris Silva            NaN
# 27104  2020-10-06     Heat   Bam Adebayo            NaN
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# ...

# %%
df2.iloc[:,[2,3]]
# Out:
#            Acquired   Relinquished
# 0               NaN  Carlos Boozer
# 1               NaN  Jonas Jerebko
# 2               NaN  Terrico White
# 3               NaN     Jeff Ayres
# 4               NaN    Troy Murphy
# ...             ...            ...
# 27100  Dion Waiters            NaN
# 27101           NaN    Bam Adebayo
# 27102           NaN   Goran Dragic
# 27103   Chris Silva            NaN
# 27104   Bam Adebayo            NaN
#
# [27104 rows x 2 columns]

# %%
#df2.iloc[:,[2]].merge(df2.iloc[:,[3]], left_on='Acquired', right_on='Relinquished', how='inner')

# %%
df2.iloc[:,[2]].join(df2.iloc[:,[3]], how='inner')
# Out:
#            Acquired   Relinquished
# 0               NaN  Carlos Boozer
# 1               NaN  Jonas Jerebko
# 2               NaN  Terrico White
# 3               NaN     Jeff Ayres
# 4               NaN    Troy Murphy
# ...             ...            ...
# 27100  Dion Waiters            NaN
# 27101           NaN    Bam Adebayo
# 27102           NaN   Goran Dragic
# 27103   Chris Silva            NaN
# 27104   Bam Adebayo            NaN
#
# [27104 rows x 2 columns]

# %%
df2.iloc[:,[2]].merge(df2.iloc[:,[3]], left_index=True, right_index=True, how='inner')
# Out:
#            Acquired   Relinquished
# 0               NaN  Carlos Boozer
# 1               NaN  Jonas Jerebko
# 2               NaN  Terrico White
# 3               NaN     Jeff Ayres
# 4               NaN    Troy Murphy
# ...             ...            ...
# 27100  Dion Waiters            NaN
# 27101           NaN    Bam Adebayo
# 27102           NaN   Goran Dragic
# 27103   Chris Silva            NaN
# 27104   Bam Adebayo            NaN
#
# [27104 rows x 2 columns]

# %%
#[for i in range(len(df2.shape[0])) if (df2.iloc[:,[2]] != df2.iloc[:,[3]]) df2.iloc[:,[2]]]

# %%
[c1 for c1 in df2.iloc[:,[2,3]]]


#df['previous_year'] = [row-1 for row in df['year']]
#https://chrisalbon.com/python/data_wrangling/pandas_list_comprehension/
# Out:
# ['Acquired', 'Relinquished']

# %%
df2[df2['Acquired'].notnull() & df2['Relinquished'].notnull()]
# Out:
#              Date   Team       Acquired   Relinquished               Notes
# 21690  2018-03-23  Hawks  John Collins   John Collins   returned to lineup

# %%
df2.iloc[:,[2,3]] = df2.iloc[:,[2,3]].fillna('')
df2.iloc[:,[2,3]]
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Acquired   Relinquished
# 0                    Carlos Boozer
# 1                    Jonas Jerebko
# 2                    Terrico White
# 3                       Jeff Ayres
# 4                      Troy Murphy
# ...             ...            ...
# 27100  Dion Waiters
# ...

# %%
df2.iloc[:,[2,3]]
# Out:
#            Acquired   Relinquished
# 0                    Carlos Boozer
# 1                    Jonas Jerebko
# 2                    Terrico White
# 3                       Jeff Ayres
# 4                      Troy Murphy
# ...             ...            ...
# 27100  Dion Waiters
# 27101                  Bam Adebayo
# 27102                 Goran Dragic
# 27103   Chris Silva
# 27104   Bam Adebayo
#
# [27104 rows x 2 columns]

# %%
df2['Relinquished_Acquired'] = (df2.iloc[:,2 ] + df2.iloc[:, 3]).to_frame()
df2['Relinquished_Acquired']
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0        Carlos Boozer
# 1        Jonas Jerebko
# 2        Terrico White
# 3           Jeff Ayres
# 4          Troy Murphy
#              ...
# 27100     Dion Waiters
# 27101      Bam Adebayo
# 27102     Goran Dragic
# 27103      Chris Silva
# 27104      Bam Adebayo
# Name: Relinquished_Acquired, Length: 27104, dtype: object

# %%
df2
# Out:
#              Date     Team      Acquired   Relinquished  \
# 0      2010-10-03    Bulls                Carlos Boozer
# 1      2010-10-06  Pistons                Jonas Jerebko
# 2      2010-10-06  Pistons                Terrico White
# 3      2010-10-08  Blazers                   Jeff Ayres
# 4      2010-10-08     Nets                  Troy Murphy
# ...           ...      ...           ...            ...
# 27100  2020-09-30   Lakers  Dion Waiters
# 27101  2020-10-02     Heat                  Bam Adebayo
# 27102  2020-10-02     Heat                 Goran Dragic
# 27103  2020-10-02     Heat   Chris Silva
# 27104  2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes  \
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
df2[df2['Relinquished_Acquired'] == 'Dion Waiters']
# Out:
#              Date       Team      Acquired  Relinquished  \
# 5461   2012-12-03  Cavaliers                Dion Waiters
# 5483   2012-12-05  Cavaliers                Dion Waiters
# 5651   2012-12-18  Cavaliers  Dion Waiters
# 6609   2013-03-04  Cavaliers                Dion Waiters
# 6628   2013-03-06  Cavaliers                Dion Waiters
# 6802   2013-03-19  Cavaliers                Dion Waiters
# 6808   2013-03-20  Cavaliers                Dion Waiters
# 6833   2013-03-22  Cavaliers                Dion Waiters
# 6904   2013-03-27  Cavaliers                Dion Waiters
# 6943   2013-03-29  Cavaliers                Dion Waiters
# 6985   2013-03-31  Cavaliers                Dion Waiters
# 7169   2013-04-10  Cavaliers  Dion Waiters
# 7805   2013-11-15  Cavaliers                Dion Waiters
# 7876   2013-11-20  Cavaliers  Dion Waiters
# 8366   2013-12-20  Cavaliers                Dion Waiters
# 8367   2013-12-20  Cavaliers                Dion Waiters
# ...

# %%
df2[df2['Relinquished_Acquired'].str.contains('LeBron James')]
# Out:
#              Date       Team      Acquired  Relinquished  \
# 1133   2011-01-13       Heat                LeBron James
# 1183   2011-01-15       Heat                LeBron James
# 1227   2011-01-18       Heat  LeBron James
# 2502   2011-04-13       Heat                LeBron James
# 2858   2012-01-07       Heat                LeBron James
# 4769   2012-04-21       Heat                LeBron James
# 4831   2012-04-24       Heat                LeBron James
# 4896   2012-04-26       Heat                LeBron James
# 6989   2013-03-31       Heat                LeBron James
# 7022   2013-04-02       Heat                LeBron James
# 7077   2013-04-05       Heat                LeBron James
# 7171   2013-04-10       Heat                LeBron James
# 7264   2013-04-15       Heat                LeBron James
# 8492   2013-12-28       Heat                LeBron James
# 8516   2013-12-30       Heat  LeBron James
# 9325   2014-02-23       Heat                LeBron James
# ...

# %%
df2.Date.value_counts()
# Out:
# 2014-04-16    76
# 2012-04-26    75
# 2017-04-12    74
# 2011-04-13    67
# 2017-10-18    67
#               ..
# 2017-07-04     1
# 2020-09-22     1
# 2020-09-18     1
# 2018-04-24     1
# 2016-04-20     1
# Name: Date, Length: 2103, dtype: int64

# %%
#horizontal histogram

fig, ax = plt.subplots(figsize=(12,8))
df2.Date.value_counts().head(20).plot(kind='barh', ax=ax)
 
ax.set_title('Date Count')
 
ax.set_xlabel('Count')
ax.set_ylabel('Date')

plt.subplots_adjust(wspace=0.5);

# %%
df2.head()
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls           Carlos Boozer
# 1  2010-10-06  Pistons           Jonas Jerebko
# 2  2010-10-06  Pistons           Terrico White
# 3  2010-10-08  Blazers              Jeff Ayres
# 4  2010-10-08     Nets             Troy Murphy
#
#                                                       Notes  \
# 0   fractured bone in right pinky finger (out indefinitely)
# 1             torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out indefinitely)
# 3                 torn ACL in right knee (out indefinitely)
# 4                    strained lower back (out indefinitely)
#
#   Relinquished_Acquired
# 0         Carlos Boozer
# 1         Jonas Jerebko
# 2         Terrico White
# 3            Jeff Ayres
# 4           Troy Murphy

# %%
df2.drop('Notes', axis=1)
# Out:
#              Date     Team      Acquired   Relinquished Relinquished_Acquired
# 0      2010-10-03    Bulls                Carlos Boozer         Carlos Boozer
# 1      2010-10-06  Pistons                Jonas Jerebko         Jonas Jerebko
# 2      2010-10-06  Pistons                Terrico White         Terrico White
# 3      2010-10-08  Blazers                   Jeff Ayres            Jeff Ayres
# 4      2010-10-08     Nets                  Troy Murphy           Troy Murphy
# ...           ...      ...           ...            ...                   ...
# 27100  2020-09-30   Lakers  Dion Waiters                         Dion Waiters
# 27101  2020-10-02     Heat                  Bam Adebayo           Bam Adebayo
# 27102  2020-10-02     Heat                 Goran Dragic          Goran Dragic
# 27103  2020-10-02     Heat   Chris Silva                          Chris Silva
# 27104  2020-10-06     Heat   Bam Adebayo                          Bam Adebayo
#
# [27104 rows x 5 columns]

# %%
df2.drop('Notes', axis=1).value_counts()
# Out:
# Date        Team       Acquired          Relinquished       Relinquished_Acquired
# 2019-11-06  Raptors                      Patrick McCaw      Patrick McCaw            3
# 2018-11-28  Mavericks  Dennis Smith Jr.                     Dennis Smith Jr.         2
# 2019-11-12  Rockets                      Eric Gordon        Eric Gordon              2
# 2012-02-22  Rockets                      Terrence Williams  Terrence Williams        2
# 2018-04-27  Wizards                      Otto Porter Jr.    Otto Porter Jr.          2
#                                                                                     ..
# 2017-03-06  Pelicans   Jarrett Jack                         Jarrett Jack             1
#             Spurs                        Joel Anthony       Joel Anthony             1
#                        Manu Ginobili                        Manu Ginobili            1
# 2017-03-07  Jazz                         Derrick Favors     Derrick Favors           1
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
df2.drop('Notes', axis=1).value_counts().head(222).plot(kind='barh', ax=ax)
 
ax.set_title('Date Count')
 
ax.set_xlabel('Count')
ax.set_ylabel('Date')

plt.subplots_adjust(wspace=0.5);

# %%
df2.head()
# Date, Team, Acquired, Relinquished == Date, Team, Acquired, Relinquished, then get index
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls           Carlos Boozer
# 1  2010-10-06  Pistons           Jonas Jerebko
# 2  2010-10-06  Pistons           Terrico White
# 3  2010-10-08  Blazers              Jeff Ayres
# 4  2010-10-08     Nets             Troy Murphy
#
#                                                       Notes  \
# 0   fractured bone in right pinky finger (out indefinitely)
# 1             torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out indefinitely)
# 3                 torn ACL in right knee (out indefinitely)
# 4                    strained lower back (out indefinitely)
#
#   Relinquished_Acquired
# 0         Carlos Boozer
# 1         Jonas Jerebko
# 2         Terrico White
# 3            Jeff Ayres
# 4           Troy Murphy

# %%
#df2['Notes'] = df2.groupby(['Date', 'Team', 'Acquired', 'Relinquished'])['Notes'].transform(lambda x: ','.join(x))

# %%
df2.groupby(['Date', 'Team', 'Acquired', 'Relinquished'])['Notes'].apply(lambda x: ','.join(x)).reset_index()
# Out:
#              Date     Team      Acquired   Relinquished  \
# 0      2010-10-03    Bulls                Carlos Boozer
# 1      2010-10-06  Pistons                Jonas Jerebko
# 2      2010-10-06  Pistons                Terrico White
# 3      2010-10-08  Blazers                   Jeff Ayres
# 4      2010-10-08     Nets                  Troy Murphy
# ...           ...      ...           ...            ...
# 26943  2020-09-30   Lakers  Dion Waiters
# 26944  2020-10-02     Heat                  Bam Adebayo
# 26945  2020-10-02     Heat                 Goran Dragic
# 26946  2020-10-02     Heat   Chris Silva
# 26947  2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#combine redundant rows and append 'Notes' with ';' separator

#https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df2 = df2.groupby(['Date', 'Team', 'Acquired', 'Relinquished'])['Notes'].apply('; '.join).reset_index()
df2
# Out:
#              Date     Team      Acquired   Relinquished  \
# 0      2010-10-03    Bulls                Carlos Boozer
# 1      2010-10-06  Pistons                Jonas Jerebko
# 2      2010-10-06  Pistons                Terrico White
# 3      2010-10-08  Blazers                   Jeff Ayres
# 4      2010-10-08     Nets                  Troy Murphy
# ...           ...      ...           ...            ...
# 26943  2020-09-30   Lakers  Dion Waiters
# 26944  2020-10-02     Heat                  Bam Adebayo
# 26945  2020-10-02     Heat                 Goran Dragic
# 26946  2020-10-02     Heat   Chris Silva
# 26947  2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#df2.groupby(['Date', 'Team', 'Acquired', 'Relinquished'])['Notes'].apply(','.join).reset_index().drop('Notes', axis=1).value_counts()

# %%
df2.shape
# Out:
# (26948, 5)

# %%
#'Team' in injuries_2010-2020 to 'team_id'

# %%
df3.head()
# Out:
#    league_id     team_id  min_year  max_year abbreviation
# 0          0  1610612737    1949.0    2018.0          ATL
# 1          0  1610612738    1946.0    2018.0          BOS
# 2          0  1610612739    1970.0    2018.0          CLE
# 3          0  1610612740    2002.0    2018.0          NOP
# 4          0  1610612741    1966.0    2018.0          CHI

# %%
df2['Team'].unique()
# Out:
# array(['Bulls', 'Pistons', 'Blazers', 'Nets', 'Nuggets', 'Bucks', 'Kings',
#        'Bobcats', 'Warriors', 'Suns', 'Heat', 'Thunder', 'Timberwolves',
#        'Celtics', 'Lakers', 'Rockets', '76ers', 'Cavaliers', 'Clippers',
#        'Grizzlies', 'Hawks', 'Hornets', 'Jazz', 'Knicks', 'Mavericks',
#        'Pacers', 'Raptors', 'Spurs', 'Magic', 'Wizards', 'Pelicans'],
#       dtype=object)

# %%
df2['Team'].unique().shape
# Out:
# (31,)

# %%
df.[team_id]
# Out:
# (57,)

# %%
df5.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded  \
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966
#
#                                                                               url
# 0  https://content.sportslogos.net/logos/6/220/full/kqhjtzl2ik3gnxsnwsn8yf002.gif
# 1  https://content.sportslogos.net/logos/6/213/full/slhg02hbef3j1ov4lsnwyol5o.png
# 2   https://cdn.statmuse.com/img/nba/players/old_nba_cavs_1995_2003--dba8iauk.png
# ...

# %%
df5[['id', 'nickname']]
# Out:
#             id       nickname
# 0   1610612737          Hawks
# 1   1610612738        Celtics
# 2   1610612739      Cavaliers
# 3   1610612740       Pelicans
# 4   1610612741          Bulls
# 5   1610612742      Mavericks
# 6   1610612743        Nuggets
# 7   1610612744       Warriors
# 8   1610612745        Rockets
# 9   1610612746       Clippers
# 10  1610612747         Lakers
# 11  1610612748           Heat
# 12  1610612749          Bucks
# 13  1610612750   Timberwolves
# 14  1610612751           Nets
# 15  1610612752         Knicks
# 16  1610612753          Magic
# 17  1610612754         Pacers
# 18  1610612755          76ers
# 19  1610612756           Suns
# 20  1610612757  Trail Blazers
# 21  1610612758          Kings
# 22  1610612759          Spurs
# 23  1610612760        Thunder
# 24  1610612761        Raptors
# 25  1610612762           Jazz
# 26  1610612763      Grizzlies
# 27  1610612764        Wizards
# 28  1610612765        Pistons
# 29  1610612766        Hornets

# %%
#What nicknames are present in 'injuries_2010-2020.csv', but not in id_nickname pairs of 'nba_teams.csv'

# %%
set1 = set(df5['nickname'])
set1
# Out:
# {'76ers',
#  'Bucks',
#  'Bulls',
#  'Cavaliers',
#  'Celtics',
#  'Clippers',
#  'Grizzlies',
#  'Hawks',
#  'Heat',
#  'Hornets',
#  'Jazz',
#  'Kings',
#  'Knicks',
#  'Lakers',
#  'Magic',
#  'Mavericks',
#  'Nets',
#  'Nuggets',
#  'Pacers',
#  'Pelicans',
#  'Pistons',
#  'Raptors',
#  'Rockets',
#  'Spurs',
#  'Suns',
#  'Thunder',
#  'Timberwolves',
#  'Trail Blazers',
#  'Warriors',
#  'Wizards'}

# %%
len(set(df5['nickname']))
# Out:
# 30

# %%
set2 = set((df2['Team']))
set2
# Out:
# {'76ers',
#  'Blazers',
#  'Bobcats',
#  'Bucks',
#  'Bulls',
#  'Cavaliers',
#  'Celtics',
#  'Clippers',
#  'Grizzlies',
#  'Hawks',
#  'Heat',
#  'Hornets',
#  'Jazz',
#  'Kings',
#  'Knicks',
#  'Lakers',
#  'Magic',
#  'Mavericks',
#  'Nets',
#  'Nuggets',
#  'Pacers',
#  'Pelicans',
#  'Pistons',
#  'Raptors',
#  'Rockets',
#  'Spurs',
#  'Suns',
#  'Thunder',
#  'Timberwolves',
#  'Warriors',
#  'Wizards'}

# %%
set1 - set2
# Out:
# {'Trail Blazers'}

# %%
set2 - set1
# Out:
# {'Blazers', 'Bobcats'}

# %%
df2.head()
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls           Carlos Boozer
# 1  2010-10-06  Pistons           Jonas Jerebko
# 2  2010-10-06  Pistons           Terrico White
# 3  2010-10-08  Blazers              Jeff Ayres
# 4  2010-10-08     Nets             Troy Murphy
#
#                                                       Notes
# 0   fractured bone in right pinky finger (out indefinitely)
# 1             torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out indefinitely)
# 3                 torn ACL in right knee (out indefinitely)
# 4                    strained lower back (out indefinitely)

# %%
df.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2  20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3  20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4  20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
#
#    w_pct  min   fgm    fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0  0.569  240  39.0   74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 1  0.542  240  37.0   68.0   0.544   5.0  20.0    0.250  29.0  37.0     1.0
# 2  0.600  240  37.0   71.0   0.521   7.0  19.0    0.368  20.0  27.0     1.0
# 3  0.605  240  39.0   85.0   0.459   8.0  18.0    0.444  34.0  37.0     1.0
# 4  0.563  290  49.0  100.0   0.490   5.0  13.0    0.385  12.0  18.0     1.0
#
# ...

# %%
df6.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
df6['NICKNAME'].unique()
# Out:
# array(['Hawks', 'Celtics', 'Pelicans', 'Bulls', 'Mavericks', 'Nuggets',
#        'Rockets', 'Clippers', 'Lakers', 'Heat', 'Bucks', 'Timberwolves',
#        'Nets', 'Knicks', 'Magic', 'Pacers', '76ers', 'Suns',
#        'Trail Blazers', 'Kings', 'Spurs', 'Thunder', 'Raptors', 'Jazz',
#        'Grizzlies', 'Wizards', 'Pistons', 'Hornets', 'Cavaliers',
#        'Warriors'], dtype=object)

# %%
len(df6['NICKNAME'].unique())
# Out:
# 30

# %%
#result = grouped.transform(lambda x: ','.join(x))

# %%
#result

# %%
#df2.drop('Notes', axis=1).value_counts()

# %%
#df2.loc['Acquired'].notnull() & df2.loc['Relinquished'].notnull()

# %%
#df2['Acquired_Relinquished'] =

# %%
df2.iloc[:,[2,3]]
# Out:
#            Acquired   Relinquished
# 0                    Carlos Boozer
# 1                    Jonas Jerebko
# 2                    Terrico White
# 3                       Jeff Ayres
# 4                      Troy Murphy
# ...             ...            ...
# 26943  Dion Waiters
# 26944                  Bam Adebayo
# 26945                 Goran Dragic
# 26946   Chris Silva
# 26947   Bam Adebayo
#
# [26948 rows x 2 columns]

# %%
df2['Acquired']
# Out:
# 0
# 1
# 2
# 3
# 4
#              ...
# 26943    Dion Waiters
# 26944
# 26945
# 26946     Chris Silva
# 26947     Bam Adebayo
# Name: Acquired, Length: 26948, dtype: object

# %%
df3.head()
# Out:
#    league_id     team_id  min_year  max_year abbreviation
# 0          0  1610612737    1949.0    2018.0          ATL
# 1          0  1610612738    1946.0    2018.0          BOS
# 2          0  1610612739    1970.0    2018.0          CLE
# 3          0  1610612740    2002.0    2018.0          NOP
# 4          0  1610612741    1966.0    2018.0          CHI

# %%
df3.team_id.unique()
# Out:
# array([1610612737, 1610612738, 1610612739, 1610612740, 1610612741,
#        1610612742, 1610612743, 1610612744, 1610612745, 1610612746,
#        1610612747, 1610612748, 1610612749, 1610612750, 1610612751,
#        1610612752, 1610612753, 1610616834, 1610616833,      12306,
#             12303,      12313,      12316,         45,      12308,
#             12304,      12320,      12315,         94,      12321,
#             12324,         93,         41,      12325,      12323,
#             12330,      15015,      15018,      12329,      15016,
#             15017, 1610612754, 1610612755, 1610612756, 1610612757,
#        1610612758, 1610612759, 1610612760, 1610612761, 1610612762,
#        1610612763, 1610612764, 1610612765, 1610612766, 1610610029,
#        1610610025, 1610610034, 1610610036, 1610610024, 1610610031,
#        1610610027, 1610610030, 1610610033, 1610610037, 1610610023,
#        1610610026, 1610610028, 1610610032, 1610610035], dtype=int64)

# %%
df3.team_id.unique().shape
# Out:
# (69,)

# %%
df4.head()
# Out:
#    person_id display_last_comma_first   display_first_last rosterstatus  \
# 0      76001          Abdelnaby, Alaa       Alaa Abdelnaby            f
# 1      76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz            f
# 2      76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar            f
# 3         51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf            f
# 4       1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad            f
#
#    from_year  to_year                   playercode games_played_flag  \
# 0     1990.0   1994.0       HISTADD_alaa_abdelnaby                 Y
# 1     1968.0   1977.0      HISTADD_zaid_abdul-aziz                 Y
# 2     1969.0   1988.0  HISTADD_kareem_abdul-jabbar                 Y
# 3     1990.0   2000.0           mahmoud_abdul-rauf                 Y
# 4     1997.0   2003.0            tariq_abdul-wahad                 Y
#
#         position  draft_year  draft_round  draft_num  birth_date  height_feet  \
# ...

# %%
df.select_dtypes('object')
# Out:
#          game_date      matchup is_home wl     season_type   season
# 0       2009-02-06  SAC vs. UTA       f  W  Regular Season  2008-09
# 1       2009-01-31  POR vs. UTA       f  L  Regular Season  2008-09
# 2       2009-01-16  MEM vs. UTA       f  W  Regular Season  2008-09
# 3       2009-01-12    IND @ UTA       t  W  Regular Season  2008-09
# 4       2008-12-27  HOU vs. UTA       f  L  Regular Season  2008-09
# ...            ...          ...     ... ..             ...      ...
# 125619  2009-04-03    MIN @ UTA       t  L  Regular Season  2008-09
# 125620  2009-03-24    HOU @ UTA       t  W  Regular Season  2008-09
# 125621  2009-03-20  OKC vs. UTA       f  W  Regular Season  2008-09
# 125622  2009-02-23    ATL @ UTA       t  W  Regular Season  2008-09
# 125623  2009-02-19    BOS @ UTA       t  W  Regular Season  2008-09
#
# [125624 rows x 6 columns]

# %%
#df[''].value_counts().head()

# %%
#missing_x = df[[' ', ' ']].isnull().sum(axis=1)

# %%
df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
#df.loc[5, ' '] = 1111

# %%
df.fga.hist(bins=30)
plt.xlabel('column_name')
plt.ylabel('Count')
plt.title('Distribution of');

# %%
df.fga[df.fga < 1000].describe()
# Out:
# count    90894.000000
# mean        83.156248
# std          9.229457
# min          0.000000
# 25%         77.000000
# 50%         83.000000
# 75%         89.000000
# max        240.000000
# Name: fga, dtype: float64

# %%
df.iloc[115]
# Out:
# game_id              20800935
# game_date          2009-03-07
# matchup           LAC vs. IND
# team_id            1610612754
# is_home                     f
# wl                          W
# w                          28
# l                          37
# w_pct                   0.431
# min                       240
# fgm                        41
# fga                        89
# fg_pct                  0.461
# fg3m                        8
# fg3a                       23
# fg3_pct                 0.348
# ftm                        16
# fta                        19
# ft_pct                      1
# oreb                        9
# dreb                       28
# reb                        37
# ast                        24
# stl                         9
# blk                         4
# tov                         9
# pf                         21
# pts                       106
# a_team_id          1610612746
# season_year              2008
# season_type    Regular Season
# ...

# %%
#type()

# %%
#len()

# %%
df.iloc[:, 4]
# Out:
# 0         f
# 1         f
# 2         f
# 3         t
# 4         f
#          ..
# 125619    t
# 125620    t
# 125621    f
# 125622    t
# 125623    t
# Name: is_home, Length: 125624, dtype: object

# %%
df.iloc[:, [0,5,6]].copy()
# Out:
#          game_id wl     w
# 0       20800741  W  29.0
# 1       20800701  L  26.0
# 2       20800584  W  24.0
# 3       20800558  W  23.0
# 4       20800440  L  18.0
# ...          ... ..   ...
# 125619  20801131  L  46.0
# 125620  20801058  W  44.0
# 125621  20801029  W  43.0
# 125622  20800839  W  34.0
# 125623  20800810  W  32.0
#
# [125624 rows x 3 columns]

# %%
df2.head()
# Out:
#          Date     Team Acquired   Relinquished  \
# 0  2010-10-03    Bulls           Carlos Boozer
# 1  2010-10-06  Pistons           Jonas Jerebko
# 2  2010-10-06  Pistons           Terrico White
# 3  2010-10-08  Blazers              Jeff Ayres
# 4  2010-10-08     Nets             Troy Murphy
#
#                                                       Notes
# 0   fractured bone in right pinky finger (out indefinitely)
# 1             torn right Achilles tendon (out indefinitely)
# 2  broken fifth metatarsal in right foot (out indefinitely)
# 3                 torn ACL in right knee (out indefinitely)
# 4                    strained lower back (out indefinitely)

# %%
#set(df.fga) - set(df2.fga)

# %%
#df.state[df.column_name.str.contains('state1|state2|state3|state4')]

# %%
#regex
#df.column_name.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)

# %%
#df.plot(x='column_name1', y='column_name2', kind='scatter');

# %%
#df.loc[df.column_name == 'state1', ['column_name', 'column_name']]

# %%
#missing = pd.concat([df.isnull().sum(axis=1), 100 * df.isnull().mean(axis=1)], axis=1)
#missing.columns=['count', '%']
#missing.sort_values(by='count', ascending=False).head(10)

# %%
#missing['%'].unique()

# %%
#datapath = 'data'

# %%
#if not os.path.exists(datapath):
    #os.mkdir(datapath)

# %%
#datapath_df = os.path.join(datapath, 'df_cleaned.csv')
#if not os.path.exists(datapath_df):
#    df.to_csv(datapath_df, index=False)

# %%
#datapath_df2 = os.path.join(datapath, 'df2.csv')
#if not os.path.exists(datapath_df2):
#    df2.to_csv(datapath_df2, index=False)

# %%
#datapath = 'data'

#if not os.path.exists(datapath):
    #os.mkdir(datapath)
    
#datapath_df = os.path.join(datapath, 'df_cleaned.csv')
#if not os.path.exists(datapath_df):
#    df.to_csv(datapath_df, index=False)

#datapath_df2 = os.path.join(datapath, 'df2.csv')
#if not os.path.exists(datapath_df2):
#    df2.to_csv(datapath_df2, index=False)
