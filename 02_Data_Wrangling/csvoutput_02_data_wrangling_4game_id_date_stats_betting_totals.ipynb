# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Paul\\sb\\DSCapstone2\\02_Data_Wrangling'

# %%
df = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\raw_data\\nba_betting_totals.csv')
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  total1  \
# 0       21100131  Pinnacle Sports      238  1610612740  1610612743   192.0
# 1       21100131           5Dimes       19  1610612740  1610612743   192.0
# 2       21100131        Bookmaker       93  1610612740  1610612743   192.0
# 3       21100131        BetOnline     1096  1610612740  1610612743   191.5
# 4       21100131           Bovada   999996  1610612740  1610612743   192.0
# ...          ...              ...      ...         ...         ...     ...
# 131381  41700215         Heritage      169  1610612755  1610612738   204.5
# 131382  41700215        Intertops      180  1610612755  1610612738   205.0
# 131383  41700215         YouWager      139  1610612755  1610612738   204.5
# 131384  41700215          JustBet     1275  1610612755  1610612738   204.0
# 131385  41700215    Sportsbetting   999991  1610612755  1610612738   204.5
#
#         total2  price1  price2
# 0        192.0  -105.0  -105.0
# ...

# %%
df = df.iloc[df.game_id.drop_duplicates().index]
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  total1  \
# 0       21100131  Pinnacle Sports      238  1610612740  1610612743   192.0
# 10      21100137  Pinnacle Sports      238  1610612760  1610612763   193.5
# 20      21100148  Pinnacle Sports      238  1610612760  1610612740   183.5
# 30      21100149  Pinnacle Sports      238  1610612745  1610612759   198.5
# 40      21100152  Pinnacle Sports      238  1610612753  1610612757   186.0
# ...          ...              ...      ...         ...         ...     ...
# 131336  41700212  Pinnacle Sports      238  1610612755  1610612738   206.5
# 131346  41700233  Pinnacle Sports      238  1610612744  1610612740   233.5
# 131356  41700213  Pinnacle Sports      238  1610612738  1610612755   206.5
# 131366  41700234  Pinnacle Sports      238  1610612744  1610612740   231.0
# 131376  41700215  Pinnacle Sports      238  1610612755  1610612738   204.5
#
#         total2  price1  price2
# 0        192.0  -105.0  -105.0
# ...

# %%
#df.iloc[df.game_id.drop_duplicates().index]['book_name'].value_counts()

# %%
df2 = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data\\3game_date_home_away.csv', parse_dates=['game_date'])
df2
# Out:
#         game_id  game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0      20600001 2006-10-31    1610612748       0.000       240      25.0
# 1      20600002 2006-10-31    1610612747       1.000       240      46.0
# 2      20600003 2006-11-01    1610612755       1.000       240      31.0
# 3      20600004 2006-11-01    1610612766       0.000       240      37.0
# 4      20600005 2006-11-01    1610612753       1.000       240      35.0
# ...         ...        ...           ...         ...       ...       ...
# 15514  41700317 2018-05-28    1610612745       0.429       240      36.0
# 15515  41700401 2018-05-31    1610612744       1.000       265      46.0
# 15516  41700402 2018-06-03    1610612744       1.000       240      47.0
# 15517  41700403 2018-06-06    1610612739       0.000       240      40.0
# 15518  41700404 2018-06-08    1610612739       0.000       240      30.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  ...  dreb_away  reb_away  \
# ...

# %%
pd.merge(df2, df, on='game_id', how='right')
# Out:
#         game_id  game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0      21100131 2012-01-09  1.610613e+09       0.600     240.0      29.0
# 1      21100137 2012-01-10  1.610613e+09       0.333     240.0      39.0
# 2      21100148 2012-01-11  1.610613e+09       0.300     240.0      36.0
# 3      21100149 2012-01-11  1.610613e+09       0.636     265.0      42.0
# 4      21100152 2012-01-11  1.610613e+09       0.700     240.0      41.0
# ...         ...        ...           ...         ...       ...       ...
# 14913  41700212 2018-05-03  1.610613e+09       1.000     240.0      37.0
# 14914  41700233 2018-05-04  1.610613e+09       0.333     240.0      48.0
# 14915  41700213 2018-05-05  1.610613e+09       0.000     265.0      38.0
# 14916  41700234 2018-05-06  1.610613e+09       0.250     240.0      32.0
# 14917  41700215 2018-05-09  1.610613e+09       0.800     240.0      38.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  ...     season_type  \
# ...

# %% [markdown]
# <font color='red'> why is team_id_home going to float????<font>

# %%
pd.merge(df2, df, on='game_id', how='right').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14918 entries, 0 to 14917
# Data columns (total 55 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       14918 non-null  int64
#  1   game_date     14886 non-null  datetime64[ns]
#  2   team_id_home  14886 non-null  float64
#  3   w_pct_home    14886 non-null  float64
#  4   min_home      14886 non-null  float64
#  5   fgm_home      14886 non-null  float64
#  6   fga_home      14886 non-null  float64
#  7   fg_pct_home   14886 non-null  float64
#  8   fg3m_home     14886 non-null  float64
#  9   fg3a_home     14886 non-null  float64
#  10  fg3_pct_home  14886 non-null  float64
#  11  ftm_home      14886 non-null  float64
#  12  fta_home      14886 non-null  float64
#  13  ft_pct_home   14886 non-null  float64
#  14  oreb_home     14886 non-null  float64
#  15  dreb_home     14886 non-null  float64
#  16  reb_home      14886 non-null  float64
# ...

# %%
df = pd.merge(df2, df, on='game_id', how='left')
df
# Out:
#         game_id  game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0      20600001 2006-10-31    1610612748       0.000       240      25.0
# 1      20600002 2006-10-31    1610612747       1.000       240      46.0
# 2      20600003 2006-11-01    1610612755       1.000       240      31.0
# 3      20600004 2006-11-01    1610612766       0.000       240      37.0
# 4      20600005 2006-11-01    1610612753       1.000       240      35.0
# ...         ...        ...           ...         ...       ...       ...
# 15514  41700317 2018-05-28    1610612745       0.429       240      36.0
# 15515  41700401 2018-05-31    1610612744       1.000       265      46.0
# 15516  41700402 2018-06-03    1610612744       1.000       240      47.0
# 15517  41700403 2018-06-06    1610612739       0.000       240      40.0
# 15518  41700404 2018-06-08    1610612739       0.000       240      30.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  ...     season_type  \
# ...

# %%
pd.merge(df2, df, on='game_id', how='left').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15519 entries, 0 to 15518
# Columns: 101 entries, game_id to price2
# dtypes: datetime64[ns](2), float64(77), int64(17), object(5)
# memory usage: 12.1+ MB

# %%
datapath = 'C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data'

if not os.path.exists(datapath):
    os.mkdir(datapath)
    
datapath_df = os.path.join(datapath, '4game_id_date_stats_betting_totals.csv')
if not os.path.exists(datapath_df):
    df.to_csv(datapath_df, index=False)
