# %%
#get team boxscores advance and team boxscore for the 2010-11 thru 2017-18 seasons

#merge 'df_tbsa1018' and 'df_tbs1018'

#drop duplicate columns

###########################################################//////////////////////////

#check for equality between team_id_away and TEAM_ID_away

#check for equality between team_id_home and TEAM_ID_home

#drop TEAM_ID_away if equal to team_id_away

#drop TEAM_ID_home if equal to team_id_home


################################################///////////////////////////////////////

# %%
#data definition...

#data types

#####################///////////////////////

#description of the columns

#counts of the columns

#ranges of values of the columns

#get mean, median, standard deviation, and range if not done already


###########################################//////////////////////////

#percentage unique values of the columns

######################################///////////////////////////////////////

#get mode and number of unique value if not done already

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np


pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
#return the first 5 and last 5 rows of this dataframe
def p(df_):
    if df_.shape[0] > 6:
        print(df_.shape)
        return pd.concat([df_.head(), df_.tail()])
    else:
        return df_

def rcp(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'processed_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'processed_data', file_), parse_dates=pd_)
    
def rcr(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'raw_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'raw_data', file_), parse_dates=pd_)

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
df_tbsa1018 = rcp('20boxscoreadvancedv2_team_away_home_2010_2018.csv')
p(df_tbsa1018)
# Out:
# (10266, 62)
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2010-10-26           Heat                    MIA
# 1      21000002  2010-10-26           Suns                    PHX
# 2      21000003  2010-10-26        Rockets                    HOU
# 3      21000015  2010-10-27        Rockets                    HOU
# 4      21000014  2010-10-27           Jazz                    UTA
# 10261  41700317  2018-05-28       Warriors                    GSW
# 10262  41700401  2018-05-31      Cavaliers                    CLE
# 10263  41700402  2018-06-03      Cavaliers                    CLE
# 10264  41700403  2018-06-06       Warriors                    GSW
# 10265  41700404  2018-06-08       Warriors                    GSW
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0              Miami   240:00  0 days 04:00:00        Celtics
# 1            Phoenix   240:00  0 days 04:00:00  Trail Blazers
# ...

# %%
df_tbs1018 = rcp('18game_id_team_id_home_away_2010_2018.csv')
p(df_tbs1018)
# Out:
# (10267, 49)
#         game_id   game_date  team_id_away wl_away  w_pct_away  min_away  \
# 0      21000002  2010-10-26    1610612756       L       0.000       240
# 1      21000001  2010-10-26    1610612748       L       0.000       240
# 2      21000003  2010-10-26    1610612745       L       0.000       240
# 3      21000005  2010-10-27    1610612765       L       0.000       240
# 4      21000004  2010-10-27    1610612738       L       0.500       240
# 10262  41700317  2018-05-28    1610612744       W       0.571       240
# 10263  41700401  2018-05-31    1610612739       L       0.000       265
# 10264  41700402  2018-06-03    1610612739       L       0.000       240
# 10265  41700403  2018-06-06    1610612744       W       1.000       240
# 10266  41700404  2018-06-08    1610612744       W       1.000       240
#
#        fgm_away  fga_away  fg_pct_away  fg3m_away  fg3a_away  fg3_pct_away  \
# 0            36        74        0.486          9         19         0.474
# ...

# %%
df_tbsatbs1018 = pd.merge(df_tbsa1018, df_tbs1018, on=['game_id', 'game_date'], how='inner')
p(df_tbsatbs1018)
# Out:
# (10266, 109)
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2010-10-26           Heat                    MIA
# 1      21000002  2010-10-26           Suns                    PHX
# 2      21000003  2010-10-26        Rockets                    HOU
# 3      21000015  2010-10-27        Rockets                    HOU
# 4      21000014  2010-10-27           Jazz                    UTA
# 10261  41700317  2018-05-28       Warriors                    GSW
# 10262  41700401  2018-05-31      Cavaliers                    CLE
# 10263  41700402  2018-06-03      Cavaliers                    CLE
# 10264  41700403  2018-06-06       Warriors                    GSW
# 10265  41700404  2018-06-08       Warriors                    GSW
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0              Miami   240:00  0 days 04:00:00        Celtics
# 1            Phoenix   240:00  0 days 04:00:00  Trail Blazers
# ...

# %%
list(df_tbsatbs1018.columns)
# Out:
# ['game_id',
#  'game_date',
#  'TEAM_NAME_away',
#  'TEAM_ABBREVIATION_away',
#  'TEAM_CITY_away',
#  'MIN_away',
#  'duration_away',
#  'TEAM_NAME_home',
#  'TEAM_ABBREVIATION_home',
#  'TEAM_CITY_home',
#  'MIN_home',
#  'duration_home',
#  'TEAM_ID_away',
#  'E_OFF_RATING_away',
#  'OFF_RATING_away',
#  'E_DEF_RATING_away',
#  'DEF_RATING_away',
#  'E_NET_RATING_away',
#  'NET_RATING_away',
#  'AST_PCT_away',
#  'AST_TOV_away',
#  'AST_RATIO_away',
#  'OREB_PCT_away',
#  'DREB_PCT_away',
#  'REB_PCT_away',
#  'E_TM_TOV_PCT_away',
#  'TM_TOV_PCT_away',
#  'EFG_PCT_away',
#  'TS_PCT_away',
#  'USG_PCT_away',
#  'E_USG_PCT_away',
#  'E_PACE_away',
#  'PACE_away',
#  'PACE_PER40_away',
#  'POSS_away',
#  'PIE_away',
#  'duration_minutes_away',
#  'TEAM_ID_home',
#  'E_OFF_RATING_home',
#  'OFF_RATING_home',
#  'E_DEF_RATING_home',
#  'DEF_RATING_home',
#  'E_NET_RATING_home',
#  'NET_RATING_home',
#  'AST_PCT_home',
#  'AST_TOV_home',
#  'AST_RATIO_home',
#  'OREB_PCT_home',
# ...

# %%
df_tbsatbs1018 = df_tbsatbs1018.sort_values('game_date').reset_index(drop=True)
p(df_tbsatbs1018)
# Out:
# (10266, 109)
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2010-10-26           Heat                    MIA
# 1      21000002  2010-10-26           Suns                    PHX
# 2      21000003  2010-10-26        Rockets                    HOU
# 3      21000016  2010-10-27  Trail Blazers                    POR
# 4      21000004  2010-10-27        Celtics                    BOS
# 10261  41700317  2018-05-28       Warriors                    GSW
# 10262  41700401  2018-05-31      Cavaliers                    CLE
# 10263  41700402  2018-06-03      Cavaliers                    CLE
# 10264  41700403  2018-06-06       Warriors                    GSW
# 10265  41700404  2018-06-08       Warriors                    GSW
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0              Miami   240:00  0 days 04:00:00        Celtics
# 1            Phoenix   240:00  0 days 04:00:00  Trail Blazers
# ...

# %%
#check for equality between team_id_away and TEAM_ID_away

#check for equality between team_id_home and TEAM_ID_home

#drop TEAM_ID_away if equal to team_id_away

#drop TEAM_ID_home if equal to team_id_home

# %%
#check for equality between team_id_away and TEAM_ID_away

(df_tbsatbs1018['team_id_away'] - df_tbsatbs1018['TEAM_ID_away']).value_counts()
# Out:
# 0    10266
# dtype: int64

# %%
#check for equality between team_id_home and TEAM_ID_home

# %%
(df_tbsatbs1018['team_id_home'] - df_tbsatbs1018['TEAM_ID_home']).value_counts()
# Out:
# 0    10266
# dtype: int64

# %%
#drop TEAM_ID_away if equal to team_id_away

df_tbsatbs1018.drop(columns=['TEAM_ID_away'], inplace=True)

#drop TEAM_ID_home if equal to team_id_home

df_tbsatbs1018.drop(columns=['TEAM_ID_home'], inplace=True)

# %%
p(df_tbsatbs1018)
# Out:
# (10266, 107)
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2010-10-26           Heat                    MIA
# 1      21000002  2010-10-26           Suns                    PHX
# 2      21000003  2010-10-26        Rockets                    HOU
# 3      21000016  2010-10-27  Trail Blazers                    POR
# 4      21000004  2010-10-27        Celtics                    BOS
# 10261  41700317  2018-05-28       Warriors                    GSW
# 10262  41700401  2018-05-31      Cavaliers                    CLE
# 10263  41700402  2018-06-03      Cavaliers                    CLE
# 10264  41700403  2018-06-06       Warriors                    GSW
# 10265  41700404  2018-06-08       Warriors                    GSW
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0              Miami   240:00  0 days 04:00:00        Celtics
# 1            Phoenix   240:00  0 days 04:00:00  Trail Blazers
# ...

# %%
#data definition...

#data types

#description of the columns

#counts of the columns

#ranges of values of the columns

###########################////////////////////////////

#percentage unique values of the columns

###############///////////////////////////////////////

#

# %%
#data types
pd.options.display.max_info_columns = 999

df_tbsatbs1018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10266 entries, 0 to 10265
# Data columns (total 107 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 10266 non-null  int64
#  1   game_date               10266 non-null  object
#  2   TEAM_NAME_away          10266 non-null  object
#  3   TEAM_ABBREVIATION_away  10266 non-null  object
#  4   TEAM_CITY_away          10266 non-null  object
#  5   MIN_away                10266 non-null  object
#  6   duration_away           10266 non-null  object
#  7   TEAM_NAME_home          10266 non-null  object
#  8   TEAM_ABBREVIATION_home  10266 non-null  object
#  9   TEAM_CITY_home          10266 non-null  object
#  10  MIN_home                10266 non-null  object
#  11  duration_home           10266 non-null  object
#  12  E_OFF_RATING_away       10266 non-null  float64
#  13  OFF_RATING_away         10266 non-null  float64
# ...

# %% [markdown]
# <font color='red'> object vs string use????</font>

# %%
#description of the columns

#counts of the columns

#ranges of values of the columns

#get mean, median, standard deviation, and range if not done already

pd.set_option('display.float_format', lambda x: '%.3f' % x)
df_tbsatbs1018.describe().T
# Out:
#                           count           mean         std            min  \
# game_id               10266.000   22655759.071 4932983.875   21000001.000
# E_OFF_RATING_away     10266.000        102.681      11.281         60.700
# OFF_RATING_away       10266.000        104.441      11.170         60.900
# E_DEF_RATING_away     10266.000        105.768      11.146         65.700
# DEF_RATING_away       10266.000        107.396      10.968         68.100
# E_NET_RATING_away     10266.000         -3.088      14.529        -58.300
# NET_RATING_away       10266.000         -2.955      13.962        -63.100
# AST_PCT_away          10266.000          0.572       0.104          0.167
# AST_TOV_away          10266.000          1.613       0.676          0.290
# AST_RATIO_away        10266.000         16.468       3.242          3.700
# OREB_PCT_away         10266.000          0.248       0.117          0.000
# DREB_PCT_away         10266.000          0.611       0.253          0.000
# ...

# %% [markdown]
# <font color='red'> why are we getting floats for game_id????</font>

# %% [markdown]
# <font color='red'> why are we unable to see the last digit of the game_id's here??????</font>

# %%
#percentage unique values of the columns

############ ###///////////////////////////////////////

#get mode and number of unique value if not done already

# %%
list(df_tbsatbs1018.columns)
# Out:
# ['game_id',
#  'game_date',
#  'TEAM_NAME_away',
#  'TEAM_ABBREVIATION_away',
#  'TEAM_CITY_away',
#  'MIN_away',
#  'duration_away',
#  'TEAM_NAME_home',
#  'TEAM_ABBREVIATION_home',
#  'TEAM_CITY_home',
#  'MIN_home',
#  'duration_home',
#  'E_OFF_RATING_away',
#  'OFF_RATING_away',
#  'E_DEF_RATING_away',
#  'DEF_RATING_away',
#  'E_NET_RATING_away',
#  'NET_RATING_away',
#  'AST_PCT_away',
#  'AST_TOV_away',
#  'AST_RATIO_away',
#  'OREB_PCT_away',
#  'DREB_PCT_away',
#  'REB_PCT_away',
#  'E_TM_TOV_PCT_away',
#  'TM_TOV_PCT_away',
#  'EFG_PCT_away',
#  'TS_PCT_away',
#  'USG_PCT_away',
#  'E_USG_PCT_away',
#  'E_PACE_away',
#  'PACE_away',
#  'PACE_PER40_away',
#  'POSS_away',
#  'PIE_away',
#  'duration_minutes_away',
#  'E_OFF_RATING_home',
#  'OFF_RATING_home',
#  'E_DEF_RATING_home',
#  'DEF_RATING_home',
#  'E_NET_RATING_home',
#  'NET_RATING_home',
#  'AST_PCT_home',
#  'AST_TOV_home',
#  'AST_RATIO_home',
#  'OREB_PCT_home',
#  'DREB_PCT_home',
#  'REB_PCT_home',
# ...

# %%
#percentage unique values of the columns

df_tbsatbs1018.TEAM_NAME_away.value_counts(normalize=True).head()
# Out:
# Spurs       0.036
# Heat        0.036
# Warriors    0.036
# Thunder     0.036
# Cavaliers   0.035
# Name: TEAM_NAME_away, dtype: float64

# %%
number = 0

# %%
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 21600253   0.000
# 21300754   0.000
# 21200205   0.000
# 21400907   0.000
# 21300554   0.000
# Name: game_id, dtype: float64
# 2011-04-13   0.001
# 2014-04-16   0.001
# 2016-11-25   0.001
# 2013-04-17   0.001
# 2012-04-18   0.001
# Name: game_date, dtype: float64
# Spurs       0.036
# Heat        0.036
# Warriors    0.036
# Thunder     0.036
# Cavaliers   0.035
# Name: TEAM_NAME_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# SAS   0.036
# MIA   0.036
# GSW   0.036
# OKC   0.036
# CLE   0.035
# Name: TEAM_ABBREVIATION_away, dtype: float64
# Los Angeles     0.054
# San Antonio     0.036
# Miami           0.036
# Golden State    0.036
# Oklahoma City   0.036
# Name: TEAM_CITY_away, dtype: float64
# 240:00   0.938
# 265:00   0.053
# 290:00   0.007
# 315:00   0.002
# 340:00   0.000
# Name: MIN_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0 days 04:00:00   0.938
# 0 days 04:25:00   0.053
# 0 days 04:50:00   0.007
# 0 days 05:15:00   0.002
# 0 days 05:40:00   0.000
# Name: duration_away, dtype: float64
# Heat       0.037
# Warriors   0.036
# Spurs      0.036
# Thunder    0.036
# Celtics    0.035
# Name: TEAM_NAME_home, dtype: float64
# MIA   0.037
# GSW   0.036
# SAS   0.036
# OKC   0.036
# BOS   0.035
# Name: TEAM_ABBREVIATION_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# Los Angeles     0.054
# Miami           0.037
# Golden State    0.036
# San Antonio     0.036
# Oklahoma City   0.036
# Name: TEAM_CITY_home, dtype: float64
# 240:00   0.938
# 265:00   0.053
# 290:00   0.007
# 315:00   0.002
# 340:00   0.000
# Name: MIN_home, dtype: float64
# 0 days 04:00:00   0.938
# 0 days 04:25:00   0.053
# 0 days 04:50:00   0.007
# 0 days 05:15:00   0.002
# 0 days 05:40:00   0.000
# Name: duration_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 100.000   0.005
# 107.200   0.005
# 104.300   0.005
# 105.600   0.005
# 105.900   0.005
# Name: E_OFF_RATING_away, dtype: float64
# 100.000   0.031
# 98.900    0.019
# 101.100   0.018
# 99.000    0.014
# 101.000   0.012
# Name: OFF_RATING_away, dtype: float64
# 109.600   0.006
# 108.700   0.005
# 103.600   0.005
# 109.100   0.005
# 111.500   0.004
# Name: E_DEF_RATING_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 100.000   0.033
# 101.100   0.019
# 98.900    0.014
# 101.000   0.012
# 99.000    0.011
# Name: DEF_RATING_away, dtype: float64
# -8.100   0.004
# -6.300   0.004
# -7.300   0.004
# -6.600   0.004
# -7.000   0.004
# Name: E_NET_RATING_away, dtype: float64
# -5.300   0.006
# -4.300   0.006
# -2.100   0.006
# -4.200   0.006
# 2.200    0.006
# Name: NET_RATING_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.500   0.041
# 0.667   0.025
# 0.600   0.020
# 0.571   0.016
# 0.514   0.015
# Name: AST_PCT_away, dtype: float64
# 1.000   0.036
# 2.000   0.033
# 1.500   0.024
# 1.060   0.017
# 1.330   0.017
# Name: AST_TOV_away, dtype: float64
# 16.700   0.015
# 15.900   0.014
# 16.900   0.014
# 15.500   0.014
# 16.400   0.013
# Name: AST_RATIO_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.000   0.128
# 0.333   0.027
# 0.250   0.023
# 0.255   0.013
# 0.286   0.013
# Name: OREB_PCT_away, dtype: float64
# 0.000   0.137
# 0.667   0.025
# 0.750   0.020
# 0.714   0.013
# 0.660   0.012
# Name: DREB_PCT_away, dtype: float64
# 0.000   0.244
# 0.500   0.035
# 0.495   0.023
# 0.505   0.022
# 0.490   0.011
# Name: REB_PCT_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 15.823   0.001
# 14.368   0.001
# 17.241   0.001
# 15.158   0.001
# 16.667   0.001
# Name: E_TM_TOV_PCT_away, dtype: float64
# 16.500   0.017
# 16.300   0.016
# 14.900   0.016
# 14.300   0.015
# 16.700   0.015
# Name: TM_TOV_PCT_away, dtype: float64
# 0.500   0.038
# 0.494   0.026
# 0.506   0.024
# 0.488   0.013
# 0.512   0.011
# Name: EFG_PCT_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.523   0.010
# 0.518   0.008
# 0.551   0.008
# 0.537   0.008
# 0.532   0.008
# Name: TS_PCT_away, dtype: float64
# 1.000   1.000
# Name: USG_PCT_away, dtype: float64
# 0.199   0.175
# 0.200   0.170
# 0.198   0.161
# 0.197   0.126
# 0.201   0.117
# Name: E_USG_PCT_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 93.460   0.002
# 95.520   0.002
# 95.600   0.002
# 98.680   0.002
# 95.100   0.002
# Name: E_PACE_away, dtype: float64
# 94.000   0.037
# 95.000   0.036
# 96.000   0.036
# 94.500   0.035
# 93.000   0.034
# Name: PACE_away, dtype: float64
# 78.330   0.037
# 79.170   0.036
# 80.000   0.036
# 78.750   0.035
# 77.500   0.034
# Name: PACE_PER40_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 94   0.078
# 95   0.070
# 96   0.069
# 97   0.066
# 92   0.064
# Name: POSS_away, dtype: float64
# 0.453   0.006
# 0.438   0.006
# 0.443   0.006
# 0.429   0.005
# 0.447   0.005
# Name: PIE_away, dtype: float64
# 240.000   0.938
# 265.000   0.053
# 290.000   0.007
# 315.000   0.002
# 340.000   0.000
# Name: duration_minutes_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 109.600   0.006
# 108.700   0.005
# 103.600   0.005
# 109.100   0.005
# 111.500   0.004
# Name: E_OFF_RATING_home, dtype: float64
# 100.000   0.033
# 101.100   0.019
# 98.900    0.014
# 101.000   0.012
# 99.000    0.011
# Name: OFF_RATING_home, dtype: float64
# 100.000   0.005
# 107.200   0.005
# 104.300   0.005
# 105.600   0.005
# 105.900   0.005
# Name: E_DEF_RATING_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 100.000   0.031
# 98.900    0.019
# 101.100   0.018
# 99.000    0.014
# 101.000   0.012
# Name: DEF_RATING_home, dtype: float64
# 8.100   0.004
# 6.300   0.004
# 7.300   0.004
# 6.600   0.004
# 7.000   0.004
# Name: E_NET_RATING_home, dtype: float64
# 5.300    0.006
# 4.300    0.006
# 2.100    0.006
# 4.200    0.006
# -2.200   0.006
# Name: NET_RATING_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.500   0.034
# 0.667   0.027
# 0.600   0.021
# 0.571   0.015
# 0.605   0.014
# Name: AST_PCT_home, dtype: float64
# 2.000   0.036
# 1.000   0.027
# 1.500   0.021
# 1.670   0.016
# 1.330   0.016
# Name: AST_TOV_home, dtype: float64
# 18.100   0.014
# 17.600   0.013
# 16.000   0.013
# 16.800   0.013
# 17.000   0.013
# Name: AST_RATIO_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.000   0.137
# 0.333   0.025
# 0.250   0.020
# 0.286   0.013
# 0.340   0.012
# Name: OREB_PCT_home, dtype: float64
# 0.000   0.128
# 0.667   0.027
# 0.750   0.023
# 0.745   0.013
# 0.714   0.013
# Name: DREB_PCT_home, dtype: float64
# 0.000   0.245
# 0.500   0.035
# 0.505   0.023
# 0.495   0.022
# 0.510   0.011
# Name: REB_PCT_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 14.286   0.001
# 16.088   0.001
# 13.233   0.001
# 13.777   0.001
# 16.779   0.001
# Name: E_TM_TOV_PCT_home, dtype: float64
# 16.300   0.018
# 14.300   0.016
# 16.500   0.016
# 15.200   0.015
# 14.000   0.015
# Name: TM_TOV_PCT_home, dtype: float64
# 0.500   0.033
# 0.494   0.027
# 0.506   0.026
# 0.488   0.013
# 0.512   0.013
# Name: EFG_PCT_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.538   0.008
# 0.541   0.008
# 0.564   0.008
# 0.550   0.008
# 0.542   0.008
# Name: TS_PCT_home, dtype: float64
# 1.000   1.000
# Name: USG_PCT_home, dtype: float64
# 0.199   0.184
# 0.200   0.168
# 0.198   0.165
# 0.201   0.120
# 0.197   0.115
# Name: E_USG_PCT_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 93.460   0.002
# 95.520   0.002
# 95.600   0.002
# 98.680   0.002
# 95.100   0.002
# Name: E_PACE_home, dtype: float64
# 94.000   0.037
# 95.000   0.036
# 96.000   0.036
# 94.500   0.035
# 93.000   0.034
# Name: PACE_home, dtype: float64
# 78.330   0.037
# 79.170   0.036
# 80.000   0.036
# 78.750   0.035
# 77.500   0.034
# Name: PACE_PER40_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 95   0.073
# 94   0.070
# 93   0.069
# 96   0.068
# 92   0.067
# Name: POSS_home, dtype: float64
# 0.547   0.006
# 0.557   0.006
# 0.571   0.005
# 0.553   0.005
# 0.563   0.005
# Name: PIE_home, dtype: float64
# 240.000   0.938
# 265.000   0.053
# 290.000   0.007
# 315.000   0.002
# 340.000   0.000
# Name: duration_minutes_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 1610612759   0.036
# 1610612748   0.036
# 1610612744   0.036
# 1610612760   0.036
# 1610612739   0.035
# Name: team_id_away, dtype: float64
# L   0.592
# W   0.408
# Name: wl_away, dtype: float64
# 0.500   0.051
# 0.000   0.030
# 0.333   0.027
# 0.667   0.024
# 1.000   0.020
# Name: w_pct_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 240   0.938
# 265   0.053
# 290   0.007
# 315   0.002
# 340   0.000
# Name: min_away, dtype: float64
# 37   0.086
# 39   0.078
# 36   0.075
# 35   0.073
# 38   0.073
# Name: fgm_away, dtype: float64
# 84   0.058
# 83   0.058
# 80   0.055
# 82   0.054
# 81   0.051
# Name: fga_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.500   0.029
# 0.494   0.020
# 0.506   0.019
# 0.488   0.015
# 0.481   0.012
# Name: fg_pct_away, dtype: float64
# 7   0.117
# 6   0.111
# 8   0.106
# 5   0.099
# 9   0.096
# Name: fg3m_away, dtype: float64
# 21   0.056
# 20   0.054
# 23   0.053
# 19   0.052
# 22   0.052
# Name: fg3a_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.333   0.060
# 0.250   0.031
# 0.500   0.031
# 0.400   0.030
# 0.375   0.022
# Name: fg3_pct_away, dtype: float64
# 16   0.067
# 15   0.067
# 14   0.066
# 17   0.066
# 18   0.062
# Name: ftm_away, dtype: float64
# 20   0.061
# 22   0.056
# 21   0.055
# 18   0.053
# 19   0.052
# Name: fta_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 1.000   0.981
# 0.000   0.019
# Name: ft_pct_away, dtype: float64
# 9    0.108
# 10   0.103
# 11   0.101
# 8    0.096
# 12   0.084
# Name: oreb_away, dtype: float64
# 32   0.075
# 30   0.073
# 31   0.071
# 33   0.070
# 29   0.068
# Name: dreb_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 43   0.064
# 41   0.063
# 42   0.062
# 44   0.062
# 40   0.061
# Name: reb_away, dtype: float64
# 20   0.081
# 19   0.079
# 21   0.079
# 22   0.077
# 23   0.071
# Name: ast_away, dtype: float64
# 7   0.140
# 8   0.138
# 6   0.130
# 9   0.111
# 5   0.102
# Name: stl_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 4   0.170
# 3   0.154
# 5   0.152
# 2   0.118
# 6   0.116
# Name: blk_away, dtype: float64
# 14   0.102
# 13   0.101
# 12   0.099
# 15   0.092
# 16   0.088
# Name: tov_away, dtype: float64
# 20   0.096
# 21   0.090
# 19   0.089
# 22   0.085
# 18   0.076
# Name: pf_away, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 98    0.036
# 95    0.034
# 103   0.033
# 99    0.033
# 100   0.032
# Name: pts_away, dtype: float64
# W   0.592
# L   0.408
# Name: wl_home, dtype: float64
# 1610612748   0.037
# 1610612744   0.036
# 1610612759   0.036
# 1610612760   0.036
# 1610612738   0.035
# Name: team_id_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 0.500   0.054
# 1.000   0.030
# 0.333   0.025
# 0.667   0.024
# 0.000   0.021
# Name: w_pct_home, dtype: float64
# 240   0.938
# 265   0.053
# 290   0.007
# 315   0.002
# 340   0.000
# Name: min_home, dtype: float64
# 38   0.080
# 37   0.079
# 39   0.076
# 36   0.072
# 40   0.070
# Name: fgm_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 81   0.059
# 83   0.058
# 82   0.057
# 84   0.052
# 80   0.052
# Name: fga_home, dtype: float64
# 0.500   0.032
# 0.494   0.022
# 0.506   0.019
# 0.488   0.017
# 0.481   0.012
# Name: fg_pct_home, dtype: float64
# 7   0.112
# 8   0.108
# 6   0.105
# 9   0.105
# 5   0.090
# Name: fg3m_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 20   0.057
# 22   0.054
# 21   0.053
# 25   0.052
# 19   0.052
# Name: fg3a_home, dtype: float64
# 0.333   0.061
# 0.500   0.034
# 0.400   0.034
# 0.250   0.027
# 0.375   0.024
# Name: fg3_pct_home, dtype: float64
# 17   0.067
# 15   0.064
# 18   0.063
# 16   0.062
# 14   0.061
# Name: ftm_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 21   0.057
# 23   0.054
# 24   0.052
# 25   0.051
# 22   0.051
# Name: fta_home, dtype: float64
# 1.000   0.985
# 0.000   0.015
# Name: ft_pct_home, dtype: float64
# 11   0.102
# 9    0.100
# 10   0.099
# 12   0.087
# 8    0.086
# Name: oreb_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 32   0.074
# 34   0.072
# 33   0.069
# 31   0.069
# 35   0.068
# Name: dreb_home, dtype: float64
# 42   0.063
# 43   0.062
# 45   0.059
# 44   0.059
# 41   0.057
# Name: reb_home, dtype: float64
# 23   0.081
# 22   0.081
# 21   0.076
# 24   0.074
# 20   0.070
# Name: ast_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 7   0.136
# 8   0.136
# 6   0.124
# 9   0.113
# 5   0.106
# Name: stl_home, dtype: float64
# 4   0.162
# 5   0.153
# 3   0.134
# 6   0.125
# 7   0.099
# Name: blk_home, dtype: float64
# 12   0.104
# 13   0.104
# 14   0.100
# 15   0.095
# 11   0.093
# Name: tov_home, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 19   0.099
# 20   0.093
# 18   0.091
# 21   0.085
# 17   0.081
# Name: pf_home, dtype: float64
# 99    0.034
# 102   0.034
# 101   0.034
# 103   0.034
# 104   0.033
# Name: pts_home, dtype: float64
# Regular Season   0.935
# Playoffs         0.065
# Name: season_type, dtype: float64

# %%
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
display(df_tbsatbs1018.iloc[:,number].value_counts(normalize=True).head())
number = number + 1
# Out:
# 2013-14   0.128
# 2015-16   0.128
# 2012-13   0.128
# 2017-18   0.128
# 2014-15   0.128
# Name: season, dtype: float64
# 2013   0.128
# 2015   0.128
# 2012   0.128
# 2017   0.128
# 2014   0.128
# Name: season_year, dtype: float64

# %%
#df_tbsatbs1018.mode(axis=0)
# Out:
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2011-04-13          Spurs                    SAS
# 1      21000002  2013-04-17            NaN                    NaN
# 2      21000003  2014-04-16            NaN                    NaN
# 3      21000004  2016-11-25            NaN                    NaN
# 4      21000005         NaN            NaN                    NaN
# ...         ...         ...            ...                    ...
# 10261  41700317         NaN            NaN                    NaN
# 10262  41700401         NaN            NaN                    NaN
# 10263  41700402         NaN            NaN                    NaN
# 10264  41700403         NaN            NaN                    NaN
# 10265  41700404         NaN            NaN                    NaN
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0        Los Angeles   240:00  0 days 04:00:00           Heat
# ...

# %%
datapath = os.path.join('..', 'processed_data')

if not os.path.exists(datapath):
    os.mkdir(datapath)

datapath_df = os.path.join(datapath, '21boxscoreadvancedv2_boxscores_team_away_home_2010_2018.csv')
if not os.path.exists(datapath_df):
    df_tbsatbs1018.to_csv(datapath_df, index=False)

# %%
df_e = rcp('21boxscoreadvancedv2_boxscores_team_away_home_2010_2018.csv')
p(df_e)
# Out:
# (10266, 107)
#         game_id   game_date TEAM_NAME_away TEAM_ABBREVIATION_away  \
# 0      21000001  2010-10-26           Heat                    MIA
# 1      21000002  2010-10-26           Suns                    PHX
# 2      21000003  2010-10-26        Rockets                    HOU
# 3      21000016  2010-10-27  Trail Blazers                    POR
# 4      21000004  2010-10-27        Celtics                    BOS
# 10261  41700317  2018-05-28       Warriors                    GSW
# 10262  41700401  2018-05-31      Cavaliers                    CLE
# 10263  41700402  2018-06-03      Cavaliers                    CLE
# 10264  41700403  2018-06-06       Warriors                    GSW
# 10265  41700404  2018-06-08       Warriors                    GSW
#
#       TEAM_CITY_away MIN_away    duration_away TEAM_NAME_home  \
# 0              Miami   240:00  0 days 04:00:00        Celtics
# 1            Phoenix   240:00  0 days 04:00:00  Trail Blazers
# ...
