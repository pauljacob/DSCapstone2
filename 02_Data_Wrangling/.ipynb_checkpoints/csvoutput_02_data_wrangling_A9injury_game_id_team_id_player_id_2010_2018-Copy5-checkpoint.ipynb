# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sqlite3

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.set_option('max_colwidth', None)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
def replace_player(df_):
    df_.player.replace({'J.J. Redick':'JJ Redick'}, inplace=True)
    
    df_.player.replace({'A.J. Price': 'AJ Price'}, inplace=True)
    
    df_.player.replace({'Alex Ajinca':'Alexis Ajinca'}, inplace=True)
    
    df_.player.replace({'C.J. Miles': 'CJ Miles'}, inplace=True)
    
    df_.player.replace({'D.J. White': 'DJ White'}, inplace=True)
    
    df_.player.replace({"Hamady N'Diaye" : 'Hamady Ndiaye'}, inplace=True)
    
    df_.player.replace({'J.J. Hickson': 'JJ Hickson'}, inplace=True)
    
    df_.player.replace({'John Wallace' : 'John Wall'}, inplace=True)
    
    df_.player.replace({'Jose Barea' : 'J.J. Barea'}, inplace=True)
    
    df_.player.replace({'Wes Johnson':'Wesley Johnson'}, inplace=True)
    
    df_.player.replace({'B.J. Mullens':'Byron Mullens'}, inplace=True)
    
    df_.player.replace({'Bill Walker':'Henry Walker'}, inplace=True)
    
    df_.player.replace({'Gerald Henderson Jr.':'Gerald Henderson'}, inplace=True)
    
    df_.player.replace({'Jianlian Yi':'Yi Jianlian'}, inplace=True)
    
    df_.player.replace({'Mike Conley Jr.':'Mike Conley'}, inplace=True)
    
    df_.player.replace({'Mike Dunleavy Jr.':'Mike Dunleavy'}, inplace=True)
    
    df_.player.replace({'Nene Hilario': 'Nene'}, inplace=True)
    
    df_.player.replace({'Didier Mbenga':'DJ Mbenga'}, inplace=True)
    
    df_.player.replace({'A.J. Hammons':'AJ Hammons'}, inplace=True)
    
    df_.player.replace({'C.J. McCollum':'CJ McCollum'}, inplace=True)
    
    df_.player.replace({'D.J. Augustine':'D.J. Augustin'}, inplace=True)
    
    df_.player.replace({'DeAndre Bembry':"DeAndre' Bembry"}, inplace=True)
    
    df_.player.replace({'Giorgios Papagiannis':'Georgios Papagiannis'}, inplace=True)
    
    df_.player.replace({'Glen Rice Jr.':'Glen Rice'}, inplace=True)
    
    df_.player.replace({'J.R. Smith':'JR Smith'}, inplace=True)
    
    df_.player.replace({'James Ennis':'James Ennis III'}, inplace=True)
    
    df_.player.replace({'John Collins  John Collins':'John Collins'}, inplace=True)
    
    df_.player.replace({'Juan Hernangomez':'Juancho Hernangomez'}, inplace=True)
    
    df_.player.replace({'Billy Ouattara':'Yakuba Ouattara'}, inplace=True)
    
    df_.player.replace({'Courtney Simpson':'Diamon Simpson'}, inplace=True)
    
    df_.player.replace({'Danuel House':'Danuel House Jr.'}, inplace=True)
    
    df_.player.replace({'Domas Sabonis':'Domantas Sabonis'}, inplace=True)
    
    df_.player.replace({'Jake Wiley':'Jacob Wiley'}, inplace=True)
    
    df_.player.replace({'James McAdoo':'James Michael McAdoo'}, inplace=True)
    
    df_.player.replace({'Jeff Pendergraph':'Jeff Ayres'}, inplace=True)
    
    df_.player.replace({'Jeff Taylor':'Jeffery Taylor'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'Malcom Lee':'Malcolm Lee'}, inplace=True)
    
    df_.player.replace({'Marcus Morris':'Marcus Morris Sr.'}, inplace=True)
    
    df_.player.replace({'Matt Williams':'Matt Williams Jr.'}, inplace=True)
    
    df_.player.replace({"Maurice N'dour":'Maurice Ndour'}, inplace=True)
    
    df_.player.replace({'Milos Tedosic':'Milos Teodosic'}, inplace=True)
    
    df_.player.replace({'Moe Harkless':'Maurice Harkless'}, inplace=True)
    
    df_.player.replace({'O.G. Anunoby':'OG Anunoby'}, inplace=True)
    
    df_.player.replace({'Ognen Kuzmic':'Ognjen Kuzmic'}, inplace=True)
    
    df_.player.replace({'P.J. Dozier':'PJ Dozier'}, inplace=True)
    
    df_.player.replace({'P.J. Hairston':'PJ Hairston'}, inplace=True)
    
    df_.player.replace({'Qi Zhou':'Zhou Qi'}, inplace=True)
    
    df_.player.replace({'R.J. Hunter':'RJ Hunter'}, inplace=True)
    
    df_.player.replace({'Ray McCallum Jr.':'Ray McCallum'}, inplace=True)
    
    df_.player.replace({'Ron Artest':'Metta World Peace'}, inplace=True)
    
    df_.player.replace({'Roy Marble':'Devyn Marble'}, inplace=True)
    
    df_.player.replace({'Stephen Zimmerman Jr.':'Stephen Zimmerman'}, inplace=True)
    
    df_.player.replace({'Tony Wroten Jr.':'Tony Wroten'}, inplace=True)
    
    df_.player.replace({'Toure Murry':"Toure' Murry"}, inplace=True)
    
    df_.player.replace({'Viacheslav Kravstov':'Viacheslav Kravtsov'}, inplace=True)
    
    df_.player.replace({'Vince Hunter':'Vincent Hunter'}, inplace=True)
    
    df_.player.replace({'Walker Russell Jr.':'Walker Russell'}, inplace=True)
    
    df_.player.replace({'Wayne Selden Jr.':'Wayne Selden'}, inplace=True)
    
    df_.player.replace({'Wes Matthews Jr.':'Wesley Matthews'}, inplace=True)
    
    return df_

#names dropped from Injury Report dataframe df_inj1018 for the following reasons:
#a. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons.
#b. player did not play an nba regular season or playoff game between the 2009-10 and 2017-18 seasons.
#c. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons. Player plays in nba games
#   following the 2017-18 season.
#d. this is the injury of a coach, not a player. coaches do not have boxscore advanced stats


def drop_player(df_):
    df_.drop(df_[df_.player.str.contains('Marion Hillard')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Matt Janning')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains("Da'Sean Butler")].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Eric Griffin')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Harry Giles')].index, inplace = True) #c
    
    df_.drop(df_[df_.player.str.contains('Magnum Rolle')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Robert Vaden')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Steve Clifford')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Steve Kerr')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Terrico White')].index, inplace = True)#a
    
    df_.drop(df_[df_.player.str.contains('Tyronn Lue')].index, inplace = True) #d
    
    return df_

def df_inj1020_fix_Date_Team(df_):
    df_.loc[5923, ['Team']] = 'Pacers'
    return df_

def manual_not_the_actual_game_date_drop(df_):
    df_.drop(21307, inplace=True) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_.reset_index(drop=True, inplace=True)
    return df_

'''def manual_not_the_game_date_drop2(df_):
    df_ = df_.drop(14084) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_ = df_.reset_index(drop=True)
    return df_'''


def get_5bsa1018_inj1018_player_diff():
    print(len(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME)))
    print(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME))
    print()
    
    print(len(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player)))
    print(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player))
    return 0
    
    
#get injury data for player
def gi(player_):
    return df_inj1018[df_inj1018.player.str.contains(player_)] 

#get boxscore advance for player
def gb(player_):
    return df_5bsa1018[df_5bsa1018.PLAYER_NAME.str.contains(player_)]

#get inactive player game-by-game
def gia(player_):
    return df_ina1018[df_ina1018.player.str.contains(player_)]

#return the first 5 and last 5 rows of this dataframe
def p(df_):
    if df_.shape[0] > 6:
        print(df_.shape)
        return pd.concat([df_.head(), df_.tail()])
    else:
        return df_

def rcp(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'processed_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'processed_data', file_), parse_dates=pd_)
    
def rcr(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'raw_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'raw_data', file_), parse_dates=pd_)

# %%
def fix_chris_wright_Team(df_):
    indexes_ = list(df_[((df_.Date == '2011-12-25') |
                        (df_.Date == '2011-12-28') |
                        (df_.Date == '2012-01-04') |
                        (df_.Date == '2012-01-20'))
                      & (df_.player == 'Chris Wright')].index)
    df_.at[indexes_, 'Team'] = 'Warriors'
    return df_

# %%
#drop '2011-12-25', 'Jeff Green' from df_inj1018 bc he didn't play the 2011-12 season

def drop_jeff_green_2011_12(df_):
    indexes_ = list(df_[((df_.Date == '2011-12-17') |
                         (df_.Date == '2011-12-25'))
                      & (df_.player == 'Jeff Green')].index)
    df_.drop(indexes_, inplace=True)
    return df_
#not seen as inactive/active on nba.com boxscores for the 2011-12 season

#'preseason physical with his employer, the Boston Celtics...failed his physical, voiding his one-year deal with the team, and won't play at all in the 2011-12 season'
#https://www.espn.com/nba/story/_/id/23713648/nba-how-jeff-green-returned-heart-defect-almost-ended-life

# %%
def fix_will_bynum_team_2013_14(df_):

    indexes_ = list(df_[df_.player.str.contains('Will Bynum') & ((df_.Date == '2014-04-04') | (df_.Date == '2013-11-29'))].index)

    df_.at[indexes_, 'Team'] = 'Pistons'

    return df_

# %%
#Bogdan Bogdanovic on game_date '2017-10-18' should have Team changed from Pacers to Kings since the Pacers play has a first name of Bojan not Bogdan
def fix_bogdan_bogdanovic_Team(df_):

    index_ = list(df_[df_.player.str.contains('Bogdan Bogdanovic') & (df_.Date == '2017-10-18')].index)

    df_.at[index_, 'Team'] = 'Kings'

    return df_

# %%
#drop jason kidd for game_date '2015-12-20' since he was a coach here
def drop_jason_kidd_2015_16(df_):
    index = list(df_[df_.player.str.contains('Jason Kidd') & (df_.Date == '2015-12-20')].index)
    df_.drop(index, inplace=True)
    return df_

# %%
#fix Team from hornets to Cavaliers for Chris Andersen on game_date '2017-02-13'
def fix_chris_andersen_Team(df_):
    index_ = list(df_[df_.player.str.contains('Chris Andersen') & (df_.Date == '2017-02-13')].index)
    df_.at[index_, 'Team']  = 'Cavaliers'
    return df_

# %%
#for Date '2017-02-13' and player/Relinquished 'Chris Wilcox', replace name with C.J. Wilcox and Team with 'Magic'

#earlier in season tenditis, but not on specific date https://www.nba.com/clippers/news/hand-injury-frustrating-wilcox-after-finally-feeling-healthy
#Wilcox of Magic inactive https://statsdmz.nba.com/pdfs/20170213/20170213_ORLMIA.pdf
#C.J. Wilcox of the Magic that 2016-17 season https://www.basketball-reference.com/players/w/wilcocj01.html
def fix_cj_wilcox_Team_player(df_):
    index_ = list(df_[(df_.Date == '2017-02-13') & df_.player.str.contains('Chris Wilcox')].index)
    df_.at[index_, 'Team'] = 'Magic'
    df_.at[index_, 'player'] = 'C.J. Wilcox'
    if True in df_inj1020.columns.str.contains('Relinquished'):
        df_.at[index_, 'Relinquished'] = 'C.J. Wilcox'
    return df_

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
#get injury report for 2010-11 thru 2017-18 sesasons: df_inj1018

#last game_date of 2017-18 season
path = os.path.join('..', 'processed_data', '7season_first_game_date_last_game_date.csv')
df_7sfgdlgd = pd.read_csv(path, parse_dates=['first', 'last'])
last_game_date_s1718 = df_7sfgdlgd.iloc[8]['last']
last_game_date_s1718
# Out:
# Timestamp('2018-06-08 00:00:00')

# %%
#read in raw injury report
path = os.path.join('..', 'raw_data', 'injuries_2010-2020.csv')
df_inj1020 = pd.read_csv(path, parse_dates=['Date'])
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 5)
# (27105, 5)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls           NaN  Carlos Boozer
# 1     2010-10-06  Pistons           NaN  Jonas Jerebko
# 2     2010-10-06  Pistons           NaN  Terrico White
# 3     2010-10-08  Blazers           NaN     Jeff Ayres
# 4     2010-10-08     Nets           NaN    Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters            NaN
# 27101 2020-10-02     Heat           NaN    Bam Adebayo
# 27102 2020-10-02     Heat           NaN   Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva            NaN
# 27104 2020-10-06     Heat   Bam Adebayo            NaN
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#preprocess player & Date
df_inj1020.Acquired.fillna('', inplace=True)
df_inj1020.Relinquished.fillna('', inplace=True)
df_inj1020['player'] = df_inj1020.Relinquished + ' ' + df_inj1020.Acquired
df_inj1020.player = df_inj1020.player.str.strip()
df_inj1020 = df_inj1020_fix_Date_Team(df_inj1020)
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 6)
# (27105, 6)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls                Carlos Boozer
# 1     2010-10-06  Pistons                Jonas Jerebko
# 2     2010-10-06  Pistons                Terrico White
# 3     2010-10-08  Blazers                   Jeff Ayres
# 4     2010-10-08     Nets                  Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters
# 27101 2020-10-02     Heat                  Bam Adebayo
# 27102 2020-10-02     Heat                 Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva
# 27104 2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes         player
# 0       fractured bone in right pinky finger (out indefinitely)  Carlos Boozer
# 1                 torn right Achilles tendon (out indefinitely)  Jonas Jerebko
# 2      broken fifth metatarsal in right foot (out indefinitely)  Terrico White
# ...

# %%
#bound last game date and make new dateframe: df_inj1018
df_inj1018 = df_inj1020.loc[df_inj1020['Date'] <= last_game_date_s1718]
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22257, 6)
# (22257, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 2     2010-10-06    Pistons                  Terrico White
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                           Notes  \
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# ...

# %%
#fix player (name)
df_inj1018 = replace_player(df_inj1018)
df_inj1018 = drop_player(df_inj1018)
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22232, 6)
# (22232, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# ...

# %%
#fix chris wright team to 'Warriors'
df_inj1018 = fix_chris_wright_Team(df_inj1018)
p(df_inj1018)
# Out:
# (22232, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# ...

# %%
#drop 2011-12 season rows for jeff green since he was out for the season to heart surgery. contract voided
df_inj1018 = drop_jeff_green_2011_12(df_inj1018)
p(df_inj1018)
# Out:
# (22230, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
# ...

# %%
#fix Team from Cavaliers to Pistons on '2014-04-04' and '2013-11-29' game_date's for 'Will Bynum' before the merges for team_id game_id etc.
df_inj1018[df_inj1018.player.str.contains('Will Bynum') & ((df_inj1018.Date == '2014-04-04') | (df_inj1018.Date == '2013-11-29'))]
# Out:
#            Date       Team Acquired Relinquished  \
# 8008 2013-11-29  Cavaliers            Will Bynum
# 9942 2014-04-04  Cavaliers            Will Bynum
#
#                                                Notes      player
# 8008             placed on IL with strained left hip  Will Bynum
# 9942  placed on IL with foot injury (out for season)  Will Bynum

# %%
'''indexes_ = list(df_inj1018[df_inj1018.player.str.contains('Will Bynum') & ((df_inj1018.Date == '2014-04-04') | (df_inj1018.Date == '2013-11-29'))].index)
indexes_'''
# Out:
# "indexes_ = list(df_inj1018[df_inj1018.player.str.contains('Will Bynum') & ((df_inj1018.Date == '2014-04-04') | (df_inj1018.Date == '2013-11-29'))].index)\nindexes_"

# %%
#df_inj1018.at[indexes_, 'Team'] = 'Pistons'

# %%
df_inj1018 = fix_will_bynum_team_2013_14(df_inj1018)
p(df_inj1018)
# Out:
# (22230, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# ...

# %%
#df_inj1018[df_inj1018.player.str.contains('Will Bynum') & ((df_inj1018.Date == '2014-04-04') | (df_inj1018.Date == '2013-11-29'))]

# %%
#df_inj1018[df_inj1018.player.str.contains('Jason Kidd') & (df_inj1018.Date == '2015-12-20')]

# %%
#index = list(df_inj1018[df_inj1018.player.str.contains('Jason Kidd') & (df_inj1018.Date == '2015-12-20')].index)
#index

# %%
#drop jason kidd for game_date '2015-12-20' since he was a coach here
df_inj1018 = drop_jason_kidd_2015_16(df_inj1018)
p(df_inj1018)
# Out:
# (22229, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
# ...

# %%
#df_inj1018[df_inj1018.player.str.contains('Jason Kidd') & (df_inj1018.Date == '2015-12-20')]

# %%
'''#fix Team from hornets to Cavaliers for Chris Andersen on game_date '2017-02-13'
df_inj1018[df_inj1018.player.str.contains('Chris Andersen') & (df_inj1018.Date == '2017-02-13')]
'''
# Out:
# "#fix Team from hornets to Cavaliers for Chris Andersen on game_date '2017-02-13'\ndf_inj1018[df_inj1018.player.str.contains('Chris Andersen') & (df_inj1018.Date == '2017-02-13')]\n"

# %%
'''index_ = list(df_inj1018[df_inj1018.player.str.contains('Chris Andersen') & (df_inj1018.Date == '2017-02-13')].index)
index_'''
# Out:
# "index_ = list(df_inj1018[df_inj1018.player.str.contains('Chris Andersen') & (df_inj1018.Date == '2017-02-13')].index)\nindex_"

# %%
#fix Team from hornets to Cavaliers for Chris Andersen on game_date '2017-02-13'
df_inj1018 = fix_chris_andersen_Team(df_inj1018)
p(df_inj1018)
# Out:
# (22229, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# ...

# %%
#df_inj1018[df_inj1018.player.str.contains('Chris Andersen') & (df_inj1018.Date == '2017-02-13')]

# %%
#Bogdan Bogdanovic on game_date '2017-10-18' should have Team changed from Pacers to Kings since the Pacers play has a first name of Bojan not Bogdan
df_inj1018 = fix_bogdan_bogdanovic_Team(df_inj1018)
p(df_inj1018)
# Out:
# (22229, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# ...

# %%
df_inj1018 = fix_cj_wilcox_Team_player(df_inj1018)
p(df_inj1018)
# Out:
# (22229, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# ...

# %%
df_inj1018[(df_inj1018.Date == '2017-02-13') & df_inj1018.player.str.contains('Chris Wilcox')]
# Out:
# Empty DataFrame
# Columns: [Date, Team, Acquired, Relinquished, Notes, player]
# Index: []

# %%
df_inj1018[(df_inj1018.Date == '2017-02-13') & df_inj1018.player.str.contains('C.J. Wilcox')]
# Out:
#             Date   Team Acquired Relinquished  \
# 17789 2017-02-13  Magic           C.J. Wilcox
#
#                                             Notes       player
# 17789  placed on IL with left Achilles tendinitis  C.J. Wilcox

# %%
df_inj1018[df_inj1018.player.str.contains('C.J. Wilcox')]
# Out:
#             Date      Team     Acquired Relinquished  \
# 10528 2014-10-30  Clippers               C.J. Wilcox
# 10877 2014-11-26  Clippers  C.J. Wilcox
# 10903 2014-11-28  Clippers               C.J. Wilcox
# 10980 2014-12-03  Clippers  C.J. Wilcox
# 11101 2014-12-13  Clippers               C.J. Wilcox
# 11443 2015-01-07  Clippers  C.J. Wilcox
# 11484 2015-01-10  Clippers               C.J. Wilcox
# 12327 2015-03-15  Clippers               C.J. Wilcox
# 12403 2015-03-20  Clippers  C.J. Wilcox
# 12434 2015-03-22  Clippers               C.J. Wilcox
# 12488 2015-03-25  Clippers  C.J. Wilcox
# 12586 2015-03-31  Clippers               C.J. Wilcox
# 13063 2015-10-28  Clippers               C.J. Wilcox
# 13716 2015-12-07  Clippers               C.J. Wilcox
# 14296 2016-01-13  Clippers  C.J. Wilcox
# 15283 2016-03-27  Clippers  C.J. Wilcox
# 15312 2016-03-28  Clippers  C.J. Wilcox
# 15704 2016-04-17  Clippers               C.J. Wilcox
# 15769 2016-04-27  Clippers  C.J. Wilcox
# ...

# %%
p(df_inj1018)
# Out:
# (22229, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# ...

# %%
def drop_okaro_white_sheldon_mac_hawks_2018_02_08(df_):
    index_ = list(df_[df_.player.str.contains('Okaro White') & (df_.Date == '2018-02-08')].index)
    df_.drop(index_, inplace=True)
    
    index_ = list(df_inj1018[df_inj1018.player.str.contains('Sheldon Mac') & (df_inj1018.Date == '2018-02-08')].index)
    df_.drop(index_, inplace=True)
    
    return df_

# %%
df_inj1018 = drop_okaro_white_sheldon_mac_hawks_2018_02_08(df_inj1018)
p(df_inj1018)
# Out:
# (22227, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
# ...

# %%
'''index_ = list(df_inj1018[df_inj1018.player.str.contains('Okaro White') & (df_inj1018.Date == '2018-02-08')].index)
index_
'''
# Out:
# "index_ = list(df_inj1018[df_inj1018.player.str.contains('Okaro White') & (df_inj1018.Date == '2018-02-08')].index)\nindex_\n"

# %%
'''index_ = list(df_inj1018[df_inj1018.player.str.contains('Sheldon Mac') & (df_inj1018.Date == '2018-02-08')].index)
index_'''
# Out:
# "index_ = list(df_inj1018[df_inj1018.player.str.contains('Sheldon Mac') & (df_inj1018.Date == '2018-02-08')].index)\nindex_"

# %%
#df_inj1018[df_inj1018.player.str.contains('Okaro White') & (df_inj1018.Date == '2018-02-08')]

# %%
#df_inj1018.drop(21056, inplace=True)

# %%
#df_inj1018[df_inj1018.player.str.contains('Okaro White') & (df_inj1018.Date == '2018-02-08')]

# %%
#df_inj1018[df_inj1018.player.str.contains('Sheldon Mac') & (df_inj1018.Date == '2018-02-08')]

# %%
p(df_inj1018)
# Out:
# (22227, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# ...

# %%
#add team_id, player_id, game_id

# %%
#team_id

#merge 3gdgiti (game_date, season) with od get unique --> season

#season, Team --> team_id

# %%
df_3gds = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'season']].drop_duplicates().reset_index(drop=True)
p(df_3gds)
# Out:
# (2450, 2)
#       game_date   season
# 0    2006-10-31  2006-07
# 1    2006-11-01  2006-07
# 2    2006-11-02  2006-07
# 3    2006-11-03  2006-07
# 4    2006-11-04  2006-07
# 2445 2018-05-28  2017-18
# 2446 2018-05-31  2017-18
# 2447 2018-06-03  2017-18
# 2448 2018-06-06  2017-18
# 2449 2018-06-08  2017-18

# %%
#merge 3gdgiti (game_date, season) with od get unique --> season
df_inj1018_dgd = pd.merge(df_3gds.rename(columns={'game_date':'Date_game_date'}), df_inj1018.rename(columns={'Date':'Date_game_date'}), on='Date_game_date', how='inner')
p(df_inj1018_dgd)
# Out:
# (21917, 7)
#       Date_game_date   season       Team        Acquired      Relinquished  \
# 0         2010-10-26  2010-11    Blazers                   Elliot Williams
# 1         2010-10-26  2010-11    Blazers                         Greg Oden
# 2         2010-10-26  2010-11    Blazers                    Joel Przybilla
# 3         2010-10-26  2010-11    Celtics                     Avery Bradley
# 4         2010-10-26  2010-11    Celtics                  Kendrick Perkins
# 21912     2018-05-22  2017-18   Warriors                    Andre Iguodala
# 21913     2018-05-26  2017-18  Cavaliers                        Kevin Love
# 21914     2018-05-26  2017-18   Warriors   Patrick McCaw
# 21915     2018-05-31  2017-18  Cavaliers      Kevin Love
# 21916     2018-06-06  2017-18   Warriors  Andre Iguodala
#
#                                                                                                    Notes  \
# ...

# %% [markdown]
# <font color='red'>are these the actual game dates or just dates nba games are played on which a player injury report was made on??? </font>

# %%
#season, Team --> team_id
df_tist = rcp('10team_id_season_team_2010_2018.csv')
p(df_tist)
# Out:
# (240, 3)
#         TEAM_ID   season      Team
# 0    1610612748  2010-11      Heat
# 1    1610612749  2010-11     Bucks
# 2    1610612765  2010-11   Pistons
# 3    1610612753  2010-11     Magic
# 4    1610612737  2010-11     Hawks
# 235  1610612752  2017-18    Knicks
# 236  1610612758  2017-18     Kings
# 237  1610612744  2017-18  Warriors
# 238  1610612765  2017-18   Pistons
# 239  1610612746  2017-18  Clippers

# %%
df_inj1018_dgdti = pd.merge(df_tist, df_inj1018_dgd, on=['season', 'Team'], how='inner')
p(df_inj1018_dgdti)
# Out:
# (21916, 8)
#           TEAM_ID   season      Team Date_game_date          Acquired  \
# 0      1610612748  2010-11      Heat     2010-10-26
# 1      1610612748  2010-11      Heat     2010-10-26
# 2      1610612748  2010-11      Heat     2010-10-26
# 3      1610612748  2010-11      Heat     2010-10-26
# 4      1610612748  2010-11      Heat     2010-10-27
# 21911  1610612746  2017-18  Clippers     2018-03-30  Danilo Gallinari
# 21912  1610612746  2017-18  Clippers     2018-04-03
# 21913  1610612746  2017-18  Clippers     2018-04-03
# 21914  1610612746  2017-18  Clippers     2018-04-09
# 21915  1610612746  2017-18  Clippers     2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21911
# 21912  Danilo Gallinari
# 21913       Jawun Evans
# 21914     Austin Rivers
# 21915      Lou Williams
#
# ...

# %%
#game_id

#team_id, Date_game_date --> game_date

#team_id, game_date --> game_id

#team_id, player, (season,) game_date --> game_id

# %% [markdown]
# <font color='red'> team_id and a game_date all i need to get game_id????</font>

# %%
#game_id

#team_id, Date_game_date --> game_date

# %%
df_3gdti = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'team_id']].drop_duplicates().reset_index(drop=True)
p(df_3gdti)
# Out:
# (31038, 2)
#        game_date     team_id
# 0     2006-10-31  1610612748
# 1     2006-10-31  1610612741
# 2     2006-10-31  1610612747
# 3     2006-10-31  1610612756
# 4     2006-11-01  1610612755
# 31033 2018-06-03  1610612744
# 31034 2018-06-06  1610612744
# 31035 2018-06-06  1610612739
# 31036 2018-06-08  1610612739
# 31037 2018-06-08  1610612744

# %%
#team_id, Date_game_date --> game_date
df_inj1018_gdti = pd.merge(df_inj1018_dgdti.rename(columns={'Date_game_date':'game_date', 'TEAM_ID':'team_id'}), df_3gdti, how='inner', on=['game_date', 'team_id'])
df_inj1018_gdti
# Out:
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# ...           ...      ...       ...        ...               ...
# 21060  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21061  1610612746  2017-18  Clippers 2018-04-03
# 21062  1610612746  2017-18  Clippers 2018-04-03
# 21063  1610612746  2017-18  Clippers 2018-04-09
# 21064  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# ...                 ...
# 21060
# 21061  Danilo Gallinari
# 21062       Jawun Evans
# 21063     Austin Rivers
# 21064      Lou Williams
#
# ...

# %%
#game_id

#team_id, game_date --> game_id
df_3gdtigi = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'team_id','game_id']].drop_duplicates().reset_index(drop=True)
p(df_3gdtigi)
# Out:
# (31038, 3)
#        game_date     team_id   game_id
# 0     2006-10-31  1610612748  20600001
# 1     2006-10-31  1610612741  20600001
# 2     2006-10-31  1610612747  20600002
# 3     2006-10-31  1610612756  20600002
# 4     2006-11-01  1610612755  20600003
# 31033 2018-06-03  1610612744  41700402
# 31034 2018-06-06  1610612744  41700403
# 31035 2018-06-06  1610612739  41700403
# 31036 2018-06-08  1610612739  41700404
# 31037 2018-06-08  1610612744  41700404

# %%
df_inj1018_gdti.columns
# Out:
# Index(['team_id', 'season', 'Team', 'game_date', 'Acquired', 'Relinquished',
#        'Notes', 'player'],
#       dtype='object')

# %%
#team_id, game_date --> game_id
df_inj1018_gdtigi = pd.merge(df_inj1018_gdti, df_3gdtigi, on=['team_id', 'game_date'])
p(df_inj1018_gdtigi)
# Out:
# (21065, 9)
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# 21060  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21061  1610612746  2017-18  Clippers 2018-04-03
# 21062  1610612746  2017-18  Clippers 2018-04-03
# 21063  1610612746  2017-18  Clippers 2018-04-09
# 21064  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21060
# 21061  Danilo Gallinari
# 21062       Jawun Evans
# 21063     Austin Rivers
# 21064      Lou Williams
#
#                                                                                                  Notes  \
# ...

# %%
df_inj1018_gdtigi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21065 entries, 0 to 21064
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   team_id       21065 non-null  int64
#  1   season        21065 non-null  object
#  2   Team          21065 non-null  object
#  3   game_date     21065 non-null  datetime64[ns]
#  4   Acquired      21065 non-null  object
#  5   Relinquished  21065 non-null  object
#  6   Notes         21065 non-null  object
#  7   player        21065 non-null  object
#  8   game_id       21065 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
df_inj1018_gdtigi[df_inj1018_gdtigi.player.str.contains('Jeff Green')]
# Out:
#           team_id   season       Team  game_date    Acquired Relinquished  \
# 1686   1610612760  2010-11    Thunder 2010-11-07               Jeff Green
# 1691   1610612760  2010-11    Thunder 2010-11-14  Jeff Green
# 1693   1610612760  2010-11    Thunder 2010-11-15               Jeff Green
# 1700   1610612760  2010-11    Thunder 2010-11-22  Jeff Green
# 13831  1610612746  2015-16   Clippers 2016-03-19               Jeff Green
# 13832  1610612746  2015-16   Clippers 2016-03-23  Jeff Green
# 17951  1610612753  2016-17      Magic 2016-11-27               Jeff Green
# 17953  1610612753  2016-17      Magic 2016-11-29  Jeff Green
# 17995  1610612753  2016-17      Magic 2017-03-22               Jeff Green
# 18000  1610612753  2016-17      Magic 2017-04-12  Jeff Green
# 18830  1610612739  2017-18  Cavaliers 2018-02-27               Jeff Green
# 18832  1610612739  2017-18  Cavaliers 2018-03-01  Jeff Green
# 18833  1610612739  2017-18  Cavaliers 2018-03-03               Jeff Green
# ...

# %% [markdown]
# <font color='red'> thought Jeff Green was already out for the reason earlier in this 2011-12 season???</font>

# %%
#player_id

#team_id, season, player --> player_id

#^-- acceptable bc no player's of the same name played for the same same team during the same season for 2010-11 thru 2017-18 seasons

# %%
df_gdgitispip = rcp('15game_date_game_id_team_id_season_player_id_player_2010_2018.csv', ['game_date'])
p(df_gdgitispip)
# Out:
# (334767, 6)
#         game_date   game_id     team_id   season  PLAYER_ID             player
# 0      2009-10-27  20900001  1610612739  2009-10     2544.0       LeBron James
# 1      2009-10-27  20900003  1610612745  2009-10   201978.0     Chase Budinger
# 2      2009-10-27  20900003  1610612745  2009-10   200822.0  Pops Mensah-Bonsu
# 3      2009-10-27  20900003  1610612745  2009-10     2431.0     David Andersen
# 4      2009-10-27  20900003  1610612745  2009-10   201171.0        Carl Landry
# 334762 2018-06-08  41700404  1610612739  2017-18   202684.0   Tristan Thompson
# 334763 2018-06-08  41700404  1610612739  2017-18   201567.0         Kevin Love
# 334764 2018-06-08  41700404  1610612739  2017-18     2544.0       LeBron James
# 334765 2018-06-08  41700404  1610612739  2017-18   203903.0    Jordan Clarkson
# 334766 2018-06-08  41700404  1610612744  2017-18  1627775.0      Patrick McCaw

# %%
df_tispip = df_gdgitispip[['team_id', 'season', 'player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True)
p(df_tispip)
# Out:
# (5057, 4)
#          team_id   season             player  PLAYER_ID
# 0     1610612739  2009-10       LeBron James     2544.0
# 1     1610612745  2009-10     Chase Budinger   201978.0
# 2     1610612745  2009-10  Pops Mensah-Bonsu   200822.0
# 3     1610612745  2009-10     David Andersen     2431.0
# 4     1610612745  2009-10        Carl Landry   201171.0
# 5052  1610612738  2017-18    Jonathan Gibson  1626780.0
# 5053  1610612747  2017-18       Andre Ingram   201281.0
# 5054  1610612745  2017-18      Aaron Jackson  1628935.0
# 5055  1610612739  2017-18   Kendrick Perkins     2570.0
# 5056  1610612764  2017-18          Ty Lawson   201951.0

# %%
p(df_inj1018_gdtigi)
# Out:
# (21065, 9)
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# 21060  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21061  1610612746  2017-18  Clippers 2018-04-03
# 21062  1610612746  2017-18  Clippers 2018-04-03
# 21063  1610612746  2017-18  Clippers 2018-04-09
# 21064  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21060
# 21061  Danilo Gallinari
# 21062       Jawun Evans
# 21063     Austin Rivers
# 21064      Lou Williams
#
#                                                                                                  Notes  \
# ...

# %%
df_inj1018_gdtigipi = pd.merge(df_inj1018_gdtigi, df_tispip, on=['team_id','season','player'], how='inner', indicator=True)
p(df_inj1018_gdtigipi)
# Out:
# (21065, 11)
#           team_id   season      Team  game_date        Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2011-02-15
# 2      1610612748  2010-11      Heat 2011-04-01  Dexter Pittman
# 3      1610612748  2010-11      Heat 2011-04-03
# 4      1610612748  2010-11      Heat 2010-10-26
# 21060  1610612746  2017-18  Clippers 2018-02-03   Avery Bradley
# 21061  1610612746  2017-18  Clippers 2018-02-22
# 21062  1610612746  2017-18  Clippers 2018-03-13
# 21063  1610612746  2017-18  Clippers 2018-02-28
# 21064  1610612746  2017-18  Clippers 2018-03-27  Tyrone Wallace
#
#            Relinquished  \
# 0        Dexter Pittman
# 1        Dexter Pittman
# 2
# 3        Dexter Pittman
# 4      Jerry Stackhouse
# 21060
# 21061     Avery Bradley
# 21062     Avery Bradley
# 21063    Tyrone Wallace
# 21064
#
#                                                                       Notes  \
# ...

# %%
df_inj1018_gdtigipi = pd.merge(df_inj1018_gdtigi, df_tispip, on=['team_id','season','player'], how='outer', indicator=True)
p(df_inj1018_gdtigipi)
# Out:
# (22730, 11)
#           team_id   season  Team  game_date        Acquired      Relinquished  \
# 0      1610612748  2010-11  Heat 2010-10-26                    Dexter Pittman
# 1      1610612748  2010-11  Heat 2011-02-15                    Dexter Pittman
# 2      1610612748  2010-11  Heat 2011-04-01  Dexter Pittman
# 3      1610612748  2010-11  Heat 2011-04-03                    Dexter Pittman
# 4      1610612748  2010-11  Heat 2010-10-26                  Jerry Stackhouse
# 22725  1610612763  2017-18   NaN        NaT             NaN               NaN
# 22726  1610612738  2017-18   NaN        NaT             NaN               NaN
# 22727  1610612747  2017-18   NaN        NaT             NaN               NaN
# 22728  1610612745  2017-18   NaN        NaT             NaN               NaN
# 22729  1610612764  2017-18   NaN        NaT             NaN               NaN
#
#                                                               Notes  \
# ...

# %%
df_inj1018_gdtigipi.value_counts('_merge')
# Out:
# _merge
# both          21065
# right_only     1665
# left_only         0
# dtype: int64

# %%
df_inj1018_gdtigipi[df_inj1018_gdtigipi._merge == 'left_only']
# Out:
# Empty DataFrame
# Columns: [team_id, season, Team, game_date, Acquired, Relinquished, Notes, player, game_id, PLAYER_ID, _merge]
# Index: []

# %%
df_inj1018[df_inj1018.player.str.contains('Okaro White') & (df_inj1018.Date == '2018-02-08')]
# Out:
# Empty DataFrame
# Columns: [Date, Team, Acquired, Relinquished, Notes, player]
# Index: []

# %%
df_inj1018[df_inj1018.player.str.contains('Sheldon Mac') & (df_inj1018.Date == '2018-02-08')]
# Out:
# Empty DataFrame
# Columns: [Date, Team, Acquired, Relinquished, Notes, player]
# Index: []

# %%
df_inj1018[df_inj1018.player.str.contains('Okaro White')]
# Out:
#             Date       Team     Acquired Relinquished  \
# 15856 2016-10-15       Heat               Okaro White
# 19027 2017-10-18       Heat               Okaro White
# 19144 2017-10-21       Heat  Okaro White
# 19291 2017-10-30       Heat               Okaro White
# 19292 2017-10-30       Heat  Okaro White
# 19521 2017-11-14       Heat               Okaro White
# 19580 2017-11-17       Heat               Okaro White
# 21683 2018-03-23  Cavaliers               Okaro White
# 22080 2018-04-09  Cavaliers               Okaro White
#
#                                                    Notes       player
# 15856                          sprained left ankle (DTD)  Okaro White
# 19027  placed on IL with sprained/strained left shoulder  Okaro White
# 19144                                  activated from IL  Okaro White
# 19291                                       placed on IL  Okaro White
# 19292                                  activated from IL  Okaro White
# ...

# %% [markdown]
# <font color='red'>Andrew White of the hawks was an inactive player on this Team and date. why does the injury report show player was Acquired???</font>

# %%
#andrew white inactive https://statsdmz.nba.com/pdfs/20180208/20180208_ATLORL.pdf
#andrew white, hawk the 2017-18 season https://www.basketball-reference.com/players/w/whitean01.html

# %% [markdown]
# <font color='red'>does okaro white return as an nba active player in the 2017-18 season??? when??</font>

# %%
#okaro white , heat, left foot surgery inactive https://statsdmz.nba.com/pdfs/20180207/20180207_HOUMIA.pdf
# okaro white, not on heat inactive list the following nba game https://statsdmz.nba.com/pdfs/20180209/20180209_MILMIA.pdf

# %% [markdown]
# <font color='red'> okaro white get his Team, Notes, Acquired, Relinquished, Date messed with???</font>

# %%
df_inj1018[df_inj1018.player.str.contains('Sheldon Mac')]
# Out:
#             Date     Team     Acquired Relinquished  \
# 18118 2017-03-11  Wizards               Sheldon Mac
# 18158 2017-03-13  Wizards  Sheldon Mac
# 18187 2017-03-15  Wizards               Sheldon Mac
# 18221 2017-03-17  Wizards  Sheldon Mac
# 18330 2017-03-24  Wizards               Sheldon Mac
# 18346 2017-03-25  Wizards  Sheldon Mac
# 18425 2017-03-29  Wizards               Sheldon Mac
# 18464 2017-03-31  Wizards  Sheldon Mac
# 18499 2017-04-02  Wizards               Sheldon Mac
# 18637 2017-04-08  Wizards               Sheldon Mac
# 18785 2017-04-12  Wizards  Sheldon Mac
# 18795 2017-04-14  Wizards               Sheldon Mac
# 18841 2017-04-16  Wizards  Sheldon Mac
# 18972 2017-10-09  Wizards               Sheldon Mac
# 18973 2017-10-10  Wizards               Sheldon Mac
# 19074 2017-10-18  Wizards               Sheldon Mac
#
#                                                                           Notes  \
# ...

# %%
df_inj1018[(df_inj1018.Team == 'Hawks') & (df_inj1018.Date.dt.year == 2018)]
# Out:
#             Date   Team            Acquired        Relinquished  \
# 20420 2018-01-02  Hawks        Mike Muscala
# 20480 2018-01-05  Hawks                          DeAndre Bembry
# 20515 2018-01-08  Hawks                            Luke Babbitt
# 20516 2018-01-08  Hawks      Dewayne Dedmon
# 20566 2018-01-12  Hawks                         Marco Belinelli
# 20567 2018-01-12  Hawks        Luke Babbitt
# 20616 2018-01-15  Hawks     Marco Belinelli
# 20634 2018-01-15  Hawks                        Andrew White III
# 20719 2018-01-20  Hawks                           Isaiah Taylor
# 20720 2018-01-20  Hawks                         Tyler Cavanaugh
# 20721 2018-01-20  Hawks        Josh Magette
# 20746 2018-01-22  Hawks                            Josh Magette
# 20747 2018-01-22  Hawks       Isaiah Taylor
# 20967 2018-02-04  Hawks                          Ersan Ilyasova
# 20972 2018-02-04  Hawks      DeAndre Bembry
# 20974 2018-02-04  Hawks                          DeAndre Bembry
# ...

# %%
#Sheldon Mac
#'He did not appear in a game for the Wizards in 2017–18, and on February 8, 2018,
# he was traded to the Atlanta Hawks alongside cash considerations in exchange for a protected 2019 second round draft pick.'

# %%
df_gdgitispip[df_gdgitispip.player.str.contains('Sheldon Mac')]
# Out:
#         game_date   game_id     team_id   season  PLAYER_ID       player
# 253622 2016-10-27  21600014  1610612764  2016-17  1627815.0  Sheldon Mac
# 254371 2016-10-30  21600039  1610612764  2016-17  1627815.0  Sheldon Mac
# 255062 2016-11-02  21600055  1610612764  2016-17  1627815.0  Sheldon Mac
# 255460 2016-11-04  21600070  1610612764  2016-17  1627815.0  Sheldon Mac
# 255719 2016-11-05  21600081  1610612764  2016-17  1627815.0  Sheldon Mac
# 256078 2016-11-07  21600094  1610612764  2016-17  1627815.0  Sheldon Mac
# 256692 2016-11-09  21600107  1610612764  2016-17  1627815.0  Sheldon Mac
# 257059 2016-11-11  21600122  1610612764  2016-17  1627815.0  Sheldon Mac
# 257331 2016-11-12  21600133  1610612764  2016-17  1627815.0  Sheldon Mac
# 258090 2016-11-16  21600158  1610612764  2016-17  1627815.0  Sheldon Mac
# 258349 2016-11-17  21600169  1610612764  2016-17  1627815.0  Sheldon Mac
# 258937 2016-11-19  21600186  1610612764  2016-17  1627815.0  Sheldon Mac
# ...

# %% [markdown]
# <font color='red'> why so many rows for Sheldon Mac in the 2017-18 season???? bball ref shows only the 2016-17 season</font>

# %%
df_tist[df_tist.TEAM_ID == 1610612764]
# Out:
#         TEAM_ID   season     Team
# 9    1610612764  2010-11  Wizards
# 53   1610612764  2011-12  Wizards
# 81   1610612764  2012-13  Wizards
# 99   1610612764  2013-14  Wizards
# 124  1610612764  2014-15  Wizards
# 162  1610612764  2015-16  Wizards
# 195  1610612764  2016-17  Wizards
# 232  1610612764  2017-18  Wizards

# %%
df_gdgitispip[df_gdgitispip.player.str.contains('Okaro White')]
# Out:
#         game_date   game_id     team_id   season  PLAYER_ID       player
# 271798 2017-01-17  21600623  1610612748  2016-17  1627855.0  Okaro White
# 272257 2017-01-19  21600637  1610612748  2016-17  1627855.0  Okaro White
# 272889 2017-01-21  21600655  1610612748  2016-17  1627855.0  Okaro White
# 273226 2017-01-23  21600668  1610612748  2016-17  1627855.0  Okaro White
# 273674 2017-01-25  21600682  1610612748  2016-17  1627855.0  Okaro White
# 273981 2017-01-27  21600700  1610612748  2016-17  1627855.0  Okaro White
# 274211 2017-01-28  21600705  1610612748  2016-17  1627855.0  Okaro White
# 274771 2017-01-30  21600719  1610612748  2016-17  1627855.0  Okaro White
# 275326 2017-02-01  21600734  1610612748  2016-17  1627855.0  Okaro White
# 275916 2017-02-04  21600758  1610612748  2016-17  1627855.0  Okaro White
# 276178 2017-02-06  21600775  1610612748  2016-17  1627855.0  Okaro White
# 276910 2017-02-08  21600787  1610612748  2016-17  1627855.0  Okaro White
# ...

# %%
df_white_2017_18 = df_gdgitispip[df_gdgitispip.player.str.contains(' White') & (df_gdgitispip.season == '2017-18')]
df_white_2017_18
# Out:
#         game_date   game_id     team_id   season  PLAYER_ID            player
# 292081 2017-10-18  21700011  1610612759  2017-18  1628401.0     Derrick White
# 292138 2017-10-18  21700005  1610612748  2017-18  1627855.0       Okaro White
# 292141 2017-10-18  21700004  1610612751  2017-18  1627785.0  Isaiah Whitehead
# 292221 2017-10-18  21700005  1610612748  2017-18   202355.0  Hassan Whiteside
# 292830 2017-10-20  21700022  1610612751  2017-18  1627785.0  Isaiah Whitehead
# 293008 2017-10-21  21700029  1610612748  2017-18  1627855.0       Okaro White
# 293074 2017-10-21  21700031  1610612759  2017-18  1628401.0     Derrick White
# 293126 2017-10-21  21700029  1610612748  2017-18   202355.0  Hassan Whiteside
# 293225 2017-10-22  21700038  1610612751  2017-18  1627785.0  Isaiah Whitehead
# 293320 2017-10-23  21700046  1610612759  2017-18  1628401.0     Derrick White
# 293431 2017-10-23  21700042  1610612748  2017-18  1627855.0       Okaro White
# ...

# %%
df_tist = rcp('10team_id_season_team_2010_2018.csv')
p(df_tist)
# Out:
# (240, 3)
#         TEAM_ID   season      Team
# 0    1610612748  2010-11      Heat
# 1    1610612749  2010-11     Bucks
# 2    1610612765  2010-11   Pistons
# 3    1610612753  2010-11     Magic
# 4    1610612737  2010-11     Hawks
# 235  1610612752  2017-18    Knicks
# 236  1610612758  2017-18     Kings
# 237  1610612744  2017-18  Warriors
# 238  1610612765  2017-18   Pistons
# 239  1610612746  2017-18  Clippers

# %%
pd.merge(df_white_2017_18, df_tist.rename(columns={'TEAM_ID':'team_id'}), on=['team_id', 'season'])
# Out:
#      game_date   game_id     team_id   season  PLAYER_ID            player  \
# 0   2017-10-18  21700011  1610612759  2017-18  1628401.0     Derrick White
# 1   2017-10-21  21700031  1610612759  2017-18  1628401.0     Derrick White
# 2   2017-10-23  21700046  1610612759  2017-18  1628401.0     Derrick White
# 3   2017-10-25  21700059  1610612759  2017-18  1628401.0     Derrick White
# 4   2017-10-27  21700071  1610612759  2017-18  1628401.0     Derrick White
# 5   2017-10-29  21700086  1610612759  2017-18  1628401.0     Derrick White
# 6   2017-10-30  21700092  1610612759  2017-18  1628401.0     Derrick White
# 7   2017-11-02  21700117  1610612759  2017-18  1628401.0     Derrick White
# 8   2017-11-03  21700126  1610612759  2017-18  1628401.0     Derrick White
# 9   2017-11-05  21700141  1610612759  2017-18  1628401.0     Derrick White
# 10  2017-11-07  21700154  1610612759  2017-18  1628401.0     Derrick White
# ...

# %%
for i in range(len(players_)):
    #print(players_[i])
    p(df_inj1018_gdtigipi[df_inj1018_gdtigipi.Team.str.contains('Hawks') & df_inj1018_gdtigipi.player.str.contains(players_[i])])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-70243408f445> in <module>
# ----> 1 for i in range(len(players_)):
#       2     #print(players_[i])
#       3     p(df_inj1018_gdtigipi[df_inj1018_gdtigipi.Team.str.contains('Hawks') & df_inj1018_gdtigipi.player.str.contains(players_[i])])
#
# NameError: name 'players_' is not defined

# %%
p(df_inj1018_gdtigipi[df_inj1018_gdtigipi.Team.str.contains('Hawks') & df_inj1018_gdtigipi.player.str.contains('White')])

# %%
df_tist[df_tist.TEAM_ID == 1610612748]

# %%
p(df_gdgitispip[df_gdgitispip.player.str.contains('Bogdan Bogdanovic') & (df_gdgitispip.season == '2017-18')].drop_duplicates())

# %% [markdown]
# <font color='red'> how is it that we have 82 rows for the 2017-18 season when Bogdan only played 78 games according to basketball reference????</font> by counting inactive games too????
