# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sqlite3

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.set_option('max_colwidth', None)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
def replace_player(df_):
    df_.player.replace({'J.J. Redick':'JJ Redick'}, inplace=True)
    
    df_.player.replace({'A.J. Price': 'AJ Price'}, inplace=True)
    
    df_.player.replace({'Alex Ajinca':'Alexis Ajinca'}, inplace=True)
    
    df_.player.replace({'C.J. Miles': 'CJ Miles'}, inplace=True)
    
    df_.player.replace({'D.J. White': 'DJ White'}, inplace=True)
    
    df_.player.replace({"Hamady N'Diaye" : 'Hamady Ndiaye'}, inplace=True)
    
    df_.player.replace({'J.J. Hickson': 'JJ Hickson'}, inplace=True)
    
    df_.player.replace({'John Wallace' : 'John Wall'}, inplace=True)
    
    df_.player.replace({'Jose Barea' : 'J.J. Barea'}, inplace=True)
    
    df_.player.replace({'Wes Johnson':'Wesley Johnson'}, inplace=True)
    
    df_.player.replace({'B.J. Mullens':'Byron Mullens'}, inplace=True)
    
    df_.player.replace({'Bill Walker':'Henry Walker'}, inplace=True)
    
    df_.player.replace({'Gerald Henderson Jr.':'Gerald Henderson'}, inplace=True)
    
    df_.player.replace({'Jianlian Yi':'Yi Jianlian'}, inplace=True)
    
    df_.player.replace({'Mike Conley Jr.':'Mike Conley'}, inplace=True)
    
    df_.player.replace({'Mike Dunleavy Jr.':'Mike Dunleavy'}, inplace=True)
    
    df_.player.replace({'Nene Hilario': 'Nene'}, inplace=True)
    
    df_.player.replace({'Didier Mbenga':'DJ Mbenga'}, inplace=True)
    
    df_.player.replace({'A.J. Hammons':'AJ Hammons'}, inplace=True)
    
    df_.player.replace({'C.J. McCollum':'CJ McCollum'}, inplace=True)
    
    df_.player.replace({'D.J. Augustine':'D.J. Augustin'}, inplace=True)
    
    df_.player.replace({'DeAndre Bembry':"DeAndre' Bembry"}, inplace=True)
    
    df_.player.replace({'Giorgios Papagiannis':'Georgios Papagiannis'}, inplace=True)
    
    df_.player.replace({'Glen Rice Jr.':'Glen Rice'}, inplace=True)
    
    df_.player.replace({'J.R. Smith':'JR Smith'}, inplace=True)
    
    df_.player.replace({'James Ennis':'James Ennis III'}, inplace=True)
    
    df_.player.replace({'John Collins  John Collins':'John Collins'}, inplace=True)
    
    df_.player.replace({'Juan Hernangomez':'Juancho Hernangomez'}, inplace=True)
    
    df_.player.replace({'Billy Ouattara':'Yakuba Ouattara'}, inplace=True)
    
    df_.player.replace({'Courtney Simpson':'Diamon Simpson'}, inplace=True)
    
    df_.player.replace({'Danuel House':'Danuel House Jr.'}, inplace=True)
    
    df_.player.replace({'Domas Sabonis':'Domantas Sabonis'}, inplace=True)
    
    df_.player.replace({'Jake Wiley':'Jacob Wiley'}, inplace=True)
    
    df_.player.replace({'James McAdoo':'James Michael McAdoo'}, inplace=True)
    
    df_.player.replace({'Jeff Pendergraph':'Jeff Ayres'}, inplace=True)
    
    df_.player.replace({'Jeff Taylor':'Jeffery Taylor'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'Malcom Lee':'Malcolm Lee'}, inplace=True)
    
    df_.player.replace({'Marcus Morris':'Marcus Morris Sr.'}, inplace=True)
    
    df_.player.replace({'Matt Williams':'Matt Williams Jr.'}, inplace=True)
    
    df_.player.replace({"Maurice N'dour":'Maurice Ndour'}, inplace=True)
    
    df_.player.replace({'Milos Tedosic':'Milos Teodosic'}, inplace=True)
    
    df_.player.replace({'Moe Harkless':'Maurice Harkless'}, inplace=True)
    
    df_.player.replace({'O.G. Anunoby':'OG Anunoby'}, inplace=True)
    
    df_.player.replace({'Ognen Kuzmic':'Ognjen Kuzmic'}, inplace=True)
    
    df_.player.replace({'P.J. Dozier':'PJ Dozier'}, inplace=True)
    
    df_.player.replace({'P.J. Hairston':'PJ Hairston'}, inplace=True)
    
    df_.player.replace({'Qi Zhou':'Zhou Qi'}, inplace=True)
    
    df_.player.replace({'R.J. Hunter':'RJ Hunter'}, inplace=True)
    
    df_.player.replace({'Ray McCallum Jr.':'Ray McCallum'}, inplace=True)
    
    df_.player.replace({'Ron Artest':'Metta World Peace'}, inplace=True)
    
    df_.player.replace({'Roy Marble':'Devyn Marble'}, inplace=True)
    
    df_.player.replace({'Stephen Zimmerman Jr.':'Stephen Zimmerman'}, inplace=True)
    
    df_.player.replace({'Tony Wroten Jr.':'Tony Wroten'}, inplace=True)
    
    df_.player.replace({'Toure Murry':"Toure' Murry"}, inplace=True)
    
    df_.player.replace({'Viacheslav Kravstov':'Viacheslav Kravtsov'}, inplace=True)
    
    df_.player.replace({'Vince Hunter':'Vincent Hunter'}, inplace=True)
    
    df_.player.replace({'Walker Russell Jr.':'Walker Russell'}, inplace=True)
    
    df_.player.replace({'Wayne Selden Jr.':'Wayne Selden'}, inplace=True)
    
    df_.player.replace({'Wes Matthews Jr.':'Wesley Matthews'}, inplace=True)
    
    return df_

#names dropped from Injury Report dataframe df_inj1018 for the following reasons:
#a. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons.
#b. player did not play an nba regular season or playoff game between the 2009-10 and 2017-18 seasons.
#c. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons. Player plays in nba games
#   following the 2017-18 season.
#d. this is the injury of a coach, not a player. coaches do not have boxscore advanced stats


def drop_player(df_):
    df_.drop(df_[df_.player.str.contains('Marion Hillard')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Matt Janning')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains("Da'Sean Butler")].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Eric Griffin')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Harry Giles')].index, inplace = True) #c
    
    df_.drop(df_[df_.player.str.contains('Magnum Rolle')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Robert Vaden')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Steve Clifford')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Steve Kerr')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Terrico White')].index, inplace = True)#a
    
    df_.drop(df_[df_.player.str.contains('Tyronn Lue')].index, inplace = True) #d
    
    return df_

def df_inj1020_fix_Date_Team(df_):
    df_.loc[5923, ['Team']] = 'Pacers'
    return df_

def manual_not_the_actual_game_date_drop(df_):
    df_.drop(21307, inplace=True) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_.reset_index(drop=True, inplace=True)
    return df_

'''def manual_not_the_game_date_drop2(df_):
    df_ = df_.drop(14084) #df_[(df_.game_date == '2013-05-10') & (df_.player == 'Eric Gordon')]
    df_ = df_.reset_index(drop=True)
    return df_'''


def get_5bsa1018_inj1018_player_diff():
    print(len(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME)))
    print(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME))
    print()
    
    print(len(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player)))
    print(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player))
    return 0
    
    
#get injury data for player
def gi(player_):
    return df_inj1018[df_inj1018.player.str.contains(player_)] 

#get boxscore advance for player
def gb(player_):
    return df_5bsa1018[df_5bsa1018.PLAYER_NAME.str.contains(player_)]

#get inactive player game-by-game
def gia(player_):
    return df_ina1018[df_ina1018.player.str.contains(player_)]

#return the first 5 and last 5 rows of this dataframe
def p(df_):
    if df_.shape[0] > 6:
        print(df_.shape)
        return pd.concat([df_.head(), df_.tail()])
    else:
        return df_

def rcp(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'processed_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'processed_data', file_), parse_dates=pd_)
    
def rcr(file_, pd_=None):
    if pd_ == None:
        return pd.read_csv(os.path.join('..', 'raw_data', file_))
    else:
        return pd.read_csv(os.path.join('..', 'raw_data', file_), parse_dates=pd_)

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
#get injury report for 2010-11 thru 2017-18 sesasons: df_inj1018

#last game_date of 2017-18 season
path = os.path.join('..', 'processed_data', '7season_first_game_date_last_game_date.csv')
df_7sfgdlgd = pd.read_csv(path, parse_dates=['first', 'last'])
last_game_date_s1718 = df_7sfgdlgd.iloc[8]['last']
last_game_date_s1718
# Out:
# Timestamp('2018-06-08 00:00:00')

# %%
#read in raw injury report
path = os.path.join('..', 'raw_data', 'injuries_2010-2020.csv')
df_inj1020 = pd.read_csv(path, parse_dates=['Date'])
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 5)
# (27105, 5)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls           NaN  Carlos Boozer
# 1     2010-10-06  Pistons           NaN  Jonas Jerebko
# 2     2010-10-06  Pistons           NaN  Terrico White
# 3     2010-10-08  Blazers           NaN     Jeff Ayres
# 4     2010-10-08     Nets           NaN    Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters            NaN
# 27101 2020-10-02     Heat           NaN    Bam Adebayo
# 27102 2020-10-02     Heat           NaN   Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva            NaN
# 27104 2020-10-06     Heat   Bam Adebayo            NaN
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# 4                        strained lower back (out indefinitely)
# 27100                                         activated from IL
# 27101                                       strained neck (DTD)
# 27102        placed on IL with torn plantar fascia in left foot
# 27103                                         activated from IL
# 27104                                        returned to lineup

# %%
#preprocess player & Date
df_inj1020.Acquired.fillna('', inplace=True)
df_inj1020.Relinquished.fillna('', inplace=True)
df_inj1020['player'] = df_inj1020.Relinquished + ' ' + df_inj1020.Acquired
df_inj1020.player = df_inj1020.player.str.strip()
df_inj1020 = df_inj1020_fix_Date_Team(df_inj1020)
print(df_inj1020.shape)
p(df_inj1020)
# Out:
# (27105, 6)
# (27105, 6)
#             Date     Team      Acquired   Relinquished  \
# 0     2010-10-03    Bulls                Carlos Boozer
# 1     2010-10-06  Pistons                Jonas Jerebko
# 2     2010-10-06  Pistons                Terrico White
# 3     2010-10-08  Blazers                   Jeff Ayres
# 4     2010-10-08     Nets                  Troy Murphy
# 27100 2020-09-30   Lakers  Dion Waiters
# 27101 2020-10-02     Heat                  Bam Adebayo
# 27102 2020-10-02     Heat                 Goran Dragic
# 27103 2020-10-02     Heat   Chris Silva
# 27104 2020-10-06     Heat   Bam Adebayo
#
#                                                           Notes         player
# 0       fractured bone in right pinky finger (out indefinitely)  Carlos Boozer
# 1                 torn right Achilles tendon (out indefinitely)  Jonas Jerebko
# 2      broken fifth metatarsal in right foot (out indefinitely)  Terrico White
# 3                     torn ACL in right knee (out indefinitely)     Jeff Ayres
# 4                        strained lower back (out indefinitely)    Troy Murphy
# 27100                                         activated from IL   Dion Waiters
# 27101                                       strained neck (DTD)    Bam Adebayo
# 27102        placed on IL with torn plantar fascia in left foot   Goran Dragic
# 27103                                         activated from IL    Chris Silva
# 27104                                        returned to lineup    Bam Adebayo

# %%
#bound last game date and make new dateframe: df_inj1018
df_inj1018 = df_inj1020.loc[df_inj1020['Date'] <= last_game_date_s1718]
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22257, 6)
# (22257, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 2     2010-10-06    Pistons                  Terrico White
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                           Notes  \
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# 3                     torn ACL in right knee (out indefinitely)
# 4                        strained lower back (out indefinitely)
# 22252                 strained right hamstring (out for season)
# 22253                                          concussion (DTD)
# 22254                                         activated from IL
# 22255                                        returned to lineup
# 22256                                        returned to lineup
#
#                player
# 0       Carlos Boozer
# 1       Jonas Jerebko
# 2       Terrico White
# 3          Jeff Ayres
# 4         Troy Murphy
# 22252      Chris Paul
# 22253      Kevin Love
# 22254   Patrick McCaw
# 22255      Kevin Love
# 22256  Andre Iguodala

# %%
#fix player (name)
df_inj1018 = replace_player(df_inj1018)
df_inj1018 = drop_player(df_inj1018)
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22232, 6)
# (22232, 6)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# 4                       strained lower back (out indefinitely)     Troy Murphy
# 5                 surgery to repair torn right Achilles tendon   Jonas Jerebko
# 22252                strained right hamstring (out for season)      Chris Paul
# 22253                                         concussion (DTD)      Kevin Love
# 22254                                        activated from IL   Patrick McCaw
# 22255                                       returned to lineup      Kevin Love
# 22256                                       returned to lineup  Andre Iguodala

# %%
p(df_inj1018)
# Out:
# (22232, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# 4                       strained lower back (out indefinitely)     Troy Murphy
# 5                 surgery to repair torn right Achilles tendon   Jonas Jerebko
# 22252                strained right hamstring (out for season)      Chris Paul
# 22253                                         concussion (DTD)      Kevin Love
# 22254                                        activated from IL   Patrick McCaw
# 22255                                       returned to lineup      Kevin Love
# 22256                                       returned to lineup  Andre Iguodala

# %%
#add team_id, player_id, game_id

# %%
#team_id

#merge 3gdgiti (game_date, season) with od get unique --> season

#season, Team --> team_id

# %%
df_3gds = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'season']].drop_duplicates().reset_index(drop=True)
p(df_3gds)
# Out:
# (2450, 2)
#       game_date   season
# 0    2006-10-31  2006-07
# 1    2006-11-01  2006-07
# 2    2006-11-02  2006-07
# 3    2006-11-03  2006-07
# 4    2006-11-04  2006-07
# 2445 2018-05-28  2017-18
# 2446 2018-05-31  2017-18
# 2447 2018-06-03  2017-18
# 2448 2018-06-06  2017-18
# 2449 2018-06-08  2017-18

# %%
#merge 3gdgiti (game_date, season) with od get unique --> season
df_inj1018_dgd = pd.merge(df_3gds.rename(columns={'game_date':'Date_game_date'}), df_inj1018.rename(columns={'Date':'Date_game_date'}), on='Date_game_date', how='inner')
p(df_inj1018_dgd)
# Out:
# (21921, 7)
#       Date_game_date   season       Team        Acquired      Relinquished  \
# 0         2010-10-26  2010-11    Blazers                   Elliot Williams
# 1         2010-10-26  2010-11    Blazers                         Greg Oden
# 2         2010-10-26  2010-11    Blazers                    Joel Przybilla
# 3         2010-10-26  2010-11    Celtics                     Avery Bradley
# 4         2010-10-26  2010-11    Celtics                  Kendrick Perkins
# 21916     2018-05-22  2017-18   Warriors                    Andre Iguodala
# 21917     2018-05-26  2017-18  Cavaliers                        Kevin Love
# 21918     2018-05-26  2017-18   Warriors   Patrick McCaw
# 21919     2018-05-31  2017-18  Cavaliers      Kevin Love
# 21920     2018-06-06  2017-18   Warriors  Andre Iguodala
#
#                                                                                                    Notes  \
# 0                                                                                           placed on IL
# 1                                                    placed on IL with left knee injury (out for season)
# 2      placed on IL placed on IL recovering from surgery on right knee to repair ruptured patella tendon
# 3                                                     placed on IL recovering from surgery on left ankle
# 4                                  placed on IL recovering from surgery on right knee to repair torn ACL
# 21916                                                                             bruised left leg (DTD)
# 21917                                                                                   concussion (DTD)
# 21918                                                                                  activated from IL
# 21919                                                                                 returned to lineup
# 21920                                                                                 returned to lineup
#
#                  player
# 0       Elliot Williams
# 1             Greg Oden
# 2        Joel Przybilla
# 3         Avery Bradley
# 4      Kendrick Perkins
# 21916    Andre Iguodala
# 21917        Kevin Love
# 21918     Patrick McCaw
# 21919        Kevin Love
# 21920    Andre Iguodala

# %% [markdown]
# <font color='red'>are these the actual game dates or just dates nba games are played on which a player injury report was made on??? </font>

# %%
#season, Team --> team_id
df_tist = rcp('10team_id_season_team_2010_2018.csv')
p(df_tist)
# Out:
# (240, 3)
#         TEAM_ID   season      Team
# 0    1610612748  2010-11      Heat
# 1    1610612749  2010-11     Bucks
# 2    1610612765  2010-11   Pistons
# 3    1610612753  2010-11     Magic
# 4    1610612737  2010-11     Hawks
# 235  1610612752  2017-18    Knicks
# 236  1610612758  2017-18     Kings
# 237  1610612744  2017-18  Warriors
# 238  1610612765  2017-18   Pistons
# 239  1610612746  2017-18  Clippers

# %%
df_inj1018_dgdti = pd.merge(df_tist, df_inj1018_dgd, on=['season', 'Team'], how='inner')
p(df_inj1018_dgdti)
# Out:
# (21920, 8)
#           TEAM_ID   season      Team Date_game_date          Acquired  \
# 0      1610612748  2010-11      Heat     2010-10-26
# 1      1610612748  2010-11      Heat     2010-10-26
# 2      1610612748  2010-11      Heat     2010-10-26
# 3      1610612748  2010-11      Heat     2010-10-26
# 4      1610612748  2010-11      Heat     2010-10-27
# 21915  1610612746  2017-18  Clippers     2018-03-30  Danilo Gallinari
# 21916  1610612746  2017-18  Clippers     2018-04-03
# 21917  1610612746  2017-18  Clippers     2018-04-03
# 21918  1610612746  2017-18  Clippers     2018-04-09
# 21919  1610612746  2017-18  Clippers     2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21915
# 21916  Danilo Gallinari
# 21917       Jawun Evans
# 21918     Austin Rivers
# 21919      Lou Williams
#
#                                                                                                  Notes  \
# 0                                                                                         placed on IL
# 1                                                                                         placed on IL
# 2                                                                    sprained ankle (out indefinitely)
# 3      placed on IL recovering from surgery on right hand to repair a broken thumb and ligament damage
# 4                                                                                         placed on IL
# 21915                                                                                activated from IL
# 21916                                                                 sore right hand (out for season)
# 21917          placed on IL with abdominal injury / sports hernia / athletic pubalgia (out for season)
# 21918                                                                sore right elbow (out for season)
# 21919                                                            sprained right ankle (out for season)
#
#                  player
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21915  Danilo Gallinari
# 21916  Danilo Gallinari
# 21917       Jawun Evans
# 21918     Austin Rivers
# 21919      Lou Williams

# %%
#game_id

#team_id, Date_game_date --> game_date

#team_id, game_date --> game_id

#team_id, player, (season,) game_date --> game_id

# %% [markdown]
# <font color='red'> team_id and a game_date all i need to get game_id????</font>

# %%
#game_id

#team_id, Date_game_date --> game_date

# %%
df_3gdti = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'team_id']].drop_duplicates().reset_index(drop=True)
p(df_3gdti)
# Out:
# (31038, 2)
#        game_date     team_id
# 0     2006-10-31  1610612748
# 1     2006-10-31  1610612741
# 2     2006-10-31  1610612747
# 3     2006-10-31  1610612756
# 4     2006-11-01  1610612755
# 31033 2018-06-03  1610612744
# 31034 2018-06-06  1610612744
# 31035 2018-06-06  1610612739
# 31036 2018-06-08  1610612739
# 31037 2018-06-08  1610612744

# %%
#team_id, Date_game_date --> game_date
df_inj1018_gdti = pd.merge(df_inj1018_dgdti.rename(columns={'Date_game_date':'game_date', 'TEAM_ID':'team_id'}), df_3gdti, how='inner', on=['game_date', 'team_id'])
df_inj1018_gdti
# Out:
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# ...           ...      ...       ...        ...               ...
# 21065  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21066  1610612746  2017-18  Clippers 2018-04-03
# 21067  1610612746  2017-18  Clippers 2018-04-03
# 21068  1610612746  2017-18  Clippers 2018-04-09
# 21069  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# ...                 ...
# 21065
# 21066  Danilo Gallinari
# 21067       Jawun Evans
# 21068     Austin Rivers
# 21069      Lou Williams
#
#                                                                                                  Notes  \
# 0                                                                                         placed on IL
# 1                                                                                         placed on IL
# 2                                                                    sprained ankle (out indefinitely)
# 3      placed on IL recovering from surgery on right hand to repair a broken thumb and ligament damage
# 4                                                                                         placed on IL
# ...                                                                                                ...
# 21065                                                                                activated from IL
# 21066                                                                 sore right hand (out for season)
# 21067          placed on IL with abdominal injury / sports hernia / athletic pubalgia (out for season)
# 21068                                                                sore right elbow (out for season)
# 21069                                                            sprained right ankle (out for season)
#
#                  player
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# ...                 ...
# 21065  Danilo Gallinari
# 21066  Danilo Gallinari
# 21067       Jawun Evans
# 21068     Austin Rivers
# 21069      Lou Williams
#
# [21070 rows x 8 columns]

# %%
#game_id

#team_id, game_date --> game_id
df_3gdtigi = rcp('3game_id_game_date_team_id.csv', ['game_date'])[['game_date', 'team_id','game_id']].drop_duplicates().reset_index(drop=True)
p(df_3gdtigi)
# Out:
# (31038, 3)
#        game_date     team_id   game_id
# 0     2006-10-31  1610612748  20600001
# 1     2006-10-31  1610612741  20600001
# 2     2006-10-31  1610612747  20600002
# 3     2006-10-31  1610612756  20600002
# 4     2006-11-01  1610612755  20600003
# 31033 2018-06-03  1610612744  41700402
# 31034 2018-06-06  1610612744  41700403
# 31035 2018-06-06  1610612739  41700403
# 31036 2018-06-08  1610612739  41700404
# 31037 2018-06-08  1610612744  41700404

# %%
df_inj1018_gdti.columns
# Out:
# Index(['team_id', 'season', 'Team', 'game_date', 'Acquired', 'Relinquished',
#        'Notes', 'player'],
#       dtype='object')

# %%
#team_id, game_date --> game_id
df_inj1018_gdtigi = pd.merge(df_inj1018_gdti, df_3gdtigi, on=['team_id', 'game_date'])
p(df_inj1018_gdtigi)
# Out:
# (21070, 9)
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# 21065  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21066  1610612746  2017-18  Clippers 2018-04-03
# 21067  1610612746  2017-18  Clippers 2018-04-03
# 21068  1610612746  2017-18  Clippers 2018-04-09
# 21069  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# 21065
# 21066  Danilo Gallinari
# 21067       Jawun Evans
# 21068     Austin Rivers
# 21069      Lou Williams
#
#                                                                                                  Notes  \
# 0                                                                                         placed on IL
# 1                                                                                         placed on IL
# 2                                                                    sprained ankle (out indefinitely)
# 3      placed on IL recovering from surgery on right hand to repair a broken thumb and ligament damage
# 4                                                                                         placed on IL
# 21065                                                                                activated from IL
# 21066                                                                 sore right hand (out for season)
# 21067          placed on IL with abdominal injury / sports hernia / athletic pubalgia (out for season)
# 21068                                                                sore right elbow (out for season)
# 21069                                                            sprained right ankle (out for season)
#
#                  player   game_id
# 0        Dexter Pittman  21000001
# 1      Jerry Stackhouse  21000001
# 2        Mario Chalmers  21000001
# 3           Mike Miller  21000001
# 4       Jamaal Magloire  21000006
# 21065  Danilo Gallinari  21701137
# 21066  Danilo Gallinari  21701168
# 21067       Jawun Evans  21701168
# 21068     Austin Rivers  21701212
# 21069      Lou Williams  21701212

# %%
df_inj1018_gdtigi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21070 entries, 0 to 21069
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   team_id       21070 non-null  int64
#  1   season        21070 non-null  object
#  2   Team          21070 non-null  object
#  3   game_date     21070 non-null  datetime64[ns]
#  4   Acquired      21070 non-null  object
#  5   Relinquished  21070 non-null  object
#  6   Notes         21070 non-null  object
#  7   player        21070 non-null  object
#  8   game_id       21070 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
#player_id

#team_id, player, (season,) game_date --> player_id

#team_id, player, season -?-?-> player_id

# %%
rcp('14player_id_player_team_id_season_team_2010_2018.csv')
# Out:
#       PLAYER_ID             player     team_id     Team   season
# 0      202376.0     Luke Harangody  1610612738  Celtics  2010-11
# 1        2570.0   Kendrick Perkins  1610612738  Celtics  2010-11
# 2      202340.0      Avery Bradley  1610612738  Celtics  2010-11
# 3      202354.0     Dexter Pittman  1610612748     Heat  2010-11
# 4        2034.0        Mike Miller  1610612748     Heat  2010-11
# ...         ...                ...         ...      ...      ...
# 4257  1626195.0  Willy Hernangomez  1610612752   Knicks  2017-18
# 4258   203504.0         Trey Burke  1610612752   Knicks  2017-18
# 4259   202722.0      Davis Bertans  1610612759    Spurs  2017-18
# 4260  1627749.0    Dejounte Murray  1610612759    Spurs  2017-18
# 4261  1627854.0        Bryn Forbes  1610612759    Spurs  2017-18
#
# [4262 rows x 5 columns]

# %%
df_inj1018_gdtigi
# Out:
#           team_id   season      Team  game_date          Acquired  \
# 0      1610612748  2010-11      Heat 2010-10-26
# 1      1610612748  2010-11      Heat 2010-10-26
# 2      1610612748  2010-11      Heat 2010-10-26
# 3      1610612748  2010-11      Heat 2010-10-26
# 4      1610612748  2010-11      Heat 2010-10-27
# ...           ...      ...       ...        ...               ...
# 21065  1610612746  2017-18  Clippers 2018-03-30  Danilo Gallinari
# 21066  1610612746  2017-18  Clippers 2018-04-03
# 21067  1610612746  2017-18  Clippers 2018-04-03
# 21068  1610612746  2017-18  Clippers 2018-04-09
# 21069  1610612746  2017-18  Clippers 2018-04-09
#
#            Relinquished  \
# 0        Dexter Pittman
# 1      Jerry Stackhouse
# 2        Mario Chalmers
# 3           Mike Miller
# 4       Jamaal Magloire
# ...                 ...
# 21065
# 21066  Danilo Gallinari
# 21067       Jawun Evans
# 21068     Austin Rivers
# 21069      Lou Williams
#
#                                                                                                  Notes  \
# 0                                                                                         placed on IL
# 1                                                                                         placed on IL
# 2                                                                    sprained ankle (out indefinitely)
# 3      placed on IL recovering from surgery on right hand to repair a broken thumb and ligament damage
# 4                                                                                         placed on IL
# ...                                                                                                ...
# 21065                                                                                activated from IL
# 21066                                                                 sore right hand (out for season)
# 21067          placed on IL with abdominal injury / sports hernia / athletic pubalgia (out for season)
# 21068                                                                sore right elbow (out for season)
# 21069                                                            sprained right ankle (out for season)
#
#                  player   game_id
# 0        Dexter Pittman  21000001
# 1      Jerry Stackhouse  21000001
# 2        Mario Chalmers  21000001
# 3           Mike Miller  21000001
# 4       Jamaal Magloire  21000006
# ...                 ...       ...
# 21065  Danilo Gallinari  21701137
# 21066  Danilo Gallinari  21701168
# 21067       Jawun Evans  21701168
# 21068     Austin Rivers  21701212
# 21069      Lou Williams  21701212
#
# [21070 rows x 9 columns]

# %%
df_gdgitispip = rcp('15game_date_game_id_team_id_season_player_id_player_2010_2018.csv', ['game_date'])
p(df_gdgitispip)
# Out:
# (334767, 6)
#         game_date   game_id     team_id   season  PLAYER_ID             player
# 0      2009-10-27  20900001  1610612739  2009-10     2544.0       LeBron James
# 1      2009-10-27  20900003  1610612745  2009-10   201978.0     Chase Budinger
# 2      2009-10-27  20900003  1610612745  2009-10   200822.0  Pops Mensah-Bonsu
# 3      2009-10-27  20900003  1610612745  2009-10     2431.0     David Andersen
# 4      2009-10-27  20900003  1610612745  2009-10   201171.0        Carl Landry
# 334762 2018-06-08  41700404  1610612739  2017-18   202684.0   Tristan Thompson
# 334763 2018-06-08  41700404  1610612739  2017-18   201567.0         Kevin Love
# 334764 2018-06-08  41700404  1610612739  2017-18     2544.0       LeBron James
# 334765 2018-06-08  41700404  1610612739  2017-18   203903.0    Jordan Clarkson
# 334766 2018-06-08  41700404  1610612744  2017-18  1627775.0      Patrick McCaw

# %%
df_pip = df_gdgitispip[['player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True)
p(df_pip)
# Out:
# (1155, 2)
#                  player  PLAYER_ID
# 0          LeBron James     2544.0
# 1        Chase Budinger   201978.0
# 2     Pops Mensah-Bonsu   200822.0
# 3        David Andersen     2431.0
# 4           Carl Landry   201171.0
# 1150     Jaylen Johnson  1628575.0
# 1151      Le'Bryan Nash  1626198.0
# 1152      Omari Johnson   204179.0
# 1153       Andre Ingram   201281.0
# 1154      Aaron Jackson  1628935.0

# %%
df_tipip = df_gdgitispip[['team_id','player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True)
p(df_tipip)
# Out:
# (2847, 3)
#          team_id             player  PLAYER_ID
# 0     1610612739       LeBron James     2544.0
# 1     1610612745     Chase Budinger   201978.0
# 2     1610612745  Pops Mensah-Bonsu   200822.0
# 3     1610612745     David Andersen     2431.0
# 4     1610612745        Carl Landry   201171.0
# 2842  1610612763      Omari Johnson   204179.0
# 2843  1610612738    Jonathan Gibson  1626780.0
# 2844  1610612747       Andre Ingram   201281.0
# 2845  1610612745      Aaron Jackson  1628935.0
# 2846  1610612764          Ty Lawson   201951.0

# %%
df_gdgitispip.columns
# Out:
# Index(['game_date', 'game_id', 'team_id', 'season', 'PLAYER_ID', 'player'], dtype='object')

# %%
#player_id

#team_id, player, (season,) game_date --> player_id

pd.merge(df_gdgitispip[['game_date', 'team_id','player', 'season', 'PLAYER_ID']], df_inj1018_gdtigi, on=['team_id', 'player', 'season', 'game_date'], how='inner').drop_duplicates().reset_index(drop=True)
# Out:
#        game_date     team_id             player   season  PLAYER_ID  \
# 0     2010-10-26  1610612745         Kyle Lowry  2010-11   200768.0
# 1     2010-10-26  1610612745    Jermaine Taylor  2010-11   201966.0
# 2     2010-10-26  1610612745  Patrick Patterson  2010-11   202335.0
# 3     2010-10-26  1610612747       Andrew Bynum  2010-11   101115.0
# 4     2010-10-26  1610612747        Luke Walton  2010-11     2575.0
# ...          ...         ...                ...      ...        ...
# 20642 2018-05-03  1610612738       Jaylen Brown  2017-18  1627759.0
# 20643 2018-05-09  1610612738       Shane Larkin  2017-18   203499.0
# 20644 2018-05-26  1610612744      Patrick McCaw  2017-18  1627775.0
# 20645 2018-05-31  1610612739         Kevin Love  2017-18   201567.0
# 20646 2018-06-06  1610612744     Andre Iguodala  2017-18     2738.0
#
#             Team        Acquired       Relinquished  \
# 0        Rockets                         Kyle Lowry
# 1        Rockets                    Jermaine Taylor
# 2        Rockets                  Patrick Patterson
# 3         Lakers                       Andrew Bynum
# 4         Lakers                        Luke Walton
# ...          ...             ...                ...
# 20642    Celtics    Jaylen Brown
# 20643    Celtics                       Shane Larkin
# 20644   Warriors   Patrick McCaw
# 20645  Cavaliers      Kevin Love
# 20646   Warriors  Andre Iguodala
#
#                                                                              Notes  \
# 0                                                    placed on IL with back spasms
# 1                                                                     placed on IL
# 2                                                                     placed on IL
# 3      placed on IL recovering from surgery on right knee to repair torn ligaments
# 4                                       placed on IL with strained right hamstring
# ...                                                                            ...
# 20642                                                           returned to lineup
# 20643                                      sprained left shoulder (out for season)
# 20644                                                            activated from IL
# 20645                                                           returned to lineup
# 20646                                                           returned to lineup
#
#         game_id
# 0      21000003
# 1      21000003
# 2      21000003
# 3      21000003
# 4      21000003
# ...         ...
# 20642  41700212
# 20643  41700215
# 20644  41700316
# 20645  41700401
# 20646  41700403
#
# [20647 rows x 10 columns]

# %% [markdown]
# <font color='red'> why the row drops when merging for player id???</font>

# %%
#team_id, player, game_date --> player_id
pd.merge(df_gdgitispip[['game_date', 'team_id','player', 'PLAYER_ID']], df_inj1018_gdtigi, on=['team_id', 'player','game_date'], how='inner').drop_duplicates().reset_index(drop=True)
# Out:
#        game_date     team_id             player  PLAYER_ID   season  \
# 0     2010-10-26  1610612745         Kyle Lowry   200768.0  2010-11
# 1     2010-10-26  1610612745    Jermaine Taylor   201966.0  2010-11
# 2     2010-10-26  1610612745  Patrick Patterson   202335.0  2010-11
# 3     2010-10-26  1610612747       Andrew Bynum   101115.0  2010-11
# 4     2010-10-26  1610612747        Luke Walton     2575.0  2010-11
# ...          ...         ...                ...        ...      ...
# 20642 2018-05-03  1610612738       Jaylen Brown  1627759.0  2017-18
# 20643 2018-05-09  1610612738       Shane Larkin   203499.0  2017-18
# 20644 2018-05-26  1610612744      Patrick McCaw  1627775.0  2017-18
# 20645 2018-05-31  1610612739         Kevin Love   201567.0  2017-18
# 20646 2018-06-06  1610612744     Andre Iguodala     2738.0  2017-18
#
#             Team        Acquired       Relinquished  \
# 0        Rockets                         Kyle Lowry
# 1        Rockets                    Jermaine Taylor
# 2        Rockets                  Patrick Patterson
# 3         Lakers                       Andrew Bynum
# 4         Lakers                        Luke Walton
# ...          ...             ...                ...
# 20642    Celtics    Jaylen Brown
# 20643    Celtics                       Shane Larkin
# 20644   Warriors   Patrick McCaw
# 20645  Cavaliers      Kevin Love
# 20646   Warriors  Andre Iguodala
#
#                                                                              Notes  \
# 0                                                    placed on IL with back spasms
# 1                                                                     placed on IL
# 2                                                                     placed on IL
# 3      placed on IL recovering from surgery on right knee to repair torn ligaments
# 4                                       placed on IL with strained right hamstring
# ...                                                                            ...
# 20642                                                           returned to lineup
# 20643                                      sprained left shoulder (out for season)
# 20644                                                            activated from IL
# 20645                                                           returned to lineup
# 20646                                                           returned to lineup
#
#         game_id
# 0      21000003
# 1      21000003
# 2      21000003
# 3      21000003
# 4      21000003
# ...         ...
# 20642  41700212
# 20643  41700215
# 20644  41700316
# 20645  41700401
# 20646  41700403
#
# [20647 rows x 10 columns]

# %%
df_merge2 = pd.merge(df_gdgitispip[['game_date', 'team_id','player', 'PLAYER_ID']], df_inj1018_gdtigi, on=['team_id', 'player','game_date'], how='outer', indicator=True).drop_duplicates().reset_index(drop=True)
p(df_merge2)
# Out:
# (335480, 11)
#         game_date     team_id             player  PLAYER_ID   season  \
# 0      2009-10-27  1610612739       LeBron James     2544.0      NaN
# 1      2009-10-27  1610612745     Chase Budinger   201978.0      NaN
# 2      2009-10-27  1610612745  Pops Mensah-Bonsu   200822.0      NaN
# 3      2009-10-27  1610612745     David Andersen     2431.0      NaN
# 4      2009-10-27  1610612745        Carl Landry   201171.0      NaN
# 335475 2018-04-20  1610612749        John Henson        NaN  2017-18
# 335476 2018-04-15  1610612749   Brandon Jennings        NaN  2017-18
# 335477 2018-04-15  1610612749        D.J. Wilson        NaN  2017-18
# 335478 2018-05-01  1610612744       Damian Jones        NaN  2017-18
# 335479 2018-05-22  1610612744     Andre Iguodala        NaN  2017-18
#
#             Team     Acquired      Relinquished  \
# 0            NaN          NaN               NaN
# 1            NaN          NaN               NaN
# 2            NaN          NaN               NaN
# 3            NaN          NaN               NaN
# 4            NaN          NaN               NaN
# 335475     Bucks                    John Henson
# 335476     Bucks               Brandon Jennings
# 335477     Bucks  D.J. Wilson
# 335478  Warriors                   Damian Jones
# 335479  Warriors                 Andre Iguodala
#
#                                                Notes     game_id      _merge
# 0                                                NaN         NaN   left_only
# 1                                                NaN         NaN   left_only
# 2                                                NaN         NaN   left_only
# 3                                                NaN         NaN   left_only
# 4                                                NaN         NaN   left_only
# 335475  placed on IL with sore back (out for season)  41700113.0  right_only
# 335476                                  placed on IL  41700111.0  right_only
# 335477                             activated from IL  41700111.0  right_only
# 335478                                  placed on IL  41700232.0  right_only
# 335479                        bruised left leg (DTD)  41700314.0  right_only

# %%
df_merge2.value_counts('_merge')
# Out:
# _merge
# left_only     314411
# both           20647
# right_only       422
# dtype: int64

# %%
#team_id, player, game_id --> player_id
pd.merge(df_gdgitispip[['game_id', 'team_id','player', 'PLAYER_ID']], df_inj1018_gdtigi, on=['team_id', 'player','game_id'], how='inner').drop_duplicates().reset_index(drop=True)
# Out:
#         game_id     team_id             player  PLAYER_ID   season       Team  \
# 0      21000003  1610612745         Kyle Lowry   200768.0  2010-11    Rockets
# 1      21000003  1610612745    Jermaine Taylor   201966.0  2010-11    Rockets
# 2      21000003  1610612745  Patrick Patterson   202335.0  2010-11    Rockets
# 3      21000003  1610612747       Andrew Bynum   101115.0  2010-11     Lakers
# 4      21000003  1610612747        Luke Walton     2575.0  2010-11     Lakers
# ...         ...         ...                ...        ...      ...        ...
# 20642  41700212  1610612738       Jaylen Brown  1627759.0  2017-18    Celtics
# 20643  41700215  1610612738       Shane Larkin   203499.0  2017-18    Celtics
# 20644  41700316  1610612744      Patrick McCaw  1627775.0  2017-18   Warriors
# 20645  41700401  1610612739         Kevin Love   201567.0  2017-18  Cavaliers
# 20646  41700403  1610612744     Andre Iguodala     2738.0  2017-18   Warriors
#
#        game_date        Acquired       Relinquished  \
# 0     2010-10-26                         Kyle Lowry
# 1     2010-10-26                    Jermaine Taylor
# 2     2010-10-26                  Patrick Patterson
# 3     2010-10-26                       Andrew Bynum
# 4     2010-10-26                        Luke Walton
# ...          ...             ...                ...
# 20642 2018-05-03    Jaylen Brown
# 20643 2018-05-09                       Shane Larkin
# 20644 2018-05-26   Patrick McCaw
# 20645 2018-05-31      Kevin Love
# 20646 2018-06-06  Andre Iguodala
#
#                                                                              Notes
# 0                                                    placed on IL with back spasms
# 1                                                                     placed on IL
# 2                                                                     placed on IL
# 3      placed on IL recovering from surgery on right knee to repair torn ligaments
# 4                                       placed on IL with strained right hamstring
# ...                                                                            ...
# 20642                                                           returned to lineup
# 20643                                      sprained left shoulder (out for season)
# 20644                                                            activated from IL
# 20645                                                           returned to lineup
# 20646                                                           returned to lineup
#
# [20647 rows x 10 columns]

# %%
#team_id, season, player, game_id --> player_id
pd.merge(df_gdgitispip[['game_id', 'team_id','player', 'season','PLAYER_ID']], df_inj1018_gdtigi, on=['team_id', 'season', 'player','game_id'], how='inner').drop_duplicates().reset_index(drop=True)
# Out:
#         game_id     team_id             player   season  PLAYER_ID       Team  \
# 0      21000003  1610612745         Kyle Lowry  2010-11   200768.0    Rockets
# 1      21000003  1610612745    Jermaine Taylor  2010-11   201966.0    Rockets
# 2      21000003  1610612745  Patrick Patterson  2010-11   202335.0    Rockets
# 3      21000003  1610612747       Andrew Bynum  2010-11   101115.0     Lakers
# 4      21000003  1610612747        Luke Walton  2010-11     2575.0     Lakers
# ...         ...         ...                ...      ...        ...        ...
# 20642  41700212  1610612738       Jaylen Brown  2017-18  1627759.0    Celtics
# 20643  41700215  1610612738       Shane Larkin  2017-18   203499.0    Celtics
# 20644  41700316  1610612744      Patrick McCaw  2017-18  1627775.0   Warriors
# 20645  41700401  1610612739         Kevin Love  2017-18   201567.0  Cavaliers
# 20646  41700403  1610612744     Andre Iguodala  2017-18     2738.0   Warriors
#
#        game_date        Acquired       Relinquished  \
# 0     2010-10-26                         Kyle Lowry
# 1     2010-10-26                    Jermaine Taylor
# 2     2010-10-26                  Patrick Patterson
# 3     2010-10-26                       Andrew Bynum
# 4     2010-10-26                        Luke Walton
# ...          ...             ...                ...
# 20642 2018-05-03    Jaylen Brown
# 20643 2018-05-09                       Shane Larkin
# 20644 2018-05-26   Patrick McCaw
# 20645 2018-05-31      Kevin Love
# 20646 2018-06-06  Andre Iguodala
#
#                                                                              Notes
# 0                                                    placed on IL with back spasms
# 1                                                                     placed on IL
# 2                                                                     placed on IL
# 3      placed on IL recovering from surgery on right knee to repair torn ligaments
# 4                                       placed on IL with strained right hamstring
# ...                                                                            ...
# 20642                                                           returned to lineup
# 20643                                      sprained left shoulder (out for season)
# 20644                                                            activated from IL
# 20645                                                           returned to lineup
# 20646                                                           returned to lineup
#
# [20647 rows x 10 columns]

# %%
#team_id, season, player, game_id, game_date --> player_id
df_merged = pd.merge(df_gdgitispip[['game_id', 'game_date', 'team_id','player', 'season', 'PLAYER_ID']], df_inj1018_gdtigi, on=['team_id','season', 'player','game_id', 'game_date'], how='outer', indicator=True).drop_duplicates().reset_index(drop=True)
p(df_merged)
# Out:
# (335480, 11)
#          game_id  game_date     team_id             player   season  \
# 0       20900001 2009-10-27  1610612739       LeBron James  2009-10
# 1       20900003 2009-10-27  1610612745     Chase Budinger  2009-10
# 2       20900003 2009-10-27  1610612745  Pops Mensah-Bonsu  2009-10
# 3       20900003 2009-10-27  1610612745     David Andersen  2009-10
# 4       20900003 2009-10-27  1610612745        Carl Landry  2009-10
# 335475  41700113 2018-04-20  1610612749        John Henson  2017-18
# 335476  41700111 2018-04-15  1610612749   Brandon Jennings  2017-18
# 335477  41700111 2018-04-15  1610612749        D.J. Wilson  2017-18
# 335478  41700232 2018-05-01  1610612744       Damian Jones  2017-18
# 335479  41700314 2018-05-22  1610612744     Andre Iguodala  2017-18
#
#         PLAYER_ID      Team     Acquired      Relinquished  \
# 0          2544.0       NaN          NaN               NaN
# 1        201978.0       NaN          NaN               NaN
# 2        200822.0       NaN          NaN               NaN
# 3          2431.0       NaN          NaN               NaN
# 4        201171.0       NaN          NaN               NaN
# 335475        NaN     Bucks                    John Henson
# 335476        NaN     Bucks               Brandon Jennings
# 335477        NaN     Bucks  D.J. Wilson
# 335478        NaN  Warriors                   Damian Jones
# 335479        NaN  Warriors                 Andre Iguodala
#
#                                                Notes      _merge
# 0                                                NaN   left_only
# 1                                                NaN   left_only
# 2                                                NaN   left_only
# 3                                                NaN   left_only
# 4                                                NaN   left_only
# 335475  placed on IL with sore back (out for season)  right_only
# 335476                                  placed on IL  right_only
# 335477                             activated from IL  right_only
# 335478                                  placed on IL  right_only
# 335479                        bruised left leg (DTD)  right_only

# %%
df_merged.value_counts('_merge')
# Out:
# _merge
# left_only     314411
# both           20647
# right_only       422
# dtype: int64

# %%
p(df_merged[df_merged._merge == 'right_only'])
# Out:
# (422, 11)
#          game_id  game_date     team_id              player   season  \
# 335058  41000214 2011-05-09  1610612748     Jamaal Magloire  2010-11
# 335059  41000301 2011-05-15  1610612748  Zydrunas Ilgauskas  2010-11
# 335060  41000303 2011-05-22  1610612748     Jamaal Magloire  2010-11
# 335061  41000401 2011-05-31  1610612748  Zydrunas Ilgauskas  2010-11
# 335062  41000131 2011-04-16  1610612753        Daniel Orton  2010-11
# 335475  41700113 2018-04-20  1610612749         John Henson  2017-18
# 335476  41700111 2018-04-15  1610612749    Brandon Jennings  2017-18
# 335477  41700111 2018-04-15  1610612749         D.J. Wilson  2017-18
# 335478  41700232 2018-05-01  1610612744        Damian Jones  2017-18
# 335479  41700314 2018-05-22  1610612744      Andre Iguodala  2017-18
#
#         PLAYER_ID      Team     Acquired        Relinquished  \
# 335058        NaN      Heat                  Jamaal Magloire
# 335059        NaN      Heat               Zydrunas Ilgauskas
# 335060        NaN      Heat                  Jamaal Magloire
# 335061        NaN      Heat               Zydrunas Ilgauskas
# 335062        NaN     Magic                     Daniel Orton
# 335475        NaN     Bucks                      John Henson
# 335476        NaN     Bucks                 Brandon Jennings
# 335477        NaN     Bucks  D.J. Wilson
# 335478        NaN  Warriors                     Damian Jones
# 335479        NaN  Warriors                   Andre Iguodala
#
#                                                           Notes      _merge
# 335058                                             placed on IL  right_only
# 335059                                             placed on IL  right_only
# 335060                                             placed on IL  right_only
# 335061                                             placed on IL  right_only
# 335062  placed on IL with surgery on left knee (out for season)  right_only
# 335475             placed on IL with sore back (out for season)  right_only
# 335476                                             placed on IL  right_only
# 335477                                        activated from IL  right_only
# 335478                                             placed on IL  right_only
# 335479                                   bruised left leg (DTD)  right_only

# %%
df_merged[df_merged._merge == 'right_only']
# Out:
#          game_id  game_date     team_id                   player   season  \
# 335058  41000214 2011-05-09  1610612748          Jamaal Magloire  2010-11
# 335059  41000301 2011-05-15  1610612748       Zydrunas Ilgauskas  2010-11
# 335060  41000303 2011-05-22  1610612748          Jamaal Magloire  2010-11
# 335061  41000401 2011-05-31  1610612748       Zydrunas Ilgauskas  2010-11
# 335062  41000131 2011-04-16  1610612753             Daniel Orton  2010-11
# 335063  41000131 2011-04-16  1610612737                  Pape Sy  2010-11
# 335064  41000135 2011-04-26  1610612737              Etan Thomas  2010-11
# 335065  41000134 2011-04-24  1610612737           Damien Wilkins  2010-11
# 335066  41000132 2011-04-19  1610612737              Etan Thomas  2010-11
# 335067  41000201 2011-05-02  1610612737             Kirk Hinrich  2010-11
# 335068  41000173 2011-04-23  1610612743           Timofey Mozgov  2010-11
# 335069  41000171 2011-04-17  1610612743            Arron Afflalo  2010-11
# 335468  41700221 2018-04-29  1610612762              Ricky Rubio  2017-18
# 335469  41700225 2018-05-08  1610612762               Dante Exum  2017-18
# 335470  41700101 2018-04-14  1610612764         Chris McCullough  2017-18
# 335471  41700101 2018-04-14  1610612764           Ramon Sessions  2017-18
# 335472  41700106 2018-04-27  1610612764              Jodie Meeks  2017-18
# 335473  41700106 2018-04-27  1610612764          Otto Porter Jr.  2017-18
# 335474  41700106 2018-04-27  1610612764          Otto Porter Jr.  2017-18
# 335475  41700113 2018-04-20  1610612749              John Henson  2017-18
# 335476  41700111 2018-04-15  1610612749         Brandon Jennings  2017-18
# 335477  41700111 2018-04-15  1610612749              D.J. Wilson  2017-18
# 335478  41700232 2018-05-01  1610612744             Damian Jones  2017-18
# 335479  41700314 2018-05-22  1610612744           Andre Iguodala  2017-18
#
#         PLAYER_ID          Team                 Acquired  \
# 335058        NaN          Heat
# 335059        NaN          Heat
# 335060        NaN          Heat
# 335061        NaN          Heat
# 335062        NaN         Magic
# 335063        NaN         Hawks
# 335064        NaN         Hawks
# 335065        NaN         Hawks
# 335066        NaN         Hawks
# 335067        NaN         Hawks
# 335068        NaN       Nuggets
# 335069        NaN       Nuggets
# 335070        NaN       Nuggets
# 335071        NaN       Blazers
# 335072        NaN       Celtics
# 335073        NaN       Celtics
# 335074        NaN       Celtics           Sasha Pavlovic
# 335075        NaN       Celtics
# 335076        NaN        Knicks         Chauncey Billups
# 335077        NaN        Knicks
# 335078        NaN        Knicks
# 335079        NaN         Bulls
# 335080        NaN         Bulls
# 335081        NaN         Bulls
# 335082        NaN        Lakers
# 335083        NaN        Lakers
# 335084        NaN        Lakers
# 335085        NaN        Lakers
# 335086        NaN       Thunder
# 335087        NaN       Thunder
# 335088        NaN       Thunder
# 335089        NaN       Thunder
# 335090        NaN       Thunder
# 335091        NaN        Pacers
# 335092        NaN         Spurs
# 335093        NaN         76ers
# 335094        NaN         76ers
# 335095        NaN         76ers
# 335096        NaN     Mavericks
# 335097        NaN     Mavericks
# 335098        NaN     Mavericks
# 335099        NaN     Mavericks
# 335100        NaN     Mavericks
# 335101        NaN     Mavericks
# 335102        NaN       Bobcats          Sherron Collins
# 335103        NaN        Knicks
# 335104        NaN        Knicks
# 335105        NaN        Knicks
# 335106        NaN        Knicks
# 335107        NaN      Clippers
# 335108        NaN      Clippers             Chris Wright
# 335109        NaN      Clippers
# 335110        NaN      Clippers
# 335111        NaN      Clippers
# 335112        NaN      Clippers
# 335113        NaN      Clippers
# 335114        NaN         76ers
# 335115        NaN         76ers
# 335116        NaN        Lakers
# 335117        NaN        Lakers
# 335118        NaN        Lakers
# 335119        NaN       Celtics
# 335120        NaN       Celtics             Chris Wilcox
# 335121        NaN       Celtics          Jermaine O'Neal
# 335122        NaN       Celtics
# 335123        NaN       Celtics
# 335124        NaN       Celtics
# 335125        NaN       Hornets           Chris Johnson
# 335126        NaN         Hawks
# 335127        NaN     Grizzlies
# 335128        NaN         Bulls
# 335129        NaN         Bulls
# 335130        NaN          Heat
# 335131        NaN          Heat
# 335132        NaN          Heat
# 335133        NaN          Heat
# 335134        NaN          Heat
# 335135        NaN         Spurs
# 335136        NaN         Spurs
# 335137        NaN         Spurs
# 335138        NaN        Pacers
# 335139        NaN       Nuggets
# 335140        NaN       Nuggets
# 335141        NaN     Mavericks
# 335142        NaN       Wizards
# 335143        NaN       Blazers
# 335144        NaN       Thunder
# 335145        NaN         Magic
# 335146        NaN       Nuggets
# 335147        NaN       Nuggets
# 335148        NaN      Warriors
# 335149        NaN      Warriors
# 335150        NaN      Warriors
# 335151        NaN        Knicks
# 335152        NaN        Knicks
# 335153        NaN        Knicks
# 335154        NaN        Knicks
# 335155        NaN        Knicks
# 335156        NaN        Lakers
# 335157        NaN        Lakers
# 335158        NaN        Lakers
# 335159        NaN  Timberwolves
# 335160        NaN         Spurs
# 335161        NaN         Spurs
# 335162        NaN         Spurs
# 335163        NaN         Spurs
# 335164        NaN       Rockets
# 335165        NaN       Rockets
# 335166        NaN          Heat
# 335167        NaN          Heat
# 335168        NaN          Heat
# 335169        NaN          Heat
# 335170        NaN      Clippers             Maalik Wayns
# 335171        NaN      Clippers
# 335172        NaN      Clippers
# 335173        NaN      Clippers
# 335174        NaN     Grizzlies
# 335175        NaN     Grizzlies
# 335176        NaN         Bucks
# 335177        NaN         Bucks
# 335178        NaN        Pacers
# 335179        NaN        Pacers
# 335180        NaN        Pacers
# 335181        NaN         Bulls
# 335182        NaN         Bulls
# 335183        NaN         Bulls
# 335184        NaN         Bulls
# 335185        NaN       Thunder
# 335186        NaN       Thunder
# 335187        NaN       Thunder
# 335188        NaN       Thunder
# 335189        NaN       Thunder
# 335190        NaN       Thunder        Russell Westbrook
# 335191        NaN       Thunder
# 335192        NaN       Thunder
# 335193        NaN       Thunder
# 335194        NaN       Thunder
# 335195        NaN       Thunder
# 335196        NaN       Rockets
# 335197        NaN       Rockets
# 335198        NaN      Warriors
# 335199        NaN      Warriors
# 335200        NaN      Warriors
# 335201        NaN      Warriors
# 335202        NaN      Warriors
# 335203        NaN      Warriors
# 335204        NaN      Warriors
# 335205        NaN      Warriors
# 335206        NaN      Warriors
# 335207        NaN      Warriors
# 335208        NaN       Wizards
# 335209        NaN       Raptors
# 335210        NaN       Raptors
# 335211        NaN       Raptors
# 335212        NaN       Raptors
# 335213        NaN       Raptors
# 335214        NaN       Blazers
# 335215        NaN       Blazers
# 335216        NaN       Blazers
# 335217        NaN       Blazers
# 335218        NaN       Blazers
# 335219        NaN         Spurs
# 335220        NaN         Spurs
# 335221        NaN         Spurs
# 335222        NaN        Pacers
# 335223        NaN        Pacers
# 335224        NaN        Pacers
# 335225        NaN        Pacers
# 335226        NaN      Clippers
# 335227        NaN      Clippers
# 335228        NaN     Grizzlies
# 335229        NaN     Grizzlies
# 335230        NaN     Grizzlies
# 335231        NaN     Mavericks
# 335232        NaN     Mavericks
# 335233        NaN     Mavericks
# 335234        NaN     Mavericks
# 335235        NaN     Mavericks
# 335236        NaN     Mavericks
# 335237        NaN     Mavericks
# 335238        NaN     Mavericks
# 335239        NaN     Mavericks
# 335240        NaN         Bulls
# 335241        NaN          Heat
# 335242        NaN          Heat
# 335243        NaN          Heat
# 335244        NaN          Heat
# 335245        NaN          Heat
# 335246        NaN          Heat
# 335247        NaN          Heat
# 335248        NaN          Heat
# 335249        NaN          Nets
# 335250        NaN     Cavaliers
# 335251        NaN     Cavaliers
# 335252        NaN         Hawks               Al Horford
# 335253        NaN         Hawks             Gustavo Ayon
# 335254        NaN         Hawks             John Jenkins
# 335255        NaN       Thunder
# 335256        NaN       Thunder
# 335257        NaN       Thunder
# 335258        NaN       Thunder
# 335259        NaN        Lakers             Xavier Henry
# 335260        NaN        Lakers               Steve Nash
# 335261        NaN         76ers             Ronny Turiaf
# 335262        NaN       Wizards
# 335263        NaN       Wizards
# 335264        NaN       Wizards
# 335265        NaN       Wizards
# 335266        NaN       Wizards
# 335267        NaN       Wizards
# 335268        NaN         Bulls
# 335269        NaN         Bulls
# 335270        NaN         Bulls
# 335271        NaN         Bulls
# 335272        NaN         Bulls
# 335273        NaN      Clippers            Nate Robinson
# 335274        NaN      Clippers
# 335275        NaN      Clippers
# 335276        NaN      Clippers
# 335277        NaN      Clippers
# 335278        NaN         Spurs
# 335279        NaN         Spurs
# 335280        NaN        Knicks
# 335281        NaN        Knicks             Lou Amundson
# 335282        NaN        Knicks             Lou Amundson
# 335283        NaN      Warriors            James McAdoo
# 335284        NaN      Warriors
# 335285        NaN      Warriors
# 335286        NaN      Warriors
# 335287        NaN      Warriors
# 335288        NaN      Warriors
# 335289        NaN      Warriors
# 335290        NaN     Grizzlies
# 335291        NaN     Grizzlies
# 335292        NaN     Grizzlies
# 335293        NaN     Grizzlies
# 335294        NaN     Grizzlies
# 335295        NaN     Grizzlies
# 335296        NaN     Grizzlies
# 335297        NaN     Mavericks
# 335298        NaN     Mavericks
# 335299        NaN     Mavericks
# 335300        NaN     Mavericks
# 335301        NaN     Mavericks
# 335302        NaN          Nets
# 335303        NaN          Nets
# 335304        NaN     Cavaliers
# 335305        NaN     Cavaliers
# 335306        NaN         Hawks
# 335307        NaN         Hawks
# 335308        NaN       Celtics
# 335309        NaN       Celtics
# 335310        NaN       Hornets
# 335311        NaN       Hornets
# 335312        NaN       Hornets
# 335313        NaN       Hornets
# ...
# 335418                                                                                            placed on IL
# 335419                                                                                            placed on IL
# 335420                                                                                            placed on IL
# 335421                                                                                            placed on IL
# 335422                                            placed on IL with torn left adductor muscle (out for season)
# 335423                                                                           placed on IL (out for season)
# 335424                                                    placed on IL with strained left hip (out for season)
# 335425                                                                  placed on IL with sprained right ankle
# 335426                                                                                            placed on IL
# 335427                                                                        placed on IL with sore left knee
# 335428                                                                    placed on IL with bruised right heel
# 335429                                                                                            placed on IL
# 335430                                                 placed on IL with right big toe injury (out for season)
# 335431                                                               placed on IL with strained left hamstring
# 335432                                                                                            placed on IL
# 335433                                                                           placed on IL (out for season)
# 335434                                                                                            placed on IL
# 335435                   placed on IL recovering from surgery on left knee to repair torn ACL (out for season)
# 335436                                                                  placed on IL with sprained right ankle
# 335437                                                                                           illness (DTD)
# 335438                                                                           placed on IL (out for season)
# 335439                                                                                            placed on IL
# 335440                                                                                            placed on IL
# 335441                                                                                            placed on IL
# 335442                                                                                            placed on IL
# 335443                                                                                       activated from IL
# 335444                                                                                            placed on IL
# 335445                                                                            placed on IL with toe injury
# 335446                                                       placed on IL with sore left knee (out for season)
# 335447                                                                                            placed on IL
# 335448                                                                           placed on IL (out for season)
# 335449                                                                           placed on IL with back spasms
# 335450                                                                                            placed on IL
# 335451                                                                                            placed on IL
# 335452                                                                 placed on IL with right shoulder injury
# 335453                                                                                            placed on IL
# 335454                                                                                            placed on IL
# 335455                                                                 placed on IL with right shoulder injury
# 335456                                                                                            placed on IL
# 335457                                                                                       activated from IL
# 335458                                                                                       activated from IL
# 335459                                                                                       activated from IL
# 335460                                                                                            placed on IL
# 335461                                                                   surgery on left foot (out for season)
# 335462                                                    placed on IL with right knee injury (out for season)
# 335463                                                                                            placed on IL
# 335464                                                                                            placed on IL
# 335465                                                                                       activated from IL
# 335466                                                                                       activated from IL
# 335467                                                                                            placed on IL
# 335468                                              placed on IL with strained left hamstring (out for season)
# 335469                                              placed on IL with strained left hamstring (out for season)
# 335470                                                                                            placed on IL
# 335471                                                                                            placed on IL
# 335472                                                                                            placed on IL
# 335473                               surgery on left leg to remove blood around a contusion (out indefinitely)
# 335474                     placed on IL recovering from surgery on left leg to remove blood around a contusion
# 335475                                                            placed on IL with sore back (out for season)
# 335476                                                                                            placed on IL
# 335477                                                                                       activated from IL
# 335478                                                                                            placed on IL
# 335479                                                                                  bruised left leg (DTD)
#
#             _merge
# 335058  right_only
# 335059  right_only
# 335060  right_only
# 335061  right_only
# 335062  right_only
# 335063  right_only
# 335064  right_only
# 335065  right_only
# 335066  right_only
# 335067  right_only
# 335068  right_only
# 335069  right_only
# 335070  right_only
# 335071  right_only
# 335072  right_only
# 335073  right_only
# 335074  right_only
# 335075  right_only
# 335076  right_only
# 335077  right_only
# 335078  right_only
# 335079  right_only
# 335080  right_only
# 335081  right_only
# 335082  right_only
# 335083  right_only
# 335084  right_only
# 335085  right_only
# 335086  right_only
# 335087  right_only
# 335088  right_only
# 335089  right_only
# 335090  right_only
# 335091  right_only
# 335092  right_only
# 335093  right_only
# 335094  right_only
# 335095  right_only
# 335096  right_only
# 335097  right_only
# 335098  right_only
# 335099  right_only
# 335100  right_only
# 335101  right_only
# 335102  right_only
# 335103  right_only
# 335104  right_only
# 335105  right_only
# 335106  right_only
# 335107  right_only
# 335108  right_only
# 335109  right_only
# 335110  right_only
# 335111  right_only
# 335112  right_only
# 335113  right_only
# 335114  right_only
# 335115  right_only
# 335116  right_only
# 335117  right_only
# 335118  right_only
# 335119  right_only
# 335120  right_only
# 335121  right_only
# 335122  right_only
# 335123  right_only
# 335124  right_only
# 335125  right_only
# 335126  right_only
# 335127  right_only
# 335128  right_only
# 335129  right_only
# 335130  right_only
# 335131  right_only
# 335132  right_only
# 335133  right_only
# 335134  right_only
# 335135  right_only
# 335136  right_only
# 335137  right_only
# 335138  right_only
# 335139  right_only
# 335140  right_only
# 335141  right_only
# 335142  right_only
# 335143  right_only
# 335144  right_only
# 335145  right_only
# 335146  right_only
# 335147  right_only
# 335148  right_only
# 335149  right_only
# 335150  right_only
# 335151  right_only
# 335152  right_only
# 335153  right_only
# 335154  right_only
# 335155  right_only
# 335156  right_only
# 335157  right_only
# 335158  right_only
# 335159  right_only
# 335160  right_only
# 335161  right_only
# 335162  right_only
# 335163  right_only
# 335164  right_only
# 335165  right_only
# 335166  right_only
# 335167  right_only
# 335168  right_only
# 335169  right_only
# 335170  right_only
# 335171  right_only
# 335172  right_only
# 335173  right_only
# 335174  right_only
# 335175  right_only
# 335176  right_only
# 335177  right_only
# 335178  right_only
# 335179  right_only
# 335180  right_only
# 335181  right_only
# 335182  right_only
# 335183  right_only
# 335184  right_only
# 335185  right_only
# 335186  right_only
# 335187  right_only
# 335188  right_only
# 335189  right_only
# 335190  right_only
# 335191  right_only
# 335192  right_only
# 335193  right_only
# 335194  right_only
# 335195  right_only
# 335196  right_only
# 335197  right_only
# 335198  right_only
# 335199  right_only
# 335200  right_only
# 335201  right_only
# 335202  right_only
# 335203  right_only
# 335204  right_only
# 335205  right_only
# 335206  right_only
# 335207  right_only
# 335208  right_only
# 335209  right_only
# 335210  right_only
# 335211  right_only
# 335212  right_only
# 335213  right_only
# 335214  right_only
# 335215  right_only
# 335216  right_only
# 335217  right_only
# 335218  right_only
# 335219  right_only
# 335220  right_only
# 335221  right_only
# 335222  right_only
# 335223  right_only
# 335224  right_only
# 335225  right_only
# 335226  right_only
# 335227  right_only
# 335228  right_only
# 335229  right_only
# 335230  right_only
# 335231  right_only
# 335232  right_only
# 335233  right_only
# 335234  right_only
# 335235  right_only
# 335236  right_only
# 335237  right_only
# 335238  right_only
# 335239  right_only
# 335240  right_only
# 335241  right_only
# 335242  right_only
# 335243  right_only
# 335244  right_only
# 335245  right_only
# 335246  right_only
# 335247  right_only
# 335248  right_only
# 335249  right_only
# 335250  right_only
# 335251  right_only
# 335252  right_only
# 335253  right_only
# 335254  right_only
# 335255  right_only
# 335256  right_only
# 335257  right_only
# 335258  right_only
# 335259  right_only
# 335260  right_only
# 335261  right_only
# 335262  right_only
# 335263  right_only
# 335264  right_only
# 335265  right_only
# 335266  right_only
# 335267  right_only
# 335268  right_only
# 335269  right_only
# 335270  right_only
# 335271  right_only
# 335272  right_only
# 335273  right_only
# 335274  right_only
# 335275  right_only
# 335276  right_only
# 335277  right_only
# 335278  right_only
# 335279  right_only
# 335280  right_only
# 335281  right_only
# 335282  right_only
# 335283  right_only
# 335284  right_only
# 335285  right_only
# 335286  right_only
# 335287  right_only
# 335288  right_only
# 335289  right_only
# 335290  right_only
# 335291  right_only
# 335292  right_only
# 335293  right_only
# 335294  right_only
# 335295  right_only
# 335296  right_only
# 335297  right_only
# 335298  right_only
# 335299  right_only
# 335300  right_only
# 335301  right_only
# 335302  right_only
# 335303  right_only
# 335304  right_only
# 335305  right_only
# 335306  right_only
# 335307  right_only
# 335308  right_only
# 335309  right_only
# 335310  right_only
# 335311  right_only
# 335312  right_only
# 335313  right_only
# 335314  right_only
# 335315  right_only
# 335316  right_only
# 335317  right_only
# 335318  right_only
# 335319  right_only
# 335320  right_only
# 335321  right_only
# 335322  right_only
# 335323  right_only
# 335324  right_only
# 335325  right_only
# 335326  right_only
# 335327  right_only
# 335328  right_only
# 335329  right_only
# 335330  right_only
# 335331  right_only
# 335332  right_only
# 335333  right_only
# 335334  right_only
# 335335  right_only
# 335336  right_only
# 335337  right_only
# 335338  right_only
# 335339  right_only
# 335340  right_only
# 335341  right_only
# 335342  right_only
# 335343  right_only
# 335344  right_only
# 335345  right_only
# 335346  right_only
# 335347  right_only
# 335348  right_only
# 335349  right_only
# 335350  right_only
# 335351  right_only
# 335352  right_only
# 335353  right_only
# 335354  right_only
# 335355  right_only
# 335356  right_only
# 335357  right_only
# 335358  right_only
# 335359  right_only
# 335360  right_only
# 335361  right_only
# 335362  right_only
# 335363  right_only
# 335364  right_only
# 335365  right_only
# 335366  right_only
# 335367  right_only
# 335368  right_only
# 335369  right_only
# 335370  right_only
# 335371  right_only
# 335372  right_only
# 335373  right_only
# 335374  right_only
# 335375  right_only
# 335376  right_only
# 335377  right_only
# 335378  right_only
# 335379  right_only
# 335380  right_only
# 335381  right_only
# 335382  right_only
# 335383  right_only
# 335384  right_only
# 335385  right_only
# 335386  right_only
# 335387  right_only
# 335388  right_only
# 335389  right_only
# 335390  right_only
# 335391  right_only
# 335392  right_only
# 335393  right_only
# 335394  right_only
# 335395  right_only
# 335396  right_only
# 335397  right_only
# 335398  right_only
# 335399  right_only
# 335400  right_only
# 335401  right_only
# 335402  right_only
# 335403  right_only
# 335404  right_only
# 335405  right_only
# 335406  right_only
# 335407  right_only
# 335408  right_only
# 335409  right_only
# 335410  right_only
# 335411  right_only
# 335412  right_only
# 335413  right_only
# 335414  right_only
# 335415  right_only
# 335416  right_only
# 335417  right_only
# 335418  right_only
# 335419  right_only
# 335420  right_only
# 335421  right_only
# 335422  right_only
# 335423  right_only
# 335424  right_only
# 335425  right_only
# 335426  right_only
# 335427  right_only
# 335428  right_only
# 335429  right_only
# 335430  right_only
# 335431  right_only
# 335432  right_only
# 335433  right_only
# 335434  right_only
# 335435  right_only
# 335436  right_only
# 335437  right_only
# 335438  right_only
# 335439  right_only
# 335440  right_only
# 335441  right_only
# 335442  right_only
# 335443  right_only
# 335444  right_only
# 335445  right_only
# 335446  right_only
# 335447  right_only
# 335448  right_only
# 335449  right_only
# 335450  right_only
# 335451  right_only
# 335452  right_only
# 335453  right_only
# 335454  right_only
# 335455  right_only
# 335456  right_only
# 335457  right_only
# 335458  right_only
# 335459  right_only
# 335460  right_only
# 335461  right_only
# 335462  right_only
# 335463  right_only
# 335464  right_only
# 335465  right_only
# 335466  right_only
# 335467  right_only
# 335468  right_only
# 335469  right_only
# 335470  right_only
# 335471  right_only
# 335472  right_only
# 335473  right_only
# 335474  right_only
# 335475  right_only
# 335476  right_only
# 335477  right_only
# 335478  right_only
# 335479  right_only

# %%
df_merged[df_merged.player.str.contains('Jamaal Magloire')][df_merged._merge == 'right_only']
# Out:
# <ipython-input-42-ef119155408f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_merged[df_merged.player.str.contains('Jamaal Magloire')][df_merged._merge == 'right_only']
#          game_id  game_date     team_id           player   season  PLAYER_ID  \
# 335058  41000214 2011-05-09  1610612748  Jamaal Magloire  2010-11        NaN
# 335060  41000303 2011-05-22  1610612748  Jamaal Magloire  2010-11        NaN
#
#         Team Acquired     Relinquished         Notes      _merge
# 335058  Heat           Jamaal Magloire  placed on IL  right_only
# 335060  Heat           Jamaal Magloire  placed on IL  right_only

# %% [markdown]
# <font color='red'> it appears out of the 244 games jamaal magloire has a game_id for, the combined inactive and boxscore advanced datasets do not include him for 2 games???</font> -appears are inactive in 2011-05-09 by nba.com
#
# -

# %%
df_ina = rcp('A11inactive_game_id_team_id_player_id_2010_2018.csv', ['game_date'])
p(df_ina)
# Out:
# (43125, 12)
#         game_id  game_date   season  PLAYER_ID FIRST_NAME     LAST_NAME  \
# 0      21000001 2010-10-26  2010-11     202376       Luke     Harangody
# 1      21000001 2010-10-26  2010-11       2570   Kendrick       Perkins
# 2      21000001 2010-10-26  2010-11     202340      Avery       Bradley
# 3      21000001 2010-10-26  2010-11     202354     Dexter       Pittman
# 4      21000001 2010-10-26  2010-11       2034       Mike        Miller
# 43120  21701230 2018-04-11  2017-18     202697       Iman      Shumpert
# 43121  21701230 2018-04-11  2017-18     203900     Markel         Brown
# 43122  21701230 2018-04-11  2017-18     201583       Ryan      Anderson
# 43123  21701230 2018-04-11  2017-18       2772     Trevor         Ariza
# 43124  21701230 2018-04-11  2017-18     201601        Luc  Mbah a Moute
#
#       JERSEY_NUM     TEAM_ID   TEAM_CITY TEAM_NAME TEAM_ABBREVIATION  \
# 0             55  1610612738      Boston   Celtics               BOS
# 1             43  1610612738      Boston   Celtics               BOS
# 2              0  1610612738      Boston   Celtics               BOS
# 3             45  1610612748       Miami      Heat               MIA
# 4             13  1610612748       Miami      Heat               MIA
# 43120          4  1610612758  Sacramento     Kings               SAC
# 43121         26  1610612745     Houston   Rockets               HOU
# 43122         33  1610612745     Houston   Rockets               HOU
# 43123          1  1610612745     Houston   Rockets               HOU
# 43124         12  1610612745     Houston   Rockets               HOU
#
#                  player
# 0        Luke Harangody
# 1      Kendrick Perkins
# 2         Avery Bradley
# 3        Dexter Pittman
# 4           Mike Miller
# 43120     Iman Shumpert
# 43121      Markel Brown
# 43122     Ryan Anderson
# 43123      Trevor Ariza
# 43124  Luc Mbah a Moute

# %%
df_ina.game_id

# %%
#check '15game_date_game_id_team_id_season_player_id_player_2010_2018.csv'
#for player's of the same name playing on the same team in the same season. should have different player_id if different players

# %%
df_tispip = df_gdgitispip[['team_id', 'season', 'player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True)
p(df_tispip)
# Out:
# (5057, 4)
#          team_id   season             player  PLAYER_ID
# 0     1610612739  2009-10       LeBron James     2544.0
# 1     1610612745  2009-10     Chase Budinger   201978.0
# 2     1610612745  2009-10  Pops Mensah-Bonsu   200822.0
# 3     1610612745  2009-10     David Andersen     2431.0
# 4     1610612745  2009-10        Carl Landry   201171.0
# 5052  1610612738  2017-18    Jonathan Gibson  1626780.0
# 5053  1610612747  2017-18       Andre Ingram   201281.0
# 5054  1610612745  2017-18      Aaron Jackson  1628935.0
# 5055  1610612739  2017-18   Kendrick Perkins     2570.0
# 5056  1610612764  2017-18          Ty Lawson   201951.0

# %%
df_tispip.value_counts(['team_id', 'season', 'player'])
# Out:
# team_id     season   player
# 1610612766  2017-18  Willy Hernangomez    1
# 1610612746  2015-16  DeAndre Jordan       1
#                      Alex Stepheson       1
#                      Austin Rivers        1
#                      Blake Griffin        1
#                                          ..
# 1610612756  2016-17  Marquese Chriss      1
#                      P.J. Tucker          1
#                      Ronnie Price         1
#                      T.J. Warren          1
# 1610612737  2009-10  Al Horford           1
# Length: 5057, dtype: int64

# %%
df_tispip.value_counts(['team_id', 'season', 'player'])[df_tispip.value_counts(['team_id', 'season', 'player']) > 1]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# <font color='red'> it appears there are no player's of the same name that played on the same team during the same season???</font> -yes

# %%
df_gdgitispip[['player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True)
# Out:
#                  player  PLAYER_ID
# 0          LeBron James     2544.0
# 1        Chase Budinger   201978.0
# 2     Pops Mensah-Bonsu   200822.0
# 3        David Andersen     2431.0
# 4           Carl Landry   201171.0
# ...                 ...        ...
# 1150     Jaylen Johnson  1628575.0
# 1151      Le'Bryan Nash  1626198.0
# 1152      Omari Johnson   204179.0
# 1153       Andre Ingram   201281.0
# 1154      Aaron Jackson  1628935.0
#
# [1155 rows x 2 columns]

# %%
df_gdgitispip[['player', 'PLAYER_ID']].drop_duplicates().reset_index(drop=True).value_counts('player')
# Out:
# player
# Chris Johnson         2
# Tony Mitchell         2
# Mike James            2
# Chris Wright          2
# Zydrunas Ilgauskas    1
#                      ..
# Marreese Speights     1
# Marqus Blakely        1
# Marquis Teague        1
# Marquis Daniels       1
# AJ Hammons            1
# Length: 1151, dtype: int64

# %% [markdown]
# <font color='red'> are the missing 3 players justified??</font> -yes, of the 3, 2 have player_id typos and 1 no nba game stats

# %%
rcp('13player_id_player_2010_2018.csv').value_counts('player')[rcp('13player_id_player_2010_2018.csv').value_counts('player') > 1]
# Out:
# player
# Elton Brand        2
# Marcus Thornton    2
# Chris Wright       2
# Chris Johnson      2
# Tony Mitchell      2
# Rashard Lewis      2
# Mike James         2
# dtype: int64

# %%
set(df_merged[df_merged._merge == 'right_only'].player)

# %%
p(df_gdgitispip[df_gdgitispip.player.str.contains('Jamaal Magloire')])
df_gdgitispip[df_gdgitispip.player.str.contains('Jamaal Magloire')]

# %%
#pd.merge(df_pip, df_inj1018_gdtigi, on=['player'], how='inner').drop_duplicates().reset_index(drop=True)

# %%
#pd.merge(df_tipip, df_inj1018_gdtigi, on=['team_id', 'player'], how='inner').drop_duplicates().reset_index(drop=True)
