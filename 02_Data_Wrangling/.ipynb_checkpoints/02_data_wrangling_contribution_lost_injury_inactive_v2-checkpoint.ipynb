# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sqlite3

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

pd.set_option('max_colwidth', None)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#return first 5 and last 5 rows of dataframe
def p(df_):
    return pd.concat([df_.head(), df_.tail()])

# %%
def replace_player(df_):
    df_.player.replace({'J.J. Redick':'JJ Redick'}, inplace=True)
    
    df_.player.replace({'A.J. Price': 'AJ Price'}, inplace=True)
    
    df_.player.replace({'Alex Ajinca':'Alexis Ajinca'}, inplace=True)
    
    df_.player.replace({'C.J. Miles': 'CJ Miles'}, inplace=True)
    
    df_.player.replace({'D.J. White': 'DJ White'}, inplace=True)
    
    df_.player.replace({"Hamady N'Diaye" : 'Hamady Ndiaye'}, inplace=True)
    
    df_.player.replace({'J.J. Hickson': 'JJ Hickson'}, inplace=True)
    
    df_.player.replace({'John Wallace' : 'John Wall'}, inplace=True)
    
    df_.player.replace({'Jose Barea' : 'J.J. Barea'}, inplace=True)
    
    df_.player.replace({'Wes Johnson':'Wesley Johnson'}, inplace=True)
    
    df_.player.replace({'B.J. Mullens':'Byron Mullens'}, inplace=True)
    
    df_.player.replace({'Bill Walker':'Henry Walker'}, inplace=True)
    
    df_.player.replace({'Gerald Henderson Jr.':'Gerald Henderson'}, inplace=True)
    
    df_.player.replace({'Jianlian Yi':'Yi Jianlian'}, inplace=True)
    
    df_.player.replace({'Mike Conley Jr.':'Mike Conley'}, inplace=True)
    
    df_.player.replace({'Mike Dunleavy Jr.':'Mike Dunleavy'}, inplace=True)
    
    df_.player.replace({'Nene Hilario': 'Nene'}, inplace=True)
    
    df_.player.replace({'Didier Mbenga':'DJ Mbenga'}, inplace=True)
    
    df_.player.replace({'A.J. Hammons':'AJ Hammons'}, inplace=True)
    
    df_.player.replace({'C.J. McCollum':'CJ McCollum'}, inplace=True)
    
    df_.player.replace({'D.J. Augustine':'D.J. Augustin'}, inplace=True)
    
    df_.player.replace({'DeAndre Bembry':"DeAndre' Bembry"}, inplace=True)
    
    df_.player.replace({'Giorgios Papagiannis':'Georgios Papagiannis'}, inplace=True)
    
    df_.player.replace({'Glen Rice Jr.':'Glen Rice'}, inplace=True)
    
    df_.player.replace({'J.R. Smith':'JR Smith'}, inplace=True)
    
    df_.player.replace({'James Ennis':'James Ennis III'}, inplace=True)
    
    df_.player.replace({'John Collins  John Collins':'John Collins'}, inplace=True)
    
    df_.player.replace({'Juan Hernangomez':'Juancho Hernangomez'}, inplace=True)
    
    df_.player.replace({'Billy Ouattara':'Yakuba Ouattara'}, inplace=True)
    
    df_.player.replace({'Courtney Simpson':'Diamon Simpson'}, inplace=True)
    
    df_.player.replace({'Danuel House':'Danuel House Jr.'}, inplace=True)
    
    df_.player.replace({'Domas Sabonis':'Domantas Sabonis'}, inplace=True)
    
    df_.player.replace({'Jake Wiley':'Jacob Wiley'}, inplace=True)
    
    df_.player.replace({'James McAdoo':'James Michael McAdoo'}, inplace=True)
    
    df_.player.replace({'Jeff Pendergraph':'Jeff Ayres'}, inplace=True)
    
    df_.player.replace({'Jeff Taylor':'Jeffery Taylor'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'K.J. McDaniels':'KJ McDaniels'}, inplace=True)
    
    df_.player.replace({'Malcom Lee':'Malcolm Lee'}, inplace=True)
    
    df_.player.replace({'Marcus Morris':'Marcus Morris Sr.'}, inplace=True)
    
    df_.player.replace({'Matt Williams':'Matt Williams Jr.'}, inplace=True)
    
    df_.player.replace({"Maurice N'dour":'Maurice Ndour'}, inplace=True)
    
    df_.player.replace({'Milos Tedosic':'Milos Teodosic'}, inplace=True)
    
    df_.player.replace({'Moe Harkless':'Maurice Harkless'}, inplace=True)
    
    df_.player.replace({'O.G. Anunoby':'OG Anunoby'}, inplace=True)
    
    df_.player.replace({'Ognen Kuzmic':'Ognjen Kuzmic'}, inplace=True)
    
    df_.player.replace({'P.J. Dozier':'PJ Dozier'}, inplace=True)
    
    df_.player.replace({'P.J. Hairston':'PJ Hairston'}, inplace=True)
    
    df_.player.replace({'Qi Zhou':'Zhou Qi'}, inplace=True)
    
    df_.player.replace({'R.J. Hunter':'RJ Hunter'}, inplace=True)
    
    df_.player.replace({'Ray McCallum Jr.':'Ray McCallum'}, inplace=True)
    
    df_.player.replace({'Ron Artest':'Metta World Peace'}, inplace=True)
    
    df_.player.replace({'Roy Marble':'Devyn Marble'}, inplace=True)
    
    df_.player.replace({'Stephen Zimmerman Jr.':'Stephen Zimmerman'}, inplace=True)
    
    df_.player.replace({'Tony Wroten Jr.':'Tony Wroten'}, inplace=True)
    
    df_.player.replace({'Toure Murry':"Toure' Murry"}, inplace=True)
    
    df_.player.replace({'Viacheslav Kravstov':'Viacheslav Kravtsov'}, inplace=True)
    
    df_.player.replace({'Vince Hunter':'Vincent Hunter'}, inplace=True)
    
    df_.player.replace({'Walker Russell Jr.':'Walker Russell'}, inplace=True)
    
    df_.player.replace({'Wayne Selden Jr.':'Wayne Selden'}, inplace=True)
    
    df_.player.replace({'Wes Matthews Jr.':'Wesley Matthews'}, inplace=True)
    
    return df_

# %%
#names dropped from Injury Report dataframe df_inj1018 for the following reasons:
#a. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons.
#b. player did not play an nba regular season or playoff game between the 2009-10 and 2017-18 seasons.
#c. no player nba regular season or playoff boxscore advanced stats between the 2009-10 and 2017-18 seasons. Player plays in nba games
#   following the 2017-18 season.
#d. this is the injury of a coach, not a player. coaches do not have boxscore advanced stats


def drop_player(df_):
    df_.drop(df_[df_.player.str.contains('Marion Hillard')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Matt Janning')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains("Da'Sean Butler")].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Eric Griffin')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Harry Giles')].index, inplace = True) #c
    
    df_.drop(df_[df_.player.str.contains('Magnum Rolle')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Robert Vaden')].index, inplace = True) #a
    
    df_.drop(df_[df_.player.str.contains('Steve Clifford')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Steve Kerr')].index, inplace = True) #d
    
    df_.drop(df_[df_.player.str.contains('Terrico White')].index, inplace = True)#a
    
    df_.drop(df_[df_.player.str.contains('Tyronn Lue')].index, inplace = True) #d
    
    
    
    return df_

# %%
#gi('Wes Matthews Jr.')

# %%
#gb('Wesley Matthews')

# %%
#gia("Toure' Murry")

# %%
#get injury data for player
def gi(player_):
    return df_inj1018[df_inj1018.player.str.contains(player_)]

# %%
#get boxscore advance for player
def gb(player_):
    return df_5bsa1018[df_5bsa1018.PLAYER_NAME.str.contains(player_)]

# %%
def gia(player_):
    return df_ina1018[df_ina1018.player.str.contains(player_)]

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
#get last game_date of 2017-18 season
path = os.path.join('..', 'processed_data', '7season_first_game_date_last_game_date.csv')
df_7sfgdlgd = pd.read_csv(path, parse_dates=['first', 'last'])
last_game_date_s1718 = df_7sfgdlgd.iloc[8]['last']
last_game_date_s1718
# Out:
# Timestamp('2018-06-08 00:00:00')

# %%
#get injury report for the 2010-11 thru 2017-18 seasons
path = os.path.join('..', 'raw_data', 'injuries_2010-2020.csv')
df_inj1020 = pd.read_csv(path, parse_dates=['Date'])

#preprocess player
df_inj1020.Acquired.fillna('', inplace=True)
df_inj1020.Relinquished.fillna('', inplace=True)
df_inj1020['player'] = df_inj1020.Relinquished + ' ' + df_inj1020.Acquired
df_inj1020.player = df_inj1020.player.str.strip()

df_inj1018 = df_inj1020.loc[df_inj1020['Date'] <= last_game_date_s1718]
df_inj1018 = replace_player(df_inj1018)
df_inj1018 = drop_player(df_inj1018)
df_inj1018
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# ...          ...        ...             ...            ...
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# 4                       strained lower back (out indefinitely)     Troy Murphy
# 5                 surgery to repair torn right Achilles tendon   Jonas Jerebko
# ...                                                        ...             ...
# 22252                strained right hamstring (out for season)      Chris Paul
# 22253                                         concussion (DTD)      Kevin Love
# 22254                                        activated from IL   Patrick McCaw
# 22255                                       returned to lineup      Kevin Love
# 22256                                       returned to lineup  Andre Iguodala
#
# [22232 rows x 6 columns]

# %%
df_inj1018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22232 entries, 0 to 22256
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          22232 non-null  datetime64[ns]
#  1   Team          22230 non-null  object
#  2   Acquired      22232 non-null  object
#  3   Relinquished  22232 non-null  object
#  4   Notes         22232 non-null  object
#  5   player        22232 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 1.2+ MB

# %%
df_inj1018.head()
# Out:
#         Date     Team Acquired   Relinquished  \
# 0 2010-10-03    Bulls           Carlos Boozer
# 1 2010-10-06  Pistons           Jonas Jerebko
# 3 2010-10-08  Blazers              Jeff Ayres
# 4 2010-10-08     Nets             Troy Murphy
# 5 2010-10-08  Pistons           Jonas Jerebko
#
#                                                      Notes         player
# 0  fractured bone in right pinky finger (out indefinitely)  Carlos Boozer
# 1            torn right Achilles tendon (out indefinitely)  Jonas Jerebko
# 3                torn ACL in right knee (out indefinitely)     Jeff Ayres
# 4                   strained lower back (out indefinitely)    Troy Murphy
# 5             surgery to repair torn right Achilles tendon  Jonas Jerebko

# %%
print(df_inj1018.shape)
p(df_inj1018)
# Out:
# (22232, 6)
#             Date       Team        Acquired   Relinquished  \
# 0     2010-10-03      Bulls                  Carlos Boozer
# 1     2010-10-06    Pistons                  Jonas Jerebko
# 3     2010-10-08    Blazers                     Jeff Ayres
# 4     2010-10-08       Nets                    Troy Murphy
# 5     2010-10-08    Pistons                  Jonas Jerebko
# 22252 2018-05-25    Rockets                     Chris Paul
# 22253 2018-05-26  Cavaliers                     Kevin Love
# 22254 2018-05-26   Warriors   Patrick McCaw
# 22255 2018-05-31  Cavaliers      Kevin Love
# 22256 2018-06-06   Warriors  Andre Iguodala
#
#                                                          Notes          player
# 0      fractured bone in right pinky finger (out indefinitely)   Carlos Boozer
# 1                torn right Achilles tendon (out indefinitely)   Jonas Jerebko
# 3                    torn ACL in right knee (out indefinitely)      Jeff Ayres
# 4                       strained lower back (out indefinitely)     Troy Murphy
# 5                 surgery to repair torn right Achilles tendon   Jonas Jerebko
# 22252                strained right hamstring (out for season)      Chris Paul
# 22253                                         concussion (DTD)      Kevin Love
# 22254                                        activated from IL   Patrick McCaw
# 22255                                       returned to lineup      Kevin Love
# 22256                                       returned to lineup  Andre Iguodala

# %%
df_inj1018.player.value_counts()
# Out:
# Dwyane Wade       126
# Manu Ginobili     124
# Kevin Love        120
# Tony Parker       108
# Nene              101
#                  ...
# Earl Boykins        1
# Derrick Byars       1
# Scotty Hopson       1
# Marcus Cousin       1
# Diamon Simpson      1
# Name: player, Length: 1002, dtype: int64

# %%
#AAA. On the 2011-01-22 nba game Wade was NWT due to a migraine (by the nba.com boxscore) during this Heat vs. Raptors
# game. Was Wade inactive for this game according to the inactive player game-by-game dataframe df_ina1018?


path = os.path.join('..', 'raw_data','basketball.sqlite')
path
con = sqlite3.connect(path)
cursor = con.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('Player',), ('Team',), ('Team_Attributes',), ('Team_History',), ('Player_Attributes',), ('Game_Officials',), ('Game_Inactive_Players',), ('Team_Salary',), ('Player_Salary',), ('Draft',), ('Draft_Combine',), ('Player_Photos',), ('Player_Bios',), ('Game',), ('News',), ('News_Missing',)]

# %%
df_ina = pd.read_sql_query("SELECT * from Game_Inactive_Players", con)
df_ina['player'] = df_ina.FIRST_NAME + " " + df_ina.LAST_NAME
df_ina.player = df_ina.player.str.strip()
df_ina
# Out:
#       PLAYER_ID FIRST_NAME LAST_NAME JERSEY_NUM     TEAM_ID    TEAM_CITY  \
# 0           184      Bobby    Phills         14  1610612739    Cleveland
# 1           781       Will    Perdue         41  1610612759  San Antonio
# 2           120     Steven     Smith          8  1610612737      Atlanta
# 3           698      Eddie   Johnson          8  1610612754      Indiana
# 4            32   Clifford    Rozier         44  1610612753      Orlando
# ...         ...        ...       ...        ...         ...          ...
# 97932      2544     LeBron     James       23    1610612747  Los Angeles
# 97933    203115       Will    Barton       5     1610612743       Denver
# 97934   1627750      Jamal    Murray       27    1610612743       Denver
# 97935   1630192       Zeke     Nnaji       22    1610612743       Denver
# 97936   1628420      Monte    Morris       11    1610612743       Denver
#
#        TEAM_NAME TEAM_ABBREVIATION     GAME_ID           player
# 0      Cavaliers               CLE  0029600034     Bobby Phills
# 1          Spurs               SAS  0029600034      Will Perdue
# 2          Hawks               ATL  0029600132     Steven Smith
# 3         Pacers               IND  0029600203    Eddie Johnson
# 4          Magic               ORL  0029600213  Clifford Rozier
# ...          ...               ...         ...              ...
# 97932     Lakers               LAL  0022000982     LeBron James
# 97933    Nuggets               DEN  0022000982      Will Barton
# 97934    Nuggets               DEN  0022000982     Jamal Murray
# 97935    Nuggets               DEN  0022000982       Zeke Nnaji
# 97936    Nuggets               DEN  0022000982     Monte Morris
#
# [97937 rows x 10 columns]

# %%
df_ina.GAME_ID = df_ina.GAME_ID.astype(int)
df_ina.GAME_ID.head()
# Out:
# 0    29600034
# 1    29600034
# 2    29600132
# 3    29600203
# 4    29600213
# Name: GAME_ID, dtype: int64

# %%
df_ina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97937 entries, 0 to 97936
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          97937 non-null  object
#  1   FIRST_NAME         97937 non-null  object
#  2   LAST_NAME          97937 non-null  object
#  3   JERSEY_NUM         97937 non-null  object
#  4   TEAM_ID            97937 non-null  object
#  5   TEAM_CITY          97937 non-null  object
#  6   TEAM_NAME          97937 non-null  object
#  7   TEAM_ABBREVIATION  97937 non-null  object
#  8   GAME_ID            97937 non-null  int64
#  9   player             97937 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 7.5+ MB

# %%
df_ina[df_ina.player.str.contains('Dwyane Wade')]
# Out:
#       PLAYER_ID FIRST_NAME LAST_NAME JERSEY_NUM     TEAM_ID  TEAM_CITY  \
# 3883       2548     Dwyane      Wade          3  1610612748      Miami
# 5043       2548     Dwyane      Wade          3  1610612748      Miami
# 5116       2548     Dwyane      Wade          3  1610612748      Miami
# 6665       2548     Dwyane      Wade          3  1610612748      Miami
# 6749       2548     Dwyane      Wade          3  1610612748      Miami
# 8457       2548     Dwyane      Wade          3  1610612748      Miami
# 8547       2548     Dwyane      Wade          3  1610612748      Miami
# 9051       2548     Dwyane      Wade          3  1610612748      Miami
# 9106       2548     Dwyane      Wade          3  1610612748      Miami
# 11027      2548     Dwyane      Wade          3  1610612748      Miami
# 11143      2548     Dwyane      Wade          3  1610612748      Miami
# 11182      2548     Dwyane      Wade          3  1610612748      Miami
# 11277      2548     Dwyane      Wade          3  1610612748      Miami
# 9840  21000001  2010-10-26  1610612738       t    1.0  240  32.0  69.0
# 9841  21000001  2010-10-26  1610612748       f    0.0  240  27.0  74.0
# 9842  21000002  2010-10-26  1610612757       t    1.0  240  43.0  93.0
# 9843  21000002  2010-10-26  1610612756       f    0.0  240  36.0  74.0
# 9844  21000003  2010-10-26  1610612745       f    0.0  240  38.0  91.0
#
#       fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  oreb  dreb  reb   ast  \
# 9840   0.464   8.0  16.0    0.500  16.0  25.0     1.0   8.0  34.0   42  25.0
# 9841   0.365   8.0  20.0    0.400  18.0  25.0     1.0  11.0  28.0   39  15.0
# 9842   0.462  10.0  20.0    0.500  10.0  15.0     1.0  18.0  30.0   48  31.0
# 9843   0.486   9.0  19.0    0.474  11.0  16.0     1.0   7.0  23.0   30  15.0
# 9844   0.418   8.0  20.0    0.400  26.0  28.0     1.0  16.0  37.0   53  25.0
#
#        stl  blk   tov    pf  pts  season_year     season_type   season
# 9840   6.0  4.0  18.0  19.0   88         2010  Regular Season  2010-11
# 9841  10.0  6.0  17.0  21.0   80         2010  Regular Season  2010-11
# 9842  11.0  2.0  12.0  22.0  106         2010  Regular Season  2010-11
# 9843   3.0  4.0  19.0  19.0   92         2010  Regular Season  2010-11
# 9844   6.0  7.0  20.0  25.0  110         2010  Regular Season  2010-11

# %%
df_3gigdti1018[['game_id', 'game_date', 'team_id']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20534 entries, 9840 to 31037
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   game_id    20534 non-null  int64
#  1   game_date  20534 non-null  object
#  2   team_id    20534 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 641.7+ KB

# %%
df_ina.rename(columns={'GAME_ID':'game_id'}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97937 entries, 0 to 97936
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PLAYER_ID          97937 non-null  object
#  1   FIRST_NAME         97937 non-null  object
#  2   LAST_NAME          97937 non-null  object
#  3   JERSEY_NUM         97937 non-null  object
#  4   TEAM_ID            97937 non-null  object
#  5   TEAM_CITY          97937 non-null  object
#  6   TEAM_NAME          97937 non-null  object
#  7   TEAM_ABBREVIATION  97937 non-null  object
#  8   game_id            97937 non-null  int64
#  9   player             97937 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 7.5+ MB

# %%
#stick a date for game_id: merge
df_ina1018 = pd.merge(df_3gigdti1018[['game_id', 'game_date']], df_ina.rename(columns={'GAME_ID':'game_id'}), on='game_id', how='inner').drop_duplicates()
df_ina1018
# Out:
#         game_id   game_date PLAYER_ID FIRST_NAME     LAST_NAME JERSEY_NUM  \
# 0      21000001  2010-10-26    202376       Luke     Harangody         55
# 1      21000001  2010-10-26      2570   Kendrick       Perkins         43
# 2      21000001  2010-10-26    202340      Avery       Bradley          0
# 3      21000001  2010-10-26    202354     Dexter       Pittman         45
# 4      21000001  2010-10-26      2034       Mike        Miller         13
# ...         ...         ...       ...        ...           ...        ...
# 86249  21701230  2018-04-11    202697       Iman      Shumpert          4
# 86250  21701230  2018-04-11    203900     Markel         Brown         26
# 86251  21701230  2018-04-11    201583       Ryan      Anderson         33
# 86252  21701230  2018-04-11      2772     Trevor         Ariza          1
# 86253  21701230  2018-04-11    201601        Luc  Mbah a Moute         12
# 35970  1610612748      Miami       Heat               MIA  Dwyane Wade
# 36076  1610612748      Miami       Heat               MIA  Dwyane Wade
# 37488  1610612748      Miami       Heat               MIA  Dwyane Wade
# 37637  1610612748      Miami       Heat               MIA  Dwyane Wade
# 37685  1610612748      Miami       Heat               MIA  Dwyane Wade
# 37860  1610612748      Miami       Heat               MIA  Dwyane Wade
# 37980  1610612748      Miami       Heat               MIA  Dwyane Wade
# 38064  1610612748      Miami       Heat               MIA  Dwyane Wade
# 38159  1610612748      Miami       Heat               MIA  Dwyane Wade
# 41215  1610612748      Miami       Heat               MIA  Dwyane Wade
# 41345  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42120  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42226  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42304  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42381  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42532  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42690  1610612748      Miami       Heat               MIA  Dwyane Wade
# 42827  1610612748      Miami       Heat               MIA  Dwyane Wade
# 44898  1610612748      Miami       Heat               MIA  Dwyane Wade
# 47305  1610612748      Miami       Heat               MIA  Dwyane Wade
# 60898  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 63154  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 63650  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 64374  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 64467  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65068  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65158  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65326  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65414  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65556  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65667  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 65928  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 66065  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 66130  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 66249  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 66360  1610612741    Chicago      Bulls               CHI  Dwyane Wade
# 73110  1610612739  Cleveland  Cavaliers               CLE  Dwyane Wade
# 73774  1610612739  Cleveland  Cavaliers               CLE  Dwyane Wade
# 78090  1610612739  Cleveland  Cavaliers               CLE  Dwyane Wade
# 78404  1610612739  Cleveland  Cavaliers               CLE  Dwyane Wade
# 79583  1610612739  Cleveland  Cavaliers               CLE  Dwyane Wade
# 82623  1610612748      Miami       Heat               MIA  Dwyane Wade
# 82845  1610612748      Miami       Heat               MIA  Dwyane Wade
# 83107  1610612748      Miami       Heat               MIA  Dwyane Wade
# 83436  1610612748      Miami       Heat               MIA  Dwyane Wade
# 83663  1610612748      Miami       Heat               MIA  Dwyane Wade
# 85307  1610612748      Miami       Heat               MIA  Dwyane Wade

# %%
#get game_id, game_date pairs
df_3gdgiti0618 = pd.read_csv(os.path.join('..', 'processed_data', '3game_id_game_date_team_id.csv'))
df_3gdgi0618 = df_3gdgiti0618[['game_date', 'game_id']].drop_duplicates()
df_3gdgi0618
# Out:
#         game_date   game_id
# 0      2006-10-31  20600001
# 2      2006-10-31  20600002
# 4      2006-11-01  20600003
# 6      2006-11-01  20600004
# 8      2006-11-01  20600005
# ...           ...       ...
# 31028  2018-05-28  41700317
# 31030  2018-05-31  41700401
# 31032  2018-06-03  41700402
# 31034  2018-06-06  41700403
# 31036  2018-06-08  41700404
#
# [15519 rows x 2 columns]

# %%
df_5bsa1018 = pd.read_csv(os.path.join('..', 'processed_data', '5boxscoreadvancedv2_2009_2018.csv'))
df_5bsa1018.shape
# Out:
# (291643, 31)

# %%
df_5bsa1018.PLAYER_NAME = df_5bsa1018.PLAYER_NAME.fillna('')
df_5bsa1018 = pd.merge(df_3gdgi0618, df_5bsa1018.rename(columns={'GAME_ID':'game_id'}), on='game_id', how='inner')
df_5bsa1018
# Out:
#          game_date   game_id       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  \
# 0       2009-10-27  20900001  1.610613e+09               BOS     Boston
# 1       2009-10-27  20900001  1.610613e+09               BOS     Boston
# 2       2009-10-27  20900001  1.610613e+09               BOS     Boston
# 3       2009-10-27  20900001  1.610613e+09               BOS     Boston
# 4       2009-10-27  20900001  1.610613e+09               BOS     Boston
# ...            ...       ...           ...               ...        ...
# 291638  2018-06-08  41700404  1.610613e+09               CLE  Cleveland
# 291639  2018-06-08  41700404  1.610613e+09               CLE  Cleveland
# 291640  2018-06-08  41700404  1.610613e+09               CLE  Cleveland
# 291641  2018-06-08  41700404  1.610613e+09               CLE  Cleveland
# 291642  2018-06-08  41700404  1.610613e+09               CLE  Cleveland
#
#         PLAYER_ID       PLAYER_NAME START_POSITION                 COMMENT  \
# 0          1718.0       Paul Pierce              F                     NaN
# 1           708.0     Kevin Garnett              F                     NaN
# 2          2570.0  Kendrick Perkins              C                     NaN
# 3           951.0         Ray Allen              G                     NaN
# 4        200765.0       Rajon Rondo              G                     NaN
# ...           ...               ...            ...                     ...
# 291638  1626204.0   Larry Nance Jr.            NaN                     NaN
# 291639  1626224.0        Cedi Osman            NaN                     NaN
# 291640   101181.0     Jose Calderon            NaN                     NaN
# 291641  1627790.0        Ante Zizic            NaN                     NaN
# 291642   203903.0   Jordan Clarkson            NaN  DNP - Coach's Decision
#
#           MIN  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  \
# 0       37:59          95.3        97.4          96.5        98.6
# 1       33:05          95.6        95.5         101.0       103.1
# 2       25:42          99.2       100.0         108.2       104.3
# 3       42:21         105.2       108.8         105.4       105.1
# 4       34:29          92.7        94.1          98.0        97.1
# ...       ...           ...         ...           ...         ...
# 291638  23:12          93.4        97.6          93.1        95.2
# 291639   4:03         100.0       114.3          76.1        75.0
# 291640   4:03         100.0       114.3          76.1        75.0
# 291641   1:40         100.0       133.3           0.0         0.0
# 291642    NaN           NaN         0.0           NaN         0.0
#
#         E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  \
# 0               -1.2        -1.3    0.053     0.50        4.8     0.028
# 1               -5.4        -7.6    0.059     1.00        7.1     0.097
# 2               -9.1        -4.3    0.077     0.33        9.1     0.000
# 3               -0.2         3.7    0.120     1.00       12.5     0.000
# 4               -5.3        -3.0    0.526     5.00       50.0     0.061
# ...              ...         ...      ...      ...        ...       ...
# 291638           0.3         2.3    0.333     0.00       33.3     0.176
# 291639          23.9        39.3    0.000     0.00        0.0     0.000
# 291640          23.9        39.3    0.250     0.00       50.0     0.000
# 291641         100.0       133.3    0.000     0.00        0.0     0.333
# 291642           NaN         0.0      NaN      NaN        NaN     0.000
#
#         DREB_PCT  REB_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  \
# 0          0.270    0.151         9.5    0.538   0.661    0.233      0.239
# 1          0.233    0.164         7.1    0.500   0.553    0.178      0.181
# 2          0.050    0.024        27.3    0.571   0.605    0.196      0.198
# 3          0.054    0.028        12.5    0.375   0.440    0.236      0.240
# 4          0.125    0.092        10.0    0.500   0.500    0.130      0.133
# ...          ...      ...         ...      ...     ...      ...        ...
# 291638     0.077    0.133         0.0    0.429   0.444    0.148      0.146
# 291639     0.000    0.000         0.0    0.333   0.333    0.333      0.333
# 291640     0.200    0.100         0.0    0.000   0.000    0.111      0.111
# 291641     0.000    0.200         0.0    1.000   1.000    0.400      0.400
# 291642     0.000    0.000         NaN      NaN     NaN    0.000      0.000
#
#         E_PACE   PACE  PACE_PER40  POSS    PIE
# 0        96.88  94.76       78.97  76.0  0.189
# 1        95.96  95.03       79.19  66.0  0.147
# 2        86.53  87.77       73.14  47.0  0.030
# 3        91.50  90.12       75.10  80.0  0.051
# 4        95.63  95.36       79.46  68.0  0.158
# ...        ...    ...         ...   ...    ...
# 291638   88.76  85.87       71.56  41.0  0.139
# 291639   94.10  88.89       74.07   7.0  0.000
# 291640   94.10  88.89       74.07   7.0  0.174
# 291641  100.80  86.40       72.00   3.0  2.250
# 291642     NaN    NaN         NaN   0.0    NaN
#
# [291643 rows x 32 columns]

# %%
print(len(set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME)))
set(df_inj1018.player) - set(df_5bsa1018.PLAYER_NAME)
# Out:
# 0
# set()

# %%
print(len(set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player)))
set(df_5bsa1018.PLAYER_NAME) - set(df_inj1020.player)
# Out:
# 129
# {'Aaron Jackson',
#  'Adam Morrison',
#  'Adonal Foyle',
#  'Alando Tucker',
#  'Alex Stepheson',
#  'Alexander Johnson',
#  'Allen Iverson',
#  'Andre Emmett',
#  'Andre Ingram',
#  'Anthony Johnson',
#  'Antonio Anderson',
#  'Antonio Daniels',
#  'Ben Bentil',
#  'Blake Ahearn',
#  'Bobby Simmons',
#  'Carldell Johnson',
#  'Casper Ware',
#  'Cedric Jackson',
#  'Charles Jenkins',
#  'Chris Hunter',
#  'Chris Richard',
#  'Chucky Atkins',
#  'Coby Karl',
#  'Courtney Fortson',
#  'D.J. Kennedy',
#  'DJ Stephens',
#  'Darnell Jackson',
#  'Darryl Watkins',
#  'David Wear',
#  'Desmond Mason',
#  'Devean George',
#  'Devin Brown',
#  'Dionte Christmas',
#  'Drew Gordon',
#  'Eddie House',
#  'Edwin Ubiles',
#  'Elijah Millsap',
#  'Eric Dawson',
#  'Fabricio Oberto',
#  'Flip Murray',
#  'Ike Diogu',
#  'Ime Udoka',
#  'J.R. Giddens',
#  "JJ O'Brien",
#  'Jabari Brown',
#  'Jameel Warney',
#  'James Nunnally',
#  'James Singleton',
#  'JamesOn Curry',
#  'Jarron Collins',
#  'Jarvis Hayes',
#  'Jason Hart',
#  'Javaris Crittenton',
#  'Jawad Williams',
#  'Jeff Foote',
#  'Jerome Dyson',
#  'Jerrelle Benimon',
#  'Jerry Smith',
#  'Jonathan Bender',
#  'Jonathan Gibson',
#  'Jorge Gutierrez',
#  'Josh Akognon',
#  'Josh Boone',
#  'Josh Davis',
#  'Josh Gray',
#  'Kalin Lucas',
#  'Kareem Rush',
#  'Keith Appling',
#  'Keith Benson',
#  'Kenny Hasbrouck',
#  'Kenny Thomas',
#  'Kevin Ollie',
#  'Kyle Collinsworth',
#  'Kyle Weaver',
#  'Langston Galloway',
#  'Larry Hughes',
#  'Larry Owens',
#  'Lindsey Hunter',
#  'Luke Zeller',
#  'Malik Hairston',
#  'Marcus Haislip',
#  'Marcus Landry',
#  'Marcus Williams',
#  'Mardy Collins',
#  'Marqus Blakely',
#  'Michael Finley',
#  'Mickael Gelabale',
#  'Mike Wilks',
#  'Mikki Moore',
#  'Morris Almond',
#  'Nathan Jawai',
#  'Oleksiy Pecherov',
#  'Oliver Lafayette',
#  'Omari Johnson',
#  'Othello Hunter',
#  'Patricio Garino',
#  'Patrick Ewing',
#  "Patrick O'Bryant",
#  'Paul Davis',
#  'Primoz Brezec',
#  'Rafer Alston',
#  'Randolph Morris',
#  'Rasho Nesterovic',
#  'Ricky Davis',
#  'Rodney Purvis',
#  'Roko Ukic',
#  'Ronald Dupree',
#  'Ronald Roberts Jr.',
#  'Ryan Bowen',
#  'Sean May',
#  'Shane Edwards',
#  'Shannon Brown',
#  'Shawn Long',
#  'Sim Bhullar',
#  'Sindarius Thornwell',
#  'Speedy Claxton',
#  'Steven Hunter',
#  'Taylor Griffin',
#  'Tim Thomas',
#  'Travis Diener',
#  'Travis Outlaw',
#  'Trenton Hassell',
#  'Trey Gilder',
#  'Trey McKinney-Jones',
#  'Walt Lemon Jr.',
#  'Will Cherry',
#  'Will Conroy',
#  'Xavier Rathan-Mayes',
#  'Yakhouba Diawara'}

# %%
#df.select_dtypes('object')

# %%
#df[''].value_counts().head()

# %%
#missing_x = df[[' ', ' ']].isnull().sum(axis=1)

# %%
df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0451799cd6c1> in <module>
# ----> 1 df.hist(figsize=(15,10))
#       2 plt.subplots_adjust(hspace=.5);
#
# NameError: name 'df' is not defined

# %%
#df.loc[5, ' '] = 1111

# %%
df.column_name.hist(bins=30)
plt.xlabel('column_name')
plt.ylabel('Count')
plt.title('Distribution of');

# %%
df.column_name[df.column_name < 1000].describe()

# %%
df.iloc[115]

# %%
#type()

# %%
#len()

# %%
#df.iloc[:, 4]

# %%
#df.iloc[:, [0,5,6]].copy()

# %%
#set(df.column_name) - set(df2.column_name)

# %%
#df.state[df.column_name.str.contains('state1|state2|state3|state4')]

# %%
#regex
#df.column_name.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)

# %%
#df.plot(x='column_name1', y='column_name2', kind='scatter');

# %%
#df.loc[df.column_name == 'state1', ['column_name', 'column_name']]

# %%
#missing = pd.concat([df.isnull().sum(axis=1), 100 * df.isnull().mean(axis=1)], axis=1)
#missing.columns=['count', '%']
#missing.sort_values(by='count', ascending=False).head(10)

# %%
#missing['%'].unique()

# %%
#datapath = 'data'

# %%
#if not os.path.exists(datapath):
    #os.mkdir(datapath)

# %%
#datapath_df = os.path.join(datapath, 'df_cleaned.csv')
#if not os.path.exists(datapath_df):
#    df.to_csv(datapath_df, index=False)

# %%
#datapath_df2 = os.path.join(datapath, 'df2.csv')
#if not os.path.exists(datapath_df2):
#    df2.to_csv(datapath_df2, index=False)
