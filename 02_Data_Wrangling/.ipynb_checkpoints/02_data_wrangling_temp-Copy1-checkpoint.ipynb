# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Paul\\sb\\DSCapstone2\\02_Data_Wrangling'

# %%
df = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data\\3game_date_home_away.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15519 entries, 0 to 15518
# Data columns (total 47 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       15519 non-null  int64
#  1   game_date     15519 non-null  object
#  2   team_id_home  15519 non-null  int64
#  3   w_pct_home    15519 non-null  float64
#  4   min_home      15519 non-null  int64
#  5   fgm_home      15519 non-null  float64
#  6   fga_home      15519 non-null  float64
#  7   fg_pct_home   15519 non-null  float64
#  8   fg3m_home     15519 non-null  float64
#  9   fg3a_home     15519 non-null  float64
#  10  fg3_pct_home  15519 non-null  float64
#  11  ftm_home      15519 non-null  float64
#  12  fta_home      15519 non-null  float64
#  13  ft_pct_home   15519 non-null  float64
#  14  oreb_home     15519 non-null  float64
#  15  dreb_home     15519 non-null  float64
#  16  reb_home      15519 non-null  int64
#  17  ast_home      15519 non-null  float64
#  18  stl_home      15519 non-null  float64
#  19  blk_home      15519 non-null  float64
#  20  tov_home      15519 non-null  float64
#  21  pf_home       15519 non-null  float64
#  22  pts_home      15519 non-null  int64
#  23  season_year   15519 non-null  float64
#  24  team_id_away  15519 non-null  int64
#  25  w_pct_away    15519 non-null  float64
#  26  min_away      15519 non-null  int64
#  27  fgm_away      15519 non-null  float64
#  28  fga_away      15519 non-null  float64
#  29  fg_pct_away   15519 non-null  float64
#  30  fg3m_away     15519 non-null  float64
#  31  fg3a_away     15519 non-null  float64
#  32  fg3_pct_away  15519 non-null  float64
#  33  ftm_away      15519 non-null  float64
#  34  fta_away      15519 non-null  float64
#  35  ft_pct_away   15519 non-null  float64
#  36  oreb_away     15519 non-null  float64
#  37  dreb_away     15519 non-null  float64
#  38  reb_away      15519 non-null  int64
#  39  ast_away      15519 non-null  float64
#  40  stl_away      15519 non-null  float64
#  41  blk_away      15519 non-null  float64
#  42  tov_away      15519 non-null  float64
#  43  pf_away       15519 non-null  float64
#  44  pts_away      15519 non-null  int64
#  45  season_type   15519 non-null  object
#  46  season        15519 non-null  object
# dtypes: float64(35), int64(9), object(3)
# memory usage: 5.6+ MB

# %%
df2 = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data\\2game_id_game_date.csv')
df2
# Out:
#         game_date   game_id
# 0      2006-10-09  10600007
# 1      2006-10-10  10600008
# 2      2006-10-10  10600009
# 3      2006-10-10  10600010
# 4      2006-10-10  10600012
# ...           ...       ...
# 16785  2017-06-01  41600401
# 16786  2017-06-04  41600402
# 16787  2017-06-07  41600403
# 16788  2017-06-09  41600404
# 16789  2017-06-12  41600405
#
# [16790 rows x 2 columns]

# %%
df0 = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\processed_data\\0team_id_abbreviation_df.csv')
df0
# Out:
#        team_id abbreviation
# 0   1610612737          ATL
# 1   1610612738          BOS
# 2   1610612739          CLE
# 3   1610612740          NOP
# 4   1610612741          CHI
# 5   1610612742          DAL
# 6   1610612743          DEN
# 7   1610612744          GSW
# 8   1610612745          HOU
# 9   1610612746          LAC
# 10  1610612747          LAL
# 11  1610612748          MIA
# 12  1610612749          MIL
# 13  1610612750          MIN
# 14  1610612751          BKN
# 15  1610612752          NYK
# 16  1610612753          ORL
# 17  1610612754          IND
# 18  1610612755          PHI
# 19  1610612756          PHX
# 20  1610612757          POR
# 21  1610612758          SAC
# 22  1610612759          SAS
# 23  1610612760          OKC
# 24  1610612761          TOR
# 25  1610612762          UTA
# 26  1610612763          MEM
# 27  1610612764          WAS
# 28  1610612765          DET
# 29  1610612766          CHA

# %%
# Out:
#         game_id   game_date  matchup_ATL   team_id_ATL is_home_ATL wl_ATL  \
# 0      20600003  2006-11-01  PHI vs. ATL  1.610613e+09           f      L
# 1      20600004  2006-11-01          NaN           NaN         NaN    NaN
# 2      20600005  2006-11-01          NaN           NaN         NaN    NaN
# 3      20600006  2006-11-01          NaN           NaN         NaN    NaN
# 4      20600007  2006-11-01          NaN           NaN         NaN    NaN
# ...         ...         ...          ...           ...         ...    ...
# 14152  21701226  2018-04-11          NaN           NaN         NaN    NaN
# 14153  21701227  2018-04-11          NaN           NaN         NaN    NaN
# 14154  21701228  2018-04-11          NaN           NaN         NaN    NaN
# 14155  21701229  2018-04-11          NaN           NaN         NaN    NaN
# 14156  21701230  2018-04-11          NaN           NaN         NaN    NaN
#
#        w_ATL  l_ATL  w_pct_ATL  min_ATL  ...  stl_MIA  blk_MIA  tov_MIA  \
# 0        0.0    1.0        0.0    240.0  ...      NaN      NaN      NaN
# 1        NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 2        NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 3        NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 4        NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# ...      ...    ...        ...      ...  ...      ...      ...      ...
# 14152    NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 14153    NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 14154    NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 14155    NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
# 14156    NaN    NaN        NaN      NaN  ...      NaN      NaN      NaN
#
#        pf_MIA  pts_MIA  a_team_id_MIA  season_year_MIA  season_type_MIA  \
# 0         NaN      NaN            NaN              NaN              NaN
# 1         NaN      NaN            NaN              NaN              NaN
# 2         NaN      NaN            NaN              NaN              NaN
# 3         NaN      NaN            NaN              NaN              NaN
# 4         NaN      NaN            NaN              NaN              NaN
# ...       ...      ...            ...              ...              ...
# 14152     NaN      NaN            NaN              NaN              NaN
# 14153     NaN      NaN            NaN              NaN              NaN
# 14154     NaN      NaN            NaN              NaN              NaN
# 14155     NaN      NaN            NaN              NaN              NaN
# 14156     NaN      NaN            NaN              NaN              NaN
#
#        season_MIA  abbreviation_MIA
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
# ...           ...               ...
# 14152         NaN               NaN
# 14153         NaN               NaN
# 14154         NaN               NaN
# 14155         NaN               NaN
# 14156         NaN               NaN
#
# [14157 rows x 932 columns]

# %%
df.head()
# Out:
#     game_id   game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0  20600001  2006-10-31    1610612748         0.0       240      25.0
# 1  20600002  2006-10-31    1610612747         1.0       240      46.0
# 2  20600003  2006-11-01    1610612755         1.0       240      31.0
# 3  20600004  2006-11-01    1610612766         0.0       240      37.0
# 4  20600005  2006-11-01    1610612753         1.0       240      35.0
#
#    fga_home  fg_pct_home  fg3m_home  fg3a_home  ...  dreb_away  reb_away  \
# 0      65.0        0.385        3.0       17.0  ...       36.0        49
# 1      83.0        0.554        6.0       12.0  ...       25.0        29
# 2      74.0        0.419        3.0        9.0  ...       25.0        42
# 3      78.0        0.474        4.0       10.0  ...       32.0        50
# 4      59.0        0.593        6.0        8.0  ...       16.0        27
#
#    ast_away  stl_away  blk_away  tov_away  pf_away  pts_away     season_type  \
# 0      22.0      10.0       5.0      16.0     21.0       108  Regular Season
# 1      29.0       7.0       5.0      21.0     25.0       106  Regular Season
# 2      11.0       9.0       4.0      18.0     24.0        75  Regular Season
# 3      26.0      14.0       5.0      17.0     26.0       106  Regular Season
# 4      21.0       7.0       0.0      15.0     31.0        94  Regular Season
#
#     season
# 0  2006-07
# 1  2006-07
# 2  2006-07
# 3  2006-07
# 4  2006-07
#
# [5 rows x 47 columns]

# %%
df = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\raw_data\\nba_betting_totals.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8404e3007b86> in <module>
# ----> 1 df = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\raw_data\\nba_betting_totals.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
#df.select_dtypes('object')

# %%
#df[''].value_counts().head()

# %%
#missing_x = df[[' ', ' ']].isnull().sum(axis=1)

# %%
df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
#df.loc[5, ' '] = 1111

# %%
df.column_name.hist(bins=30)
plt.xlabel('column_name')
plt.ylabel('Count')
plt.title('Distribution of');

# %%
df.column_name[df.column_name < 1000].describe()

# %%
df.iloc[115]

# %%
#type()

# %%
#len()

# %%
#df.iloc[:, 4]

# %%
#df.iloc[:, [0,5,6]].copy()

# %%
#set(df.column_name) - set(df2.column_name)

# %%
#df.state[df.column_name.str.contains('state1|state2|state3|state4')]

# %%
#regex
#df.column_name.replace(to_replace='\[.*\]', value='', regex=True, inplace=True)

# %%
#df.plot(x='column_name1', y='column_name2', kind='scatter');

# %%
#df.loc[df.column_name == 'state1', ['column_name', 'column_name']]

# %%
#missing = pd.concat([df.isnull().sum(axis=1), 100 * df.isnull().mean(axis=1)], axis=1)
#missing.columns=['count', '%']
#missing.sort_values(by='count', ascending=False).head(10)

# %%
#missing['%'].unique()

# %%
#datapath = 'data'

# %%
#if not os.path.exists(datapath):
    #os.mkdir(datapath)

# %%
#datapath_df = os.path.join(datapath, 'df_cleaned.csv')
#if not os.path.exists(datapath_df):
#    df.to_csv(datapath_df, index=False)

# %%
#datapath_df2 = os.path.join(datapath, 'df2.csv')
#if not os.path.exists(datapath_df2):
#    df2.to_csv(datapath_df2, index=False)
