# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in /opt/anaconda3/lib/python3.8/site-packages (1.1.9)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from nba_api) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->nba_api) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import numpy as np

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
from nba_api.stats.endpoints import commonplayerinfo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-11171ee1d306> in <module>
# ----> 1 from nba_api.stats.endpoints import commonplayerinfo
#
# ModuleNotFoundError: No module named 'nba_api.stats'

# %% [markdown]
# # Basics and Package Structure
#
# If you're just interested in pulling data, you will primarily be using `nba_api.stats.endpoints`.
# This submodule contains a class for each API endpoint supported by stats.nba.com.
# For example, [the PlayerCareerStats class](https://github.com/swar/nba_api/blob/master/nba_api/stats/endpoints/playercareerstats.py) is initialized with a player ID and returns some career statistics for the player.

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-359a5b4d2577> in <module>
# ----> 1 from nba_api.stats.endpoints import playercareerstats
#       2 # Anthony Davis
#       3 career = playercareerstats.PlayerCareerStats(player_id='203076')
#       4 career.get_data_frames()[0]
#
# ModuleNotFoundError: No module named 'nba_api.stats'

# %% [markdown]
# `career`, above, is a `PlayerCareerStats` object.
# This class (and the other endpoint classes) supports several methods of accessing the data: `get_dict()`, `get_json()`, `get_data_frames()`, and more.
# `get_data_frames()` returns a list of pandas DataFrames, and when working in notebooks, this is often your best option for viewing data.
# In general, the first DataFrame in this list is the primary returned data structure and the one you'll want to look at.
#
# Almost all of the endpoint classes take at least one required argument, along with several optional ones.
# In the case of `PlayerCareerStats`, a player ID is required, but the user may also specify a league ID.

# %% [markdown]
# At the time of writing this notebook, these are the endpoints available:
#
# <table><tr></tr><tr><td>boxscoreadvancedv2</td><td>boxscorefourfactorsv2</td><td>boxscoremiscv2</td><td>boxscoreplayertrackv2</td></tr><tr><td>boxscorescoringv2</td><td>boxscoresummaryv2</td><td>boxscoretraditionalv2</td><td>boxscoreusagev2</td></tr><tr><td>commonallplayers</td><td>commonplayerinfo</td><td>commonplayoffseries</td><td>commonteamroster</td></tr><tr><td>commonteamyears</td><td>defensehub</td><td>draftcombinedrillresults</td><td>draftcombinenonstationaryshooting</td></tr><tr><td>draftcombineplayeranthro</td><td>draftcombinespotshooting</td><td>draftcombinestats</td><td>drafthistory</td></tr><tr><td>franchisehistory</td><td>homepageleaders</td><td>homepagev2</td><td>infographicfanduelplayer</td></tr><tr><td>leaderstiles</td><td>leaguedashlineups</td><td>leaguedashplayerbiostats</td><td>leaguedashplayerclutch</td></tr><tr><td>leaguedashplayerptshot</td><td>leaguedashplayershotlocations</td><td>leaguedashplayerstats</td><td>leaguedashptdefend</td></tr><tr><td>leaguedashptstats</td><td>leaguedashptteamdefend</td><td>leaguedashteamclutch</td><td>leaguedashteamptshot</td></tr><tr><td>leaguedashteamshotlocations</td><td>leaguedashteamstats</td><td>leaguegamefinder</td><td>leaguegamelog</td></tr><tr><td>leagueleaders</td><td>leaguestandings</td><td>playbyplay</td><td>playbyplayv2</td></tr><tr><td>playerawards</td><td>playercareerstats</td><td>playercompare</td><td>playerdashboardbyclutch</td></tr><tr><td>playerdashboardbygamesplits</td><td>playerdashboardbygeneralsplits</td><td>playerdashboardbylastngames</td><td>playerdashboardbyopponent</td></tr><tr><td>playerdashboardbyshootingsplits</td><td>playerdashboardbyteamperformance</td><td>playerdashboardbyyearoveryear</td><td>playerdashptpass</td></tr><tr><td>playerdashptreb</td><td>playerdashptshotdefend</td><td>playerdashptshots</td><td>playerfantasyprofile</td></tr><tr><td>playerfantasyprofilebargraph</td><td>playergamelog</td><td>playergamestreakfinder</td><td>playernextngames</td></tr><tr><td>playerprofilev2</td><td>playersvsplayers</td><td>playervsplayer</td><td>playoffpicture</td></tr><tr><td>scoreboard</td><td>scoreboardv2</td><td>shotchartdetail</td><td>shotchartlineupdetail</td></tr><tr><td>teamdashboardbyclutch</td><td>teamdashboardbygamesplits</td><td>teamdashboardbygeneralsplits</td><td>teamdashboardbylastngames</td></tr><tr><td>teamdashboardbyopponent</td><td>teamdashboardbyshootingsplits</td><td>teamdashboardbyteamperformance</td><td>teamdashboardbyyearoveryear</td></tr><tr><td>teamdashlineups</td><td>teamdashptpass</td><td>teamdashptreb</td><td>teamdashptshots</td></tr><tr><td>teamdetails</td><td>teamgamelog</td><td>teamgamestreakfinder</td><td>teamhistoricalleaders</td></tr><tr><td>teaminfocommon</td><td>teamplayerdashboard</td><td>teamplayeronoffdetails</td><td>teamplayeronoffsummary</td></tr><tr><td>teamvsplayer</td><td>teamyearbyyearstats</td><td>videodetails</td><td>videoevents</td></tr><tr><td>videostatus</td></tr></table>

# %%
from nba_api.stats.endpoints import playerdashboardbylastngames

# %%
from nba_api.stats.endpoints import boxscoreplayertrackv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-54721b98b04d> in <module>
# ----> 1 from nba_api.stats.endpoints import boxscoreplayertrackv2
#
# ModuleNotFoundError: No module named 'nba_api.stats'

# %%
help(playerdashboardbylastngames)
# Out:
# Help on module nba_api.stats.endpoints.playerdashboardbylastngames in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.playerdashboardbylastngames
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         PlayerDashboardByLastNGames
#
#     class PlayerDashboardByLastNGames(nba_api.stats.endpoints._base.Endpoint)
#      |  PlayerDashboardByLastNGames(player_id, last_n_games='0', measure_type_detailed='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_playoffs='Regular Season', date_from_nullable='', date_to_nullable='', game_segment_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', season_segment_nullable='', shot_clock_range_nullable='', vs_conference_nullable='', vs_division_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      PlayerDashboardByLastNGames
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, player_id, last_n_games='0', measure_type_detailed='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_playoffs='Regular Season', date_from_nullable='', date_to_nullable='', game_segment_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', season_segment_nullable='', shot_clock_range_nullable='', vs_conference_nullable='', vs_division_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  data_sets = None
#      |
#      |  endpoint = 'playerdashboardbylastngames'
#      |
#      |  expected_data = {'GameNumberPlayerDashboard': ['GROUP_SET', 'GROUP_VAL...
#      |
#      |  headers = None
#      |
#      |  nba_response = None
#      |
#      |  player_stats = None
#      |
#      |  team_stats = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  get_available_data(self)
#      |
#      |  get_data_frames(self)
#      |
#      |  get_dict(self)
#      |
#      |  get_json(self)
#      |
#      |  get_normalized_dict(self)
#      |
#      |  get_normalized_json(self)
#      |
#      |  get_request_url(self)
#      |
#      |  get_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  DataSet = <class 'nba_api.stats.endpoints._base.Endpoint.DataSet'>
#
# FILE
#     c:\users\paul\anaconda3\lib\site-packages\nba_api\stats\endpoints\playerdashboardbylastngames.py

# %%
playerdashboardbylastngames.__init__('GameNumberPlayerDashboard', player_id=203076)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-930d2936f1f0> in <module>
# ----> 1 playerdashboardbylastngames.__init__('GameNumberPlayerDashboard', player_id=203076)
#
# TypeError: 'player_id' is an invalid keyword argument for module()

# %%
playerdashboardbylastngames.get_data_frames()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-95a60c801e37> in <module>
# ----> 1 playerdashboardbylastngames.get_data_frames()
#
# AttributeError: module 'nba_api.stats.endpoints.playerdashboardbylastngames' has no attribute 'get_data_frames'

# %%
playerdashboardbylastngames.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3aca94d51d3a> in <module>
# ----> 1 playerdashboardbylastngames.month
#
# AttributeError: module 'nba_api.stats.endpoints.playerdashboardbylastngames' has no attribute 'month'

# %%
help(playerdashboardbylastngames)
# Out:
# Help on module nba_api.stats.endpoints.playerdashboardbylastngames in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.playerdashboardbylastngames
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         PlayerDashboardByLastNGames
#
#     class PlayerDashboardByLastNGames(nba_api.stats.endpoints._base.Endpoint)
#      |  PlayerDashboardByLastNGames(player_id, last_n_games='0', measure_type_detailed='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_playoffs='Regular Season', date_from_nullable='', date_to_nullable='', game_segment_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', season_segment_nullable='', shot_clock_range_nullable='', vs_conference_nullable='', vs_division_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      PlayerDashboardByLastNGames
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, player_id, last_n_games='0', measure_type_detailed='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_playoffs='Regular Season', date_from_nullable='', date_to_nullable='', game_segment_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', season_segment_nullable='', shot_clock_range_nullable='', vs_conference_nullable='', vs_division_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  data_sets = None
#      |
#      |  endpoint = 'playerdashboardbylastngames'
#      |
#      |  expected_data = {'GameNumberPlayerDashboard': ['GROUP_SET', 'GROUP_VAL...
#      |
#      |  headers = None
#      |
#      |  nba_response = None
#      |
#      |  player_stats = None
#      |
#      |  team_stats = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  get_available_data(self)
#      |
#      |  get_data_frames(self)
#      |
#      |  get_dict(self)
#      |
#      |  get_json(self)
#      |
#      |  get_normalized_dict(self)
#      |
#      |  get_normalized_json(self)
#      |
#      |  get_request_url(self)
#      |
#      |  get_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  DataSet = <class 'nba_api.stats.endpoints._base.Endpoint.DataSet'>
#
# FILE
#     c:\users\paul\anaconda3\lib\site-packages\nba_api\stats\endpoints\playerdashboardbylastngames.py

# %%
playerdashboardbylastngames.get_available_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-f63dc7a72a80> in <module>
# ----> 1 playerdashboardbylastngames.get_available_data()
#
# AttributeError: module 'nba_api.stats.endpoints.playerdashboardbylastngames' has no attribute 'get_available_data'

# %%
from nba_api.stats.endpoints import playerdashboardbyshootingsplits
# get_teams returns a list of 30 dictionaries, each an NBA team.

# %%
help(leaguedashplayershotlocations)
# Out:
# Help on module nba_api.stats.endpoints.leaguedashplayershotlocations in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.leaguedashplayershotlocations
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         LeagueDashPlayerShotLocations
#
#     class LeagueDashPlayerShotLocations(nba_api.stats.endpoints._base.Endpoint)
#      |  LeagueDashPlayerShotLocations(distance_range='By Zone', last_n_games='0', measure_type_simple='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_all_star='Regular Season', college_nullable='', conference_nullable='', country_nullable='', date_from_nullable='', date_to_nullable='', division_simple_nullable='', draft_pick_nullable='', draft_year_nullable='', game_scope_simple_nullable='', game_segment_nullable='', height_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', player_experience_nullable='', player_position_abbreviation_nullable='', season_segment_nullable='', shot_clock_range_nullable='', starter_bench_nullable='', team_id_nullable='', vs_conference_nullable='', vs_division_nullable='', weight_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      LeagueDashPlayerShotLocations
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, distance_range='By Zone', last_n_games='0', measure_type_simple='Base', month='0', opponent_team_id=0, pace_adjust='N', per_mode_detailed='Totals', period='0', plus_minus='N', rank='N', season='2020-21', season_type_all_star='Regular Season', college_nullable='', conference_nullable='', country_nullable='', date_from_nullable='', date_to_nullable='', division_simple_nullable='', draft_pick_nullable='', draft_year_nullable='', game_scope_simple_nullable='', game_segment_nullable='', height_nullable='', league_id_nullable='', location_nullable='', outcome_nullable='', po_round_nullable='', player_experience_nullable='', player_position_abbreviation_nullable='', season_segment_nullable='', shot_clock_range_nullable='', starter_bench_nullable='', team_id_nullable='', vs_conference_nullable='', vs_division_nullable='', weight_nullable='', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
#      |
#      |  load_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  data_sets = None
#      |
#      |  endpoint = 'leaguedashplayershotlocations'
#      |
#      |  expected_data = {'ShotLocations': [{'columnNames': ['Restricted Area',...
#      |
#      |  headers = None
#      |
#      |  nba_response = None
#      |
#      |  player_stats = None
#      |
#      |  team_stats = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  get_available_data(self)
#      |
#      |  get_data_frames(self)
#      |
#      |  get_dict(self)
#      |
#      |  get_json(self)
#      |
#      |  get_normalized_dict(self)
#      |
#      |  get_normalized_json(self)
#      |
#      |  get_request_url(self)
#      |
#      |  get_response(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from nba_api.stats.endpoints._base.Endpoint:
#      |
#      |  DataSet = <class 'nba_api.stats.endpoints._base.Endpoint.DataSet'>
#
# FILE
#     c:\users\paul\anaconda3\lib\site-packages\nba_api\stats\endpoints\leaguedashplayershotlocations.py

# %%
nba_teams = playerdashboardbyshootingsplits.get_available_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-c04bd92429fc> in <module>
# ----> 1 nba_teams = playerdashboardbyshootingsplits.get_available_data()
#
# AttributeError: module 'nba_api.stats.endpoints.playerdashboardbyshootingsplits' has no attribute 'get_available_data'

# %%
playerdashboardbyshootingsplits
# Out:
# <module 'nba_api.stats.endpoints.playerdashboardbyshootingsplits' from 'C:\\Users\\Paul\\anaconda3\\lib\\site-packages\\nba_api\\stats\\endpoints\\playerdashboardbyshootingsplits.py'>

# %%
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams[:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0f5ba5297143> in <module>
# ----> 1 print('Number of teams fetched: {}'.format(len(nba_teams)))
#       2 nba_teams[:3]
#
# TypeError: object of type 'module' has no len()

# %% [markdown]
# ### Getting Team and Player IDs
# The package also includes utilities for fetching player and team information available under `nba_api.stats.static`.
# You can use this to fetch player IDs and team IDs, which are often used as inputs to API endpoints.

# %%
from nba_api.stats.static import teams
# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams[:3]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
from nba_api.stats.static import players
# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:5]
# Out:
# Number of players fetched: 4501
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False}]

# %% [markdown]
# To search for an individual team or player by its name (or other attribute), dictionary comprehensions are your friend.

# %%
spurs = [team for team in nba_teams
         if team['full_name'] == 'San Antonio Spurs'][0]
spurs
# Out:
# {'id': 1610612759,
#  'full_name': 'San Antonio Spurs',
#  'abbreviation': 'SAS',
#  'nickname': 'Spurs',
#  'city': 'San Antonio',
#  'state': 'Texas',
#  'year_founded': 1976}

# %%
big_fundamental = [player for player in nba_players
                   if player['full_name'] == 'Tim Duncan'][0]
big_fundamental
# Out:
# {'id': 1495,
#  'full_name': 'Tim Duncan',
#  'first_name': 'Tim',
#  'last_name': 'Duncan',
#  'is_active': False}
