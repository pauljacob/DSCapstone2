# %%
import pandas as pd

pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 999
pd.options.display.max_rows = 999

# %%
from nba_api.stats.endpoints import playerdashboardbylastngames, boxscoreadvancedv2

# %%
playerdashboardbylastngames.PlayerDashboardByLastNGames(player_id=203076).get_data_frames()[0]
# Out:
#   GROUP_SET GROUP_VALUE  GP   W  L  W_PCT         MIN  FGM  FGA  FG_PCT  FG3M  \
# 0   Overall     2020-21  23  17  6  0.739  755.011667  204  383   0.533    17
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA  \
# 0    58    0.293   93  130   0.715    47   146  193   70   45   31   41    13
#
#    PF  PFD  PTS  PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  GP_RANK  W_RANK  \
# 0  42  103  518         135           1025.6    8    0        1       1
#
#    L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0       1           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
# ...

# %%
playerdashboardbylastngames.PlayerDashboardByLastNGames(player_id=203076)

# %%
help(boxscoreadvancedv2)
# Out:
# Help on module nba_api.stats.endpoints.boxscoreadvancedv2 in nba_api.stats.endpoints:
#
# NAME
#     nba_api.stats.endpoints.boxscoreadvancedv2
#
# CLASSES
#     nba_api.stats.endpoints._base.Endpoint(builtins.object)
#         BoxScoreAdvancedV2
#
#     class BoxScoreAdvancedV2(nba_api.stats.endpoints._base.Endpoint)
#      |  BoxScoreAdvancedV2(game_id, end_period='0', end_range='0', range_type='0', start_period='0', start_range='0', proxy=None, headers=None, timeout=30, get_request=True)
#      |
#      |  Method resolution order:
#      |      BoxScoreAdvancedV2
#      |      nba_api.stats.endpoints._base.Endpoint
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, game_id, end_period='0', end_range='0', range_type='0', start_period='0', start_range='0', proxy=None, headers=None, timeout=30, get_request=True)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  get_request(self)
# ...

# %%
boxscoreadvancedv2 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0041700317').get_data_frames()[0]
boxscoreadvancedv2
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041700317  1610612744               GSW  Golden State     201142
# 1   0041700317  1610612744               GSW  Golden State     203110
# 2   0041700317  1610612744               GSW  Golden State    1626172
# 3   0041700317  1610612744               GSW  Golden State     202691
# 4   0041700317  1610612744               GSW  Golden State     201939
# 5   0041700317  1610612744               GSW  Golden State       2733
# 6   0041700317  1610612744               GSW  Golden State    1628395
# 7   0041700317  1610612744               GSW  Golden State    1626188
# 8   0041700317  1610612744               GSW  Golden State     201156
# 9   0041700317  1610612744               GSW  Golden State    1627775
# 10  0041700317  1610612744               GSW  Golden State     201580
# 11  0041700317  1610612744               GSW  Golden State       2585
# ...

# %%
df2 = pd.read_csv('C:\\Users\\Paul\\sb\\DSCapstone2\\raw_data\\injuries_2010-2020.csv')
df2
# Out:
#              Date     Team      Acquired   Relinquished  \
# 0      2010-10-03    Bulls           NaN  Carlos Boozer
# 1      2010-10-06  Pistons           NaN  Jonas Jerebko
# 2      2010-10-06  Pistons           NaN  Terrico White
# 3      2010-10-08  Blazers           NaN     Jeff Ayres
# 4      2010-10-08     Nets           NaN    Troy Murphy
# ...           ...      ...           ...            ...
# 27100  2020-09-30   Lakers  Dion Waiters            NaN
# 27101  2020-10-02     Heat           NaN    Bam Adebayo
# 27102  2020-10-02     Heat           NaN   Goran Dragic
# 27103  2020-10-02     Heat   Chris Silva            NaN
# 27104  2020-10-06     Heat   Bam Adebayo            NaN
#
#                                                           Notes
# 0       fractured bone in right pinky finger (out indefinitely)
# 1                 torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out indefinitely)
# ...
