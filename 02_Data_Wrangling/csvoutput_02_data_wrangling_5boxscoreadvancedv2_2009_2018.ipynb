# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
os.getcwd()
# Out:
# '/Users/pauljacob/Documents/GitHub/DSCapstone2/02_Data_Wrangling'

# %%
#https://www.earthdatascience.org/courses/intro-to-earth-data-science/python-code-fundamentals/work-with-files-directories-paths-in-python/set-working-directory-os-package/
path = os.path.join('..', 'processed_data', '5boxscoreadvancedv2_2006_2018.csv')
path
# Out:
# '../processed_data/5boxscoreadvancedv2_2006_2018.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0       20800716  1610612738               BOS    Boston       1718
# 1       20800716  1610612738               BOS    Boston     201175
# 2       20800716  1610612738               BOS    Boston       2570
# 3       20800716  1610612738               BOS    Boston        951
# 4       20800716  1610612738               BOS    Boston     200765
# ...          ...         ...               ...       ...        ...
# 386106  21000475  1610612757               POR  Portland     201988
# 386107  21000475  1610612757               POR  Portland       1752
# 386108  21000475  1610612757               POR  Portland     202356
# 386109  21000475  1610612757               POR  Portland     202337
# 386110  21000475  1610612757               POR  Portland     200750
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# 0            Paul Pierce              F                     NaN  37:00
# ...

# %%
386000 * .7
# Out:
# 270200.0

# %%
#regular season and playoff games for 2009-10 season?

# %%
path = os.path.join('..', 'processed_data', '3game_date_home_away.csv')
df2 = pd.read_csv(path)
df2
# Out:
#         game_id   game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0      20600001  2006-10-31    1610612748       0.000       240      25.0
# 1      20600002  2006-10-31    1610612747       1.000       240      46.0
# 2      20600003  2006-11-01    1610612755       1.000       240      31.0
# 3      20600004  2006-11-01    1610612766       0.000       240      37.0
# 4      20600005  2006-11-01    1610612753       1.000       240      35.0
# ...         ...         ...           ...         ...       ...       ...
# 15514  41700317  2018-05-28    1610612745       0.429       240      36.0
# 15515  41700401  2018-05-31    1610612744       1.000       265      46.0
# 15516  41700402  2018-06-03    1610612744       1.000       240      47.0
# 15517  41700403  2018-06-06    1610612739       0.000       240      40.0
# 15518  41700404  2018-06-08    1610612739       0.000       240      30.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# ...

# %%
#df2.info()

# %%
#df2[(df2.season == '2009-10')][(df2.season_type == 'Regular Season') | (df2.season_type == 'Playoffs')].reset_index(drop=True)
df2 = df2[(df2.season == '2009-10') |
         (df2.season == '2010-11') |
         (df2.season == '2011-12') |
         (df2.season == '2012-13') |
         (df2.season == '2013-14') |
         (df2.season == '2014-15') |
         (df2.season == '2015-16') |
         (df2.season == '2016-17') |
         (df2.season == '2017-18')].reset_index(drop=True)
df2
# Out:
#         game_id   game_date  team_id_home  w_pct_home  min_home  fgm_home  \
# 0      20900001  2009-10-27    1610612739       0.000       240      29.0
# 1      20900002  2009-10-27    1610612742       0.000       240      30.0
# 2      20900003  2009-10-27    1610612757       1.000       240      33.0
# 3      20900004  2009-10-27    1610612747       1.000       240      35.0
# 4      20900005  2009-10-28    1610612737       1.000       240      46.0
# ...         ...         ...           ...         ...       ...       ...
# 11574  41700317  2018-05-28    1610612745       0.429       240      36.0
# 11575  41700401  2018-05-31    1610612744       1.000       265      46.0
# 11576  41700402  2018-06-03    1610612744       1.000       240      47.0
# 11577  41700403  2018-06-06    1610612739       0.000       240      40.0
# 11578  41700404  2018-06-08    1610612739       0.000       240      30.0
#
#        fga_home  fg_pct_home  fg3m_home  fg3a_home  fg3_pct_home  ftm_home  \
# ...

# %%
df2.season.value_counts()
# Out:
# 2013-14    1319
# 2015-16    1316
# 2012-13    1315
# 2009-10    1312
# 2017-18    1312
# 2010-11    1311
# 2014-15    1311
# 2016-17    1309
# 2011-12    1074
# Name: season, dtype: int64

# %%
df2.shape
# Out:
# (11579, 47)

# %%
23 * 11579
# Out:
# 266317

# %%
df.rename(columns={'GAME_ID':'game_id'}, inplace=True)
df
# Out:
#          game_id     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0       20800716  1610612738               BOS    Boston       1718
# 1       20800716  1610612738               BOS    Boston     201175
# 2       20800716  1610612738               BOS    Boston       2570
# 3       20800716  1610612738               BOS    Boston        951
# 4       20800716  1610612738               BOS    Boston     200765
# ...          ...         ...               ...       ...        ...
# 386106  21000475  1610612757               POR  Portland     201988
# 386107  21000475  1610612757               POR  Portland       1752
# 386108  21000475  1610612757               POR  Portland     202356
# 386109  21000475  1610612757               POR  Portland     202337
# 386110  21000475  1610612757               POR  Portland     200750
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# 0            Paul Pierce              F                     NaN  37:00
# ...

# %%
df = pd.merge(df, df2.game_id, how='right', on='game_id').rename(columns={'game_id':'GAME_ID'})
df
# Out:
#          GAME_ID       TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0       20900001  1.610613e+09               BOS     Boston     1718.0
# 1       20900001  1.610613e+09               BOS     Boston      708.0
# 2       20900001  1.610613e+09               BOS     Boston     2570.0
# 3       20900001  1.610613e+09               BOS     Boston      951.0
# 4       20900001  1.610613e+09               BOS     Boston   200765.0
# ...          ...           ...               ...        ...        ...
# 291638  41700404  1.610613e+09               CLE  Cleveland  1626204.0
# 291639  41700404  1.610613e+09               CLE  Cleveland  1626224.0
# 291640  41700404  1.610613e+09               CLE  Cleveland   101181.0
# 291641  41700404  1.610613e+09               CLE  Cleveland  1627790.0
# 291642  41700404  1.610613e+09               CLE  Cleveland   203903.0
#
#              PLAYER_NAME START_POSITION                 COMMENT    MIN  \
# ...

# %%
#df[df.GAME_ID == 20900001]
#23

# %%
set1=  set(df.GAME_ID)

# %%
set2 = set(df2.game_id)

# %%
set2 - set1
# Out:
# set()

# %%
set1  - set2
# Out:
# set()

# %%
datapath = os.path.join('..', 'processed_data')

if not os.path.exists(datapath):
    os.mkdir(datapath)

datapath_df = os.path.join(datapath, '5boxscoreadvancedv2_2009_2018.csv')
if not os.path.exists(datapath_df):
    df.to_csv(datapath_df, index=False)
